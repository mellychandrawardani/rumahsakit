# %% [markdown]
# # CATATAN ADAPTASI UNTUK KAGGLE
#
# Notebook ini awalnya dibuat untuk **Google Colab** (memakai `google.colab.drive` dan folder
# `MyDrive/NEW/...`). Sekarang sudah disesuaikan untuk **Kaggle Notebook**, dengan dataset
# bernama **`new-dataset`** yang isinya SEMUA file (xlsx & pkl) langsung di root dataset —
# **benar-benar flat, tanpa subfolder apapun** (tidak ada `preprocessed_data`, tidak ada
# `processed-data`, tidak ada `experiment_states`, dst).
#
# ## Langkah yang perlu kamu lakukan di Kaggle (sebelum run):
#
# 1. **Dataset `new-dataset` sudah kamu buat di Kaggle** berisi semua file (xlsx & pkl) langsung
#    di root dataset (tidak ada subfolder sama sekali).
# 2. **Tambahkan dataset ke notebook** — klik **+ Add Input** (panel kanan) -> cari `new-dataset`
#    -> **Add**, lalu restart session.
# 3. **Aktifkan GPU** (Settings -> Accelerator -> GPU) karena training dilakukan untuk 3 nilai
#    dropout (0.2, 0.5, 0.8), masing-masing dengan 5-fold K-Fold.
#
# ## Perbaikan di versi ini:
# - Semua pembacaan file dari dataset (`dataset_hasil_labelling_aspek.xlsx`, `aspect_le.pkl`,
#   `sentiment_le.pkl`) sekarang lewat helper `find_input_file(...)` yang mencari file
#   **langsung di root `INPUT_DIR`**, dan otomatis mencari satu tingkat ke bawah kalau ternyata
#   Kaggle tetap membungkusnya dalam folder tambahan. Kalau file benar-benar tidak ada, cell akan
#   menampilkan **isi folder dataset yang sebenarnya** supaya gampang di-debug — bukan cuma error
#   generik.
# - `INPUT_DIR` dideteksi otomatis dari `/kaggle/input` (bukan hardcode `new-dataset` saja), jadi
#   kalau slug dataset kamu sedikit berbeda, notebook tetap jalan dan akan memberi peringatan.
# - `drive.mount(...)` dihapus total (Kaggle tidak pakai Google Drive).
# - Semua path pakai dua variabel utama:
#   - `INPUT_DIR` = dataset Kaggle (read-only, FLAT, tanpa subfolder).
#   - `WORK_DIR` = `/kaggle/working` (semua model, pickle, dataset olahan disimpan di sini;
#     otomatis ikut tersimpan saat kamu klik **Save Version**).
# - `BASE_DRIVE_PATH`, `SAVE_ROOT_PATH` tetap dipakai di cell-cell berikutnya (supaya struktur kode
#   asli tidak perlu diubah total), tapi sekarang jadi subfolder di dalam `WORK_DIR` (writable).
# - **Penting**: `/kaggle/input` bersifat *read-only* — semua hasil (model .keras, tokenizer.pkl,
#   dataset olahan) disimpan ke `/kaggle/working`.
#
# ## Uji coba parameter Dropout (0.2 / 0.5 / 0.8)
# - `DROPOUT_VALUES = [0.2, 0.5, 0.8]` di cell konfigurasi paling atas.
# - Cell training **klasifikasi aspek** dan **sentimen per aspek** melatih model untuk
#   **setiap nilai dropout**, masing-masing dengan 5-fold K-Fold (total training jauh lebih
#   lama — pastikan GPU aktif).
# - Nama file model menyertakan nilai dropout, misal:
#   `aspect_model_dropout_0_2_fold_1.keras`, `sentiment_model_<aspek>_dropout_0_5_fold_3.keras`.
# - Cell evaluasi menampilkan **perbandingan akurasi per nilai dropout** (per fold, rata-rata
#   K-Fold, dan ensemble soft-voting).
# - Model terbaik yang disimpan ke `best_models/` dan `best_sentiment_models/` dipilih dari
#   akurasi tertinggi **lintas semua nilai dropout & fold**.

# %% [markdown]
# #SAVE DATA

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
import os
from IPython.display import display  # sudah otomatis tersedia di notebook Kaggle, import ini jaga-jaga saja

# ==========================================================
# KONFIGURASI PATH UNTUK KAGGLE
# ==========================================================
# Dataset 'new-dataset' berisi SEMUA file (xlsx & pkl) LANGSUNG di root-nya,
# TIDAK ADA subfolder apapun (tidak ada 'preprocessed_data', tidak ada
# 'processed-data', tidak ada 'experiment_states', dst). Semua file dibaca
# langsung dari INPUT_DIR.

_KAGGLE_INPUT_ROOT = '/kaggle/input'
_PREFERRED_SLUG = 'new-dataset'

if os.path.isdir(_KAGGLE_INPUT_ROOT):
    _available_datasets = sorted(os.listdir(_KAGGLE_INPUT_ROOT))
else:
    _available_datasets = []

if _PREFERRED_SLUG in _available_datasets:
    INPUT_DIR = os.path.join(_KAGGLE_INPUT_ROOT, _PREFERRED_SLUG)
elif _available_datasets:
    # Fallback: kalau slug persis 'new-dataset' tidak ketemu, otomatis pakai
    # dataset pertama yang tersedia supaya notebook tetap bisa jalan.
    INPUT_DIR = os.path.join(_KAGGLE_INPUT_ROOT, _available_datasets[0])
    print(f"Peringatan: slug '{_PREFERRED_SLUG}' tidak ditemukan di /kaggle/input, "
          f"otomatis pakai dataset pertama yang tersedia: '{_available_datasets[0]}'")
else:
    INPUT_DIR = os.path.join(_KAGGLE_INPUT_ROOT, _PREFERRED_SLUG)
    print("Peringatan: /kaggle/input kosong atau tidak ada. Pastikan dataset sudah "
          "ditambahkan lewat '+ Add Input' lalu restart session.")

# WORK_DIR -> folder kerja Kaggle, tempat semua output (model, pickle,
# dataset hasil olahan) disimpan. Isinya otomatis ikut tersimpan saat
# kamu klik "Save Version".
WORK_DIR = '/kaggle/working'
os.makedirs(WORK_DIR, exist_ok=True)

# DROPOUT_VALUES -> daftar nilai dropout yang ingin diuji coba pada
# training LSTM (klasifikasi aspek maupun sentimen per aspek).
DROPOUT_VALUES = [0.2, 0.5, 0.8]

# ==========================================================
# HELPER: cari file di dalam dataset
# ==========================================================
def find_input_file(filename, base_dir=None, required=True):
    """Cari `filename` di dalam base_dir (default INPUT_DIR).
    Dataset SEHARUSNYA flat (file langsung ada di root), tapi helper ini
    tetap mencari satu tingkat ke bawah untuk jaga-jaga. Kalau tidak
    ketemu, isi folder dataset ditampilkan supaya gampang di-debug."""
    base_dir = base_dir or INPUT_DIR

    direct_path = os.path.join(base_dir, filename)
    if os.path.isfile(direct_path):
        return direct_path

    if os.path.isdir(base_dir):
        for root, _dirs, files in os.walk(base_dir):
            if filename in files:
                return os.path.join(root, filename)

    if required:
        print(f"File '{filename}' tidak ditemukan di dalam '{base_dir}'.")
        if os.path.isdir(base_dir):
            print("Isi folder dataset saat ini:")
            found_any = False
            for root, _dirs, files in os.walk(base_dir):
                for f in files:
                    found_any = True
                    print(" -", os.path.relpath(os.path.join(root, f), base_dir))
            if not found_any:
                print(" (folder kosong)")
        else:
            print(f"Folder '{base_dir}' tidak ada sama sekali.")
        raise FileNotFoundError(
            f"'{filename}' tidak ditemukan di '{base_dir}'. Pastikan dataset "
            f"'{_PREFERRED_SLUG}' sudah ditambahkan via '+ Add Input', berisi file ini "
            f"langsung di root, dan session sudah di-restart setelah menambahkannya."
        )
    return None

print(f"Dataset yang terdeteksi di /kaggle/input : {_available_datasets}")
print(f"INPUT_DIR (dataset flat, semua file di root) : {INPUT_DIR}")
print(f"WORK_DIR  (folder kerja / output)             : {WORK_DIR}")
print(f"DROPOUT_VALUES (uji coba dropout)             : {DROPOUT_VALUES}")
# Out:
# Peringatan: slug 'new-dataset' tidak ditemukan di /kaggle/input, otomatis pakai dataset pertama yang tersedia: 'datasets'
# Dataset yang terdeteksi di /kaggle/input : ['datasets']
# INPUT_DIR (dataset flat, semua file di root) : /kaggle/input/datasets
# WORK_DIR  (folder kerja / output)             : /kaggle/working
# DROPOUT_VALUES (uji coba dropout)             : [0.2, 0.5, 0.8]

# %%
import os

# Sebelumnya ada DUA folder root berbeda (BASE_DRIVE_PATH = 'epoch_lima' dan
# SAVE_ROOT_PATH = 'EPOCH 05'), sehingga model, tokenizer, dan dataset olahan
# tersebar di dua tempat berbeda. Sekarang disatukan jadi SATU folder saja:
# WORK_DIR/EPOCH_05 -- dipakai bersama oleh BASE_DRIVE_PATH & SAVE_ROOT_PATH.
BASE_DRIVE_PATH = os.path.join(WORK_DIR, 'EPOCH_05')
SAVE_ROOT_PATH = BASE_DRIVE_PATH  # alias, disatukan supaya tidak ada folder duplikat

os.makedirs(BASE_DRIVE_PATH, exist_ok=True)
os.makedirs(os.path.join(BASE_DRIVE_PATH, 'experiment_states'), exist_ok=True)

print(f"Base path (disatukan) untuk semua output disetel ke: {BASE_DRIVE_PATH}")
# Out:
# Base path (disatukan) untuk semua output disetel ke: /kaggle/working/EPOCH_05

# %%
import pandas as pd
import os

# Dataset 'new-dataset' FLAT -> file langsung ada di root INPUT_DIR (tidak ada
# subfolder 'preprocessed_data' / 'processed-data' sama sekali).
# PREPROCESSED_DATA_DIR dipertahankan sebagai alias supaya cell-cell
# berikutnya tidak perlu diubah strukturnya.
PREPROCESSED_DATA_DIR = INPUT_DIR
# CATATAN: /kaggle/input bersifat READ-ONLY -> tidak perlu (dan tidak bisa) os.makedirs di sini.

try:
    file_path_to_load = find_input_file("dataset_hasil_labelling_aspek.xlsx", base_dir=PREPROCESSED_DATA_DIR)
    print(f"Mencoba memuat file dari: {file_path_to_load}")

    df_loaded = pd.read_excel(file_path_to_load)

    print("File berhasil dimuat! Berikut adalah 5 baris pertama:")
    display(df_loaded.head())

except FileNotFoundError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"Terjadi kesalahan saat memuat file: {e}")
# Out:
# Mencoba memuat file dari: /kaggle/input/datasets/mellychanwardani/new-dataset/dataset_hasil_labelling_aspek.xlsx
# File berhasil dimuat! Berikut adalah 5 baris pertama:
#    Original_Review_ID                                             Review  \
# 0                   0  Ruang flamboyan rumah sakit mitra keluarga dar...
# 1                   1  Ruang flamboyan rumah sakit mitra keluarga dar...
# 2                   2  nilai plusnya -dekat dari rumah -obat yang dib...
# 3                   3                           Pelayanan baik memuaskan
# 4                   4  Dirawat inap di kamar Flamboyan, setelah opera...
#
#   Extracted_Opinion      Translated_Opinion  Cleaned_Opinion  \
# 0       kamar penuh               full room      kamar penuh
# 1     perawat ramah          friendly nurse    perawat ramah
# 2   kebetulan cocok  coincidentally matched  kebetulan cocok
# 3    Pelayanan baik            Good service   Pelayanan baik
# 4      tenaga medis       medical personnel     tenaga medis
#
#   Casefolded_Opinion       Tokenized_Opinion Vader_Sentiment_Category  \
# 0        kamar penuh      ['kamar', 'penuh']                  Neutral
# 1      perawat ramah    ['perawat', 'ramah']                 Positive
# 2    kebetulan cocok  ['kebetulan', 'cocok']                  Neutral
# 3     pelayanan baik   ['pelayanan', 'baik']                 Positive
# 4       tenaga medis     ['tenaga', 'medis']                  Neutral
#
#    Sentiment_encoded                              Aspek  Aspek_encoded
# 0                  1        fasilitas dan infrastruktur              1
# 1                  2  kualitas pelayanan medis dan staf              2
# 2                  1                            lainnya              3
# 3                  2  kualitas pelayanan medis dan staf              2
# 4                  1  kualitas pelayanan medis dan staf              2

# %%
import os
import pandas as pd

# Ensure SAVE_ROOT_PATH is defined (it should be from previous cells)
if 'SAVE_ROOT_PATH' not in globals():
    SAVE_ROOT_PATH = os.path.join(WORK_DIR, 'EPOCH_05')  # Fallback value if not defined (disatukan dengan BASE_DRIVE_PATH)
    print("Warning: SAVE_ROOT_PATH not found, using default fallback path.")

# Define the directory where you want to save the file
save_directory = SAVE_ROOT_PATH

# Ensure the save directory exists
os.makedirs(save_directory, exist_ok=True)

# Define the full path for the output file
output_file_path = os.path.join(save_directory, 'dataset_hasil_labelling_aspek.xlsx')

# Check if df_loaded exists and is a DataFrame before saving
if 'df_loaded' in globals() and isinstance(df_loaded, pd.DataFrame):
    try:
        # Save the DataFrame to an Excel file
        df_loaded.to_excel(output_file_path, index=False)
        print(f"✅ Dataset 'dataset_hasil_labelling_aspek' berhasil disimpan ke: {output_file_path}")
    except Exception as e:
        print(f"❌ Terjadi kesalahan saat menyimpan file: {e}")
else:
    print("❌ DataFrame 'df_loaded' tidak ditemukan atau bukan DataFrame. Pastikan telah dimuat sebelumnya.")
# Out:
# ✅ Dataset 'dataset_hasil_labelling_aspek' berhasil disimpan ke: /kaggle/working/EPOCH_05/dataset_hasil_labelling_aspek.xlsx

# %%
# !pip install -q scikit-learn==1.8.0

# %%
import os
import pickle
from sklearn.preprocessing import LabelEncoder  # Import LabelEncoder for potential fallback initialization

# aspect_le.pkl & sentiment_le.pkl diharapkan ada LANGSUNG di root dataset
# 'new-dataset' (flat, tanpa subfolder 'experiment_states').
EXPERIMENT_STATES_DIR = INPUT_DIR  # alias, dipertahankan untuk kompatibilitas
# CATATAN: /kaggle/input bersifat READ-ONLY -> tidak perlu os.makedirs di sini.

# --- Load aspect_le.pkl ---
aspect_le = None  # Initialize aspect_le
try:
    aspect_le_path = find_input_file('aspect_le.pkl', base_dir=EXPERIMENT_STATES_DIR)
    with open(aspect_le_path, 'rb') as f:
        aspect_le = pickle.load(f)
    print(f"'aspect_le.pkl' berhasil dimuat dari: {aspect_le_path}")
    print(f"Kelas aspek yang dimuat: {aspect_le.classes_}")
except FileNotFoundError as e:
    print(f"Error: {e}")
    # Optionally, initialize with a dummy LabelEncoder if file not found
    aspect_le = LabelEncoder()
except Exception as e:
    print(f"Terjadi kesalahan saat memuat 'aspect_le.pkl': {e}")
    aspect_le = LabelEncoder()

# --- Load sentiment_le.pkl ---
sentiment_le = None  # Initialize sentiment_le
try:
    sentiment_le_path = find_input_file('sentiment_le.pkl', base_dir=EXPERIMENT_STATES_DIR)
    with open(sentiment_le_path, 'rb') as f:
        sentiment_le = pickle.load(f)
    print(f"'sentiment_le.pkl' berhasil dimuat dari: {sentiment_le_path}")
    print(f"Kelas sentimen yang dimuat: {sentiment_le.classes_}")
except FileNotFoundError as e:
    print(f"Error: {e}")
    # Optionally, initialize with a dummy LabelEncoder if file not found
    sentiment_le = LabelEncoder()
except Exception as e:
    print(f"Terjadi kesalahan saat memuat 'sentiment_le.pkl': {e}")
    sentiment_le = LabelEncoder()
# Out:
# 'aspect_le.pkl' berhasil dimuat dari: /kaggle/input/datasets/mellychanwardani/new-dataset/aspect_le.pkl
# Kelas aspek yang dimuat: ['biaya layanan' 'fasilitas dan infrastruktur'
#  'kualitas pelayanan medis dan staf' 'lainnya' 'waktu tunggu']
# 'sentiment_le.pkl' berhasil dimuat dari: /kaggle/input/datasets/mellychanwardani/new-dataset/sentiment_le.pkl
# Kelas sentimen yang dimuat: ['Negative' 'Neutral' 'Positive']

# %%
import pickle
import os

# Ensure EXPERIMENT_DIR_FULL_PATH is defined and correct
if 'EXPERIMENT_DIR_FULL_PATH' not in globals():
    # Fallback if EXPERIMENT_DIR_FULL_PATH somehow wasn't defined
    SAVE_ROOT_PATH = os.path.join(WORK_DIR, 'EPOCH_05')
    EXPERIMENT_DIR_FULL_PATH = os.path.join(SAVE_ROOT_PATH, 'experiment_states')
    os.makedirs(EXPERIMENT_DIR_FULL_PATH, exist_ok=True)
    print("Warning: EXPERIMENT_DIR_FULL_PATH not defined, using default fallback path.")

# Save aspect_le.pkl
if 'aspect_le' in globals():
    aspect_le_save_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'aspect_le.pkl')
    with open(aspect_le_save_path, "wb") as f:
        pickle.dump(aspect_le, f)
    print(f"'aspect_le.pkl' saved successfully to: '{aspect_le_save_path}'")
else:
    print("Error: 'aspect_le' object not found in current session. Not saving aspect_le.pkl.")

# Save sentiment_le.pkl
if 'sentiment_le' in globals():
    sentiment_le_save_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'sentiment_le.pkl')
    with open(sentiment_le_save_path, "wb") as f:
        pickle.dump(sentiment_le, f)
    print(f"'sentiment_le.pkl' saved successfully to: '{sentiment_le_save_path}'")
else:
    print("Error: 'sentiment_le' object not found in current session. Not saving sentiment_le.pkl.")
# Out:
# Warning: EXPERIMENT_DIR_FULL_PATH not defined, using default fallback path.
# 'aspect_le.pkl' saved successfully to: '/kaggle/working/EPOCH_05/experiment_states/aspect_le.pkl'
# 'sentiment_le.pkl' saved successfully to: '/kaggle/working/EPOCH_05/experiment_states/sentiment_le.pkl'

# %% [markdown]
# #KLASIFIKASI ASPEK

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# Ensure PREPROCESSED_DATA_DIR is defined
# (It should be defined in previous cells, but we ensure its availability)
if 'PREPROCESSED_DATA_DIR' not in globals():
    # Dataset Kaggle diupload FLAT (tanpa subfolder) -> langsung pakai INPUT_DIR
    print("Warning: PREPROCESSED_DATA_DIR not found, falling back to INPUT_DIR.")
    PREPROCESSED_DATA_DIR = INPUT_DIR

df_data = pd.read_excel(find_input_file('dataset_hasil_labelling_aspek.xlsx', base_dir=PREPROCESSED_DATA_DIR))
X_data = df_data[['Tokenized_Opinion']]
Y_aspect_data = df_data['Aspek_encoded']
Y_sentiment_data = df_data['Sentiment_encoded']

X_train_full, X_test_full, Y_train_aspect, Y_test_aspect = train_test_split(
    X_data,
    Y_aspect_data,
    test_size=0.2,
    random_state=42,
    stratify=Y_aspect_data
)

Y_train_sent = Y_sentiment_data.loc[X_train_full.index]
Y_test_sent = Y_sentiment_data.loc[X_test_full.index]

print("--- Hasil Split ---")
print("Data Training:", X_train_full.shape[0], "baris")
print("Data Testing:", X_test_full.shape[0], "baris")
# Out:
# --- Hasil Split ---
# Data Training: 4204 baris
# Data Testing: 1051 baris

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import ast
import os
import pickle

def ensure_list(text):
    if isinstance(text, str) and text.startswith('['):
        try:
            return ast.literal_eval(text)
        except (ValueError, SyntaxError):
            return []
    elif isinstance(text, list):
        return text
    return []

X_train_texts = X_train_full['Tokenized_Opinion'].apply(ensure_list).apply(lambda x: ' '.join(x) if x else '')
X_test_texts = X_test_full['Tokenized_Opinion'].apply(ensure_list).apply(lambda x: ' '.join(x) if x else '')

print(f"  Training samples (X_train_texts): {len(X_train_texts)}")
print(f"  Testing samples (X_test_texts): {len(X_test_texts)}")
print(f"  Example X_train_texts (first row): {X_train_texts.head(1).iloc[0]}")

# Tokenizer
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train_texts)  # fit only on training data texts

# Convert texts to sequences of indices
X_train_seq = tokenizer.texts_to_sequences(X_train_texts)
X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

# Padding
maxlen = 20  # Max length for sequences
X_train_pad = pad_sequences(X_train_seq, maxlen=maxlen, padding='post', truncating='post')
X_test_pad = pad_sequences(X_test_seq, maxlen=maxlen, padding='post', truncating='post')

# Info results
print("Tokenization & Padding complete.")
print(f"  Vocabulary size   : {len(tokenizer.word_index)} unique words")
print(f"  Train data shape  : {X_train_pad.shape}")
print(f"  Test data shape   : {X_test_pad.shape}")

if X_train_seq:
    print(f"  Example first train sequence (first 20 tokens):\n{X_train_seq[0][:20]}")
else:
    print("  No training sequences generated.")

# Save tokenizer ke WORK_DIR (Kaggle)
# SAVE_ROOT_PATH sudah disatukan dengan BASE_DRIVE_PATH di cell konfigurasi
# (WORK_DIR/EPOCH_05), jadi tidak perlu didefinisikan ulang ke folder lain.
if 'SAVE_ROOT_PATH' not in globals():
    SAVE_ROOT_PATH = os.path.join(WORK_DIR, 'EPOCH_05')
EXPERIMENT_DIR_FULL_PATH = os.path.join(SAVE_ROOT_PATH, 'experiment_states')

os.makedirs(EXPERIMENT_DIR_FULL_PATH, exist_ok=True)
tokenizer_save_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'tokenizer_lstm.pkl')
with open(tokenizer_save_path, "wb") as f:
    pickle.dump(tokenizer, f)
print(f"Tokenizer saved to '{tokenizer_save_path}'")
# Out:
#   Training samples (X_train_texts): 4204
#   Testing samples (X_test_texts): 1051
#   Example X_train_texts (first row): sakit sebelah perlu rujukan
# Tokenization & Padding complete.
#   Vocabulary size   : 1503 unique words
#   Train data shape  : (4204, 20)
#   Test data shape   : (1051, 20)
#   Example first train sequence (first 20 tokens):
# [3, 380, 241, 323]
# Tokenizer saved to '/kaggle/working/EPOCH_05/experiment_states/tokenizer_lstm.pkl'

# %%
import pickle
from sklearn.preprocessing import LabelEncoder

# Load the aspect label encoder from the drive
aspect_le_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'aspect_le.pkl') # Corrected: consistency with 'sentiment_le.pkl' to match global testing

try:
    with open(aspect_le_path, 'rb') as f:
        aspect_le = pickle.load(f)
    print(f"Aspect LabelEncoder loaded from '{aspect_le_path}'")
    print(f"Number of aspect classes: {len(aspect_le.classes_)}")
except FileNotFoundError:
    print(f"Error: '{aspect_le_path}' not found. Please ensure the aspect label encoder is saved at this location.")
    aspect_le = LabelEncoder()
    if 'df_data' in globals():
        aspect_le.fit(df_data['Aspek'])
        print("Warning: Aspect LabelEncoder not found, a new one was created from df_data['Aspek']. Please ensure this is the intended behavior.")
        print(f"Number of aspect classes (newly created): {len(aspect_le.classes_)}")
    else:
        print("Error: df_data not found to create aspect_le. Please check previous cells.")

# Load or create the sentiment label encoder
sentiment_le_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'sentiment_le.pkl') # Corrected: consistent naming with saving in Lx5RY78R5SW4 and loading in f11050e1

try:
    with open(sentiment_le_path, 'rb') as f:
        sentiment_le = pickle.load(f)
    print(f"Sentiment LabelEncoder loaded from '{sentiment_le_path}'")
    print(f"Sentiment classes: {sentiment_le.classes_}")
except FileNotFoundError:
    print(f"Error: '{sentiment_le_path}' not found. Please ensure the sentiment label encoder is saved at this location.")
    sentiment_le = LabelEncoder()
    if 'df_data' in globals():
        sentiment_le.fit(df_data['Vader_Sentiment_Category'])
        print("Warning: Sentiment LabelEncoder not found, a new one was created from df_data['Vader_Sentiment_Category']. Please ensure this is the intended behavior.")
        print(f"Sentiment classes (newly created): {sentiment_le.classes_}")
        # Optionally save it for future runs
        try:
            with open(sentiment_le_path, "wb") as f:
                pickle.dump(sentiment_le, f)
            print(f"Newly created Sentiment LabelEncoder saved to '{sentiment_le_path}'")
        except Exception as e:
            print(f"Could not save sentiment_le to drive: {e}")
    else:
        print("Error: df_data not found to create sentiment_le. Please check previous cells.")
# Out:
# Aspect LabelEncoder loaded from '/kaggle/working/EPOCH_05/experiment_states/aspect_le.pkl'
# Number of aspect classes: 5
# Sentiment LabelEncoder loaded from '/kaggle/working/EPOCH_05/experiment_states/sentiment_le.pkl'
# Sentiment classes: ['Negative' 'Neutral' 'Positive']

# %%
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping # Removed EarlyStopping

import numpy as np
import tensorflow as tf
import random
import os # Added os import for saving models correctly

# =========================
# RANDOM SEED
# =========================
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# =========================
# PARAMETER
# =========================
vocab_size = 5000
max_len = 20
num_classes = len(aspect_le.classes_)

EPOCHS = 5

# =========================
# PARAMETER UJI COBA DROPOUT
# =========================
# DROPOUT_VALUES didefinisikan di cell konfigurasi paling atas.
# Kalau belum ada (misal cell konfigurasi belum dijalankan), fallback ke default berikut.
if 'DROPOUT_VALUES' not in globals():
    DROPOUT_VALUES = [0.2, 0.5, 0.8]

print(f"Dropout yang akan diuji untuk klasifikasi aspek: {DROPOUT_VALUES}")

# =========================
# KFOLD
# =========================
skf = KFold(
    n_splits=5,
    shuffle=True,
    random_state=SEED
)

# Define directory for saving models
model_save_dir = os.path.join(BASE_DRIVE_PATH, 'aspect_classification_models')
os.makedirs(model_save_dir, exist_ok=True)

# Menyimpan ringkasan rata-rata akurasi per nilai dropout
dropout_summary = []

# =========================
# LOOP TIAP NILAI DROPOUT
# =========================
for dropout_rate in DROPOUT_VALUES:

    dropout_tag = str(dropout_rate).replace('.', '_')

    print("\n" + "#"*60)
    print(f"# TRAINING KLASIFIKASI ASPEK DENGAN DROPOUT = {dropout_rate}")
    print("#"*60)

    print("="*60)
    print(f"TRAINING DENGAN MAX EPOCH = {EPOCHS}")
    print("="*60)

    # best_val_loss = float('inf') # Removed as EarlyStopping is removed
    fold_no = 1

    fold_accuracies = []

    # =========================
    # KFOLD LOOP
    # =========================
    for train_index, val_index in skf.split(X_train_pad, Y_train_aspect):

        print(f"\n====== Dropout {dropout_rate} | Fold {fold_no} ======")

        # =========================
        # SPLIT DATA
        # =========================
        X_tr = X_train_pad[train_index]
        X_val = X_train_pad[val_index]

        y_tr = Y_train_aspect.iloc[train_index]
        y_val = Y_train_aspect.iloc[val_index]

        # =========================
        # MODEL
        # =========================
        model = Sequential([

            Embedding(
                input_dim=vocab_size,
                output_dim=128,
                mask_zero=True
            ),

            LSTM(
                128,
                return_sequences=True,
                dropout=dropout_rate,
                recurrent_dropout=dropout_rate
            ),

            LSTM(
                64,
                dropout=dropout_rate,
                recurrent_dropout=dropout_rate
            ),

            Dense(128, activation='relu'),

            Dropout(dropout_rate),

            Dense(num_classes, activation='softmax')
        ])

        # =========================
        # COMPILE
        # =========================
        model.compile(
            optimizer=Adam(learning_rate=0.0005),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        # =========================
        # EARLY STOPPING - REMOVED
        # =========================
        # early_stopping = EarlyStopping(
        #     monitor='val_loss',
        #     patience=2,
        #     restore_best_weights=True,
        #     verbose=1
        # )

        # =========================
        # TRAINING
        # =========================
        history = model.fit(
            X_tr,
            y_tr,
            epochs=EPOCHS,
            batch_size=32,
            validation_data=(X_val, y_val),
            # callbacks=[early_stopping], # Removed early_stopping from callbacks
            verbose=1
        )

        # =========================
        # EVALUASI
        # =========================
        scores = model.evaluate(
            X_val,
            y_val,
            verbose=0
        )

        print(f"\nDropout {dropout_rate} | Fold {fold_no}")
        print(f"Loss     : {scores[0]:.4f}")
        print(f"Accuracy : {scores[1]:.4f}")

        fold_accuracies.append(scores[1])

        # =========================
        # SAVE MODEL FOR EACH FOLD
        # =========================
        # Nama file sekarang menyertakan nilai dropout supaya tiap konfigurasi
        # bisa dibandingkan pada cell evaluasi berikutnya.
        model_filename = os.path.join(
            model_save_dir,
            f"aspect_model_dropout_{dropout_tag}_fold_{fold_no}.keras"
        )
        model.save(model_filename)
        print(f"Model for Dropout {dropout_rate} Fold {fold_no} saved to: {model_filename}")

        fold_no += 1

    # =========================
    # RATA-RATA AKURASI UNTUK DROPOUT INI
    # =========================
    avg_acc = np.mean(fold_accuracies)
    dropout_summary.append({'dropout': dropout_rate, 'avg_accuracy': avg_acc})

    print("\n" + "="*60)
    print(f"HASIL AKHIR DROPOUT = {dropout_rate}")
    print("="*60)

    print(f"Average Accuracy : {avg_acc:.4f}")

# =========================
# RINGKASAN PERBANDINGAN SEMUA DROPOUT
# =========================
print("\n" + "#"*60)
print("# RINGKASAN PERBANDINGAN DROPOUT (Klasifikasi Aspek)")
print("#"*60)
for row in dropout_summary:
    print(f"Dropout {row['dropout']}: rata-rata accuracy (K-Fold) = {row['avg_accuracy']:.4f}")
# Out:
# Dropout yang akan diuji untuk klasifikasi aspek: [0.2, 0.5, 0.8]
#
# ############################################################
# # TRAINING KLASIFIKASI ASPEK DENGAN DROPOUT = 0.2
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.2 | Fold 1 ======
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782873107.713393     259 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1782873107.716502     259 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 25s 132ms/step - accuracy: 0.6408 - loss: 1.1681 - val_accuracy: 0.8098 - val_loss: 0.6995
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.8891 - loss: 0.4208 - val_accuracy: 0.9144 - val_loss: 0.3001
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.9575 - loss: 0.1535 - val_accuracy: 0.9489 - val_loss: 0.1861
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9712 - loss: 0.0843 - val_accuracy: 0.9560 - val_loss: 0.1463
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.9786 - loss: 0.0515 - val_accuracy: 0.9631 - val_loss: 0.1198
#
# Dropout 0.2 | Fold 1
# Loss     : 0.1198
# Accuracy : 0.9631
# Model for Dropout 0.2 Fold 1 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_2_fold_1.keras
#
# ====== Dropout 0.2 | Fold 2 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.6438 - loss: 1.1637 - val_accuracy: 0.8074 - val_loss: 0.6600
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.8799 - loss: 0.4434 - val_accuracy: 0.9227 - val_loss: 0.2779
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.9387 - loss: 0.1721 - val_accuracy: 0.9477 - val_loss: 0.1890
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9694 - loss: 0.0872 - val_accuracy: 0.9572 - val_loss: 0.1534
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.9762 - loss: 0.0565 - val_accuracy: 0.9620 - val_loss: 0.1427
#
# Dropout 0.2 | Fold 2
# Loss     : 0.1427
# Accuracy : 0.9620
# Model for Dropout 0.2 Fold 2 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_2_fold_2.keras
#
# ====== Dropout 0.2 | Fold 3 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.6461 - loss: 1.1721 - val_accuracy: 0.8407 - val_loss: 0.6727
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.8956 - loss: 0.4108 - val_accuracy: 0.9037 - val_loss: 0.3076
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.9411 - loss: 0.1778 - val_accuracy: 0.9382 - val_loss: 0.1847
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9688 - loss: 0.0909 - val_accuracy: 0.9512 - val_loss: 0.1480
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.9756 - loss: 0.0605 - val_accuracy: 0.9596 - val_loss: 0.1376
#
# Dropout 0.2 | Fold 3
# Loss     : 0.1376
# Accuracy : 0.9596
# Model for Dropout 0.2 Fold 3 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_2_fold_3.keras
#
# ====== Dropout 0.2 | Fold 4 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.6539 - loss: 1.1674 - val_accuracy: 0.8454 - val_loss: 0.6271
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.8986 - loss: 0.4227 - val_accuracy: 0.9239 - val_loss: 0.2524
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.9512 - loss: 0.1606 - val_accuracy: 0.9536 - val_loss: 0.1391
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.9685 - loss: 0.0830 - val_accuracy: 0.9679 - val_loss: 0.1149
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.9780 - loss: 0.0538 - val_accuracy: 0.9655 - val_loss: 0.1058
#
# Dropout 0.2 | Fold 4
# Loss     : 0.1058
# Accuracy : 0.9655
# Model for Dropout 0.2 Fold 4 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_2_fold_4.keras
#
# ====== Dropout 0.2 | Fold 5 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.5779 - loss: 1.2011 - val_accuracy: 0.7917 - val_loss: 0.7244
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.8861 - loss: 0.4226 - val_accuracy: 0.9214 - val_loss: 0.2864
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.9548 - loss: 0.1547 - val_accuracy: 0.9619 - val_loss: 0.1616
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9729 - loss: 0.0772 - val_accuracy: 0.9607 - val_loss: 0.1382
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.9777 - loss: 0.0596 - val_accuracy: 0.9595 - val_loss: 0.1282
#
# Dropout 0.2 | Fold 5
# Loss     : 0.1282
# Accuracy : 0.9595
# Model for Dropout 0.2 Fold 5 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_2_fold_5.keras
#
# ============================================================
# HASIL AKHIR DROPOUT = 0.2
# ============================================================
# Average Accuracy : 0.9619
#
# ############################################################
# # TRAINING KLASIFIKASI ASPEK DENGAN DROPOUT = 0.5
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.5 | Fold 1 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 132ms/step - accuracy: 0.5204 - loss: 1.2923 - val_accuracy: 0.7895 - val_loss: 0.7971
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.8543 - loss: 0.5987 - val_accuracy: 0.8918 - val_loss: 0.4407
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.9072 - loss: 0.3367 - val_accuracy: 0.9180 - val_loss: 0.2658
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9453 - loss: 0.1883 - val_accuracy: 0.9477 - val_loss: 0.1764
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.9610 - loss: 0.1206 - val_accuracy: 0.9584 - val_loss: 0.1411
#
# Dropout 0.5 | Fold 1
# Loss     : 0.1411
# Accuracy : 0.9584
# Model for Dropout 0.5 Fold 1 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_5_fold_1.keras
#
# ====== Dropout 0.5 | Fold 2 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.5394 - loss: 1.2945 - val_accuracy: 0.7241 - val_loss: 0.7685
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.8353 - loss: 0.6188 - val_accuracy: 0.9013 - val_loss: 0.3552
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.9087 - loss: 0.2795 - val_accuracy: 0.9263 - val_loss: 0.2422
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9450 - loss: 0.1602 - val_accuracy: 0.9524 - val_loss: 0.1863
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.9649 - loss: 0.1030 - val_accuracy: 0.9548 - val_loss: 0.1600
#
# Dropout 0.5 | Fold 2
# Loss     : 0.1600
# Accuracy : 0.9548
# Model for Dropout 0.5 Fold 2 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_5_fold_2.keras
#
# ====== Dropout 0.5 | Fold 3 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 20s 129ms/step - accuracy: 0.4784 - loss: 1.3218 - val_accuracy: 0.7432 - val_loss: 0.9005
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.8347 - loss: 0.6176 - val_accuracy: 0.8942 - val_loss: 0.4240
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9105 - loss: 0.3123 - val_accuracy: 0.9168 - val_loss: 0.2485
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9468 - loss: 0.1626 - val_accuracy: 0.9382 - val_loss: 0.1760
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - accuracy: 0.9646 - loss: 0.1043 - val_accuracy: 0.9489 - val_loss: 0.1558
#
# Dropout 0.5 | Fold 3
# Loss     : 0.1558
# Accuracy : 0.9489
# Model for Dropout 0.5 Fold 3 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_5_fold_3.keras
#
# ====== Dropout 0.5 | Fold 4 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 130ms/step - accuracy: 0.4588 - loss: 1.3306 - val_accuracy: 0.7194 - val_loss: 0.9259
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - accuracy: 0.8052 - loss: 0.6884 - val_accuracy: 0.8954 - val_loss: 0.4010
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.9060 - loss: 0.3450 - val_accuracy: 0.9144 - val_loss: 0.2540
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9185 - loss: 0.2205 - val_accuracy: 0.9227 - val_loss: 0.1914
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.9408 - loss: 0.1524 - val_accuracy: 0.9560 - val_loss: 0.1503
#
# Dropout 0.5 | Fold 4
# Loss     : 0.1503
# Accuracy : 0.9560
# Model for Dropout 0.5 Fold 4 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_5_fold_4.keras
#
# ====== Dropout 0.5 | Fold 5 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.4596 - loss: 1.3624 - val_accuracy: 0.7131 - val_loss: 0.9976
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.8133 - loss: 0.6618 - val_accuracy: 0.8833 - val_loss: 0.4385
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.9117 - loss: 0.2973 - val_accuracy: 0.9083 - val_loss: 0.2757
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9293 - loss: 0.1896 - val_accuracy: 0.9286 - val_loss: 0.2166
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.9530 - loss: 0.1303 - val_accuracy: 0.9476 - val_loss: 0.1758
#
# Dropout 0.5 | Fold 5
# Loss     : 0.1758
# Accuracy : 0.9476
# Model for Dropout 0.5 Fold 5 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_5_fold_5.keras
#
# ============================================================
# HASIL AKHIR DROPOUT = 0.5
# ============================================================
# Average Accuracy : 0.9531
#
# ############################################################
# # TRAINING KLASIFIKASI ASPEK DENGAN DROPOUT = 0.8
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.8 | Fold 1 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.3764 - loss: 1.4709 - val_accuracy: 0.6326 - val_loss: 1.2668
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.4680 - loss: 1.2108 - val_accuracy: 0.7051 - val_loss: 0.9627
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.7217 - loss: 0.8710 - val_accuracy: 0.8264 - val_loss: 0.6870
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.8153 - loss: 0.6664 - val_accuracy: 0.8811 - val_loss: 0.5129
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.8573 - loss: 0.5274 - val_accuracy: 0.8930 - val_loss: 0.3861
#
# Dropout 0.8 | Fold 1
# Loss     : 0.3861
# Accuracy : 0.8930
# Model for Dropout 0.8 Fold 1 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_8_fold_1.keras
#
# ====== Dropout 0.8 | Fold 2 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 132ms/step - accuracy: 0.4014 - loss: 1.4720 - val_accuracy: 0.4055 - val_loss: 1.2678
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.4267 - loss: 1.2538 - val_accuracy: 0.6849 - val_loss: 1.0440
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.6789 - loss: 0.9191 - val_accuracy: 0.8751 - val_loss: 0.5729
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.8213 - loss: 0.6336 - val_accuracy: 0.9001 - val_loss: 0.3970
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.8644 - loss: 0.4820 - val_accuracy: 0.9156 - val_loss: 0.3072
#
# Dropout 0.8 | Fold 2
# Loss     : 0.3072
# Accuracy : 0.9156
# Model for Dropout 0.8 Fold 2 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 20s 127ms/step - accuracy: 0.3973 - loss: 1.5028 - val_accuracy: 0.3591 - val_loss: 1.3386
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - accuracy: 0.4321 - loss: 1.2718 - val_accuracy: 0.6932 - val_loss: 1.1716
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.6744 - loss: 0.9481 - val_accuracy: 0.8169 - val_loss: 0.6743
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - accuracy: 0.8243 - loss: 0.6279 - val_accuracy: 0.8823 - val_loss: 0.4358
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - accuracy: 0.8760 - loss: 0.4568 - val_accuracy: 0.8989 - val_loss: 0.3396
#
# Dropout 0.8 | Fold 3
# Loss     : 0.3396
# Accuracy : 0.8989
# Model for Dropout 0.8 Fold 3 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_8_fold_3.keras
#
# ====== Dropout 0.8 | Fold 4 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 21s 131ms/step - accuracy: 0.3886 - loss: 1.4769 - val_accuracy: 0.4162 - val_loss: 1.2720
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - accuracy: 0.4020 - loss: 1.2760 - val_accuracy: 0.6147 - val_loss: 1.1276
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.6476 - loss: 0.9595 - val_accuracy: 0.7919 - val_loss: 0.6703
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 124ms/step - accuracy: 0.7921 - loss: 0.7119 - val_accuracy: 0.8847 - val_loss: 0.4645
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.8448 - loss: 0.5564 - val_accuracy: 0.9073 - val_loss: 0.3368
#
# Dropout 0.8 | Fold 4
# Loss     : 0.3368
# Accuracy : 0.9073
# Model for Dropout 0.8 Fold 4 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_8_fold_4.keras
#
# ====== Dropout 0.8 | Fold 5 ======
# Epoch 1/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 20s 129ms/step - accuracy: 0.3856 - loss: 1.4974 - val_accuracy: 0.4143 - val_loss: 1.2999
# Epoch 2/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - accuracy: 0.4646 - loss: 1.2389 - val_accuracy: 0.7238 - val_loss: 1.0184
# Epoch 3/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - accuracy: 0.7027 - loss: 0.8971 - val_accuracy: 0.8024 - val_loss: 0.7060
# Epoch 4/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 121ms/step - accuracy: 0.8139 - loss: 0.6442 - val_accuracy: 0.8810 - val_loss: 0.4718
# Epoch 5/5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 13s 122ms/step - accuracy: 0.8769 - loss: 0.4512 - val_accuracy: 0.9024 - val_loss: 0.3609
#
# Dropout 0.8 | Fold 5
# Loss     : 0.3609
# Accuracy : 0.9024
# Model for Dropout 0.8 Fold 5 saved to: /kaggle/working/EPOCH_05/aspect_classification_models/aspect_model_dropout_0_8_fold_5.keras
#
# ============================================================
# HASIL AKHIR DROPOUT = 0.8
# ============================================================
# Average Accuracy : 0.9034
#
# ############################################################
# # RINGKASAN PERBANDINGAN DROPOUT (Klasifikasi Aspek)
# ############################################################
# Dropout 0.2: rata-rata accuracy (K-Fold) = 0.9619
# Dropout 0.5: rata-rata accuracy (K-Fold) = 0.9531
# Dropout 0.8: rata-rata accuracy (K-Fold) = 0.9034

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix
)

import numpy as np
import pandas as pd
import os
import re
import ast

# =========================
# FUNCTION
# =========================

def ensure_list(x):

    if isinstance(x, list):
        return x

    if isinstance(x, str):

        try:
            val = ast.literal_eval(x)

            if isinstance(val, list):
                return val

        except:
            return x.split()

    return []

# =========================
# PREPARE TEST DATA
# =========================

tokens = X_test_full['Tokenized_Opinion'].apply(ensure_list)

X_test_texts = tokens.apply(lambda x: ' '.join(x)).fillna("")

print("Contoh teks:")
print(X_test_texts.iloc[0])

X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

X_test_pad_final = pad_sequences(
    X_test_seq,
    maxlen=max_len,
    padding='post',
    truncating='post'
)

y_true = np.array(Y_test_aspect)

print("\nShape X_test:", X_test_pad_final.shape)
print("Shape y_test:", y_true.shape)

# =========================
# LOAD MODEL FILES
# =========================

model_save_dir = os.path.join(
    BASE_DRIVE_PATH,
    'aspect_classification_models'
)

model_files = [
    f for f in os.listdir(model_save_dir)
    if f.endswith('.keras')
    and f.startswith('aspect_model_dropout_')
]

def parse_dropout_fold(filename):
    """Ambil nilai dropout & nomor fold dari nama file aspect_model_dropout_<d>_fold_<n>.keras"""
    match = re.search(r'dropout_([0-9_]+)_fold_(\d+)\.keras', filename)
    if match:
        dropout_value = float(match.group(1).replace('_', '.'))
        fold_number = int(match.group(2))
        return dropout_value, fold_number
    return None, -1

model_files = sorted(
    model_files,
    key=lambda f: parse_dropout_fold(f)
)

results = []
# Prediksi dikelompokkan per nilai dropout supaya bisa dibuat ensemble per dropout
preds_by_dropout = {}

if not model_files:

    print(
        f"\nTidak ada model ditemukan di {model_save_dir}"
    )

else:

    print("\nModel ditemukan:")
    for file in model_files:
        print("-", file)

    for file_name in model_files:

        full_file_path = os.path.join(
            model_save_dir,
            file_name
        )

        dropout_value, fold_number = parse_dropout_fold(file_name)

        print("\n" + "="*60)
        print(
            f"EVALUASI MODEL | Dropout {dropout_value} | Fold {fold_number}"
        )
        print("="*60)

        model = load_model(full_file_path)

        y_pred_prob = model.predict(
            X_test_pad_final,
            verbose=0
        )

        preds_by_dropout.setdefault(dropout_value, []).append(y_pred_prob)

        y_pred = np.argmax(
            y_pred_prob,
            axis=1
        )

        print("\nDistribusi Prediksi:")
        print(np.bincount(y_pred))

        # =========================
        # METRICS
        # =========================

        acc = accuracy_score(
            y_true,
            y_pred
        )

        precision = precision_score(
            y_true,
            y_pred,
            average='weighted',
            zero_division=0
        )

        recall = recall_score(
            y_true,
            y_pred,
            average='weighted',
            zero_division=0
        )

        f1 = f1_score(
            y_true,
            y_pred,
            average='weighted',
            zero_division=0
        )

        print(f"\nAccuracy      : {acc:.4f}")
        print(f"Precision     : {precision:.4f}")
        print(f"Recall        : {recall:.4f}")
        print(f"F1-Score      : {f1:.4f}")

        results.append({
            "model_name": file_name,
            "dropout": dropout_value,
            "fold": fold_number,
            "accuracy": acc,
            "precision": precision,
            "recall": recall,
            "f1_score": f1
        })

# =========================
# HASIL SEMUA MODEL (per fold, semua dropout)
# =========================

df_results = pd.DataFrame(results)

if not df_results.empty:

    df_results = df_results.sort_values(
        by='accuracy',
        ascending=False
    )

    print("\n" + "="*60)
    print("PERBANDINGAN HASIL MODEL (semua dropout & fold)")
    print("="*60)

    display(df_results)

    # =========================
    # RINGKASAN RATA-RATA PER NILAI DROPOUT
    # =========================
    print("\n" + "="*60)
    print("RATA-RATA AKURASI PER NILAI DROPOUT")
    print("="*60)

    df_dropout_summary = (
        df_results
        .groupby('dropout')[['accuracy', 'precision', 'recall', 'f1_score']]
        .mean()
        .sort_values(by='accuracy', ascending=False)
    )
    display(df_dropout_summary)

# =========================
# ENSEMBLE PER NILAI DROPOUT (soft voting antar fold, per dropout)
# =========================

ensemble_summary = []

for dropout_value, prob_list in preds_by_dropout.items():

    avg_y_pred_prob = np.mean(prob_list, axis=0)
    y_pred_ensemble = np.argmax(avg_y_pred_prob, axis=1)

    ensemble_accuracy = accuracy_score(y_true, y_pred_ensemble)
    ensemble_precision = precision_score(y_true, y_pred_ensemble, average='weighted', zero_division=0)
    ensemble_recall = recall_score(y_true, y_pred_ensemble, average='weighted', zero_division=0)
    ensemble_f1 = f1_score(y_true, y_pred_ensemble, average='weighted', zero_division=0)

    ensemble_summary.append({
        'dropout': dropout_value,
        'ensemble_accuracy': ensemble_accuracy,
        'ensemble_precision': ensemble_precision,
        'ensemble_recall': ensemble_recall,
        'ensemble_f1': ensemble_f1
    })

    print("\n" + "="*60)
    print(f"EVALUASI ENSEMBLE (soft voting 5-fold) | Dropout = {dropout_value}")
    print("="*60)

    print(f"Accuracy      : {ensemble_accuracy:.4f}")
    print(f"Precision     : {ensemble_precision:.4f}")
    print(f"Recall        : {ensemble_recall:.4f}")
    print(f"F1-Score      : {ensemble_f1:.4f}")

    print("\nClassification Report:")
    if 'aspect_le' in globals():
        target_names_str = [str(cls) for cls in aspect_le.classes_]
        print(classification_report(y_true, y_pred_ensemble, target_names=target_names_str, zero_division=0))
    else:
        print(classification_report(y_true, y_pred_ensemble, zero_division=0))

    print("\nConfusion Matrix:")
    print(confusion_matrix(y_true, y_pred_ensemble))

if ensemble_summary:
    print("\n" + "#"*60)
    print("# RINGKASAN ENSEMBLE PER DROPOUT (Klasifikasi Aspek)")
    print("#"*60)
    df_ensemble_summary = pd.DataFrame(ensemble_summary).sort_values(by='ensemble_accuracy', ascending=False)
    display(df_ensemble_summary)
# Out:
# Contoh teks:
# instruksi jelas
#
# Shape X_test: (1051, 20)
# Shape y_test: (1051,)
#
# Model ditemukan:
# - aspect_model_dropout_0_2_fold_1.keras
# - aspect_model_dropout_0_2_fold_2.keras
# - aspect_model_dropout_0_2_fold_3.keras
# - aspect_model_dropout_0_2_fold_4.keras
# - aspect_model_dropout_0_2_fold_5.keras
# - aspect_model_dropout_0_5_fold_1.keras
# - aspect_model_dropout_0_5_fold_2.keras
# - aspect_model_dropout_0_5_fold_3.keras
# - aspect_model_dropout_0_5_fold_4.keras
# - aspect_model_dropout_0_5_fold_5.keras
# - aspect_model_dropout_0_8_fold_1.keras
# - aspect_model_dropout_0_8_fold_2.keras
# - aspect_model_dropout_0_8_fold_3.keras
# - aspect_model_dropout_0_8_fold_4.keras
# - aspect_model_dropout_0_8_fold_5.keras
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 1
# ============================================================
#
# Distribusi Prediksi:
# [  0 189 382 417  63]
#
# Accuracy      : 0.9534
# Precision     : 0.9408
# Recall        : 0.9534
# F1-Score      : 0.9466
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 2
# ============================================================
#
# Distribusi Prediksi:
# [  6 175 386 425  59]
#
# Accuracy      : 0.9591
# Precision     : 0.9577
# Recall        : 0.9591
# F1-Score      : 0.9565
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 3
# ============================================================
#
# Distribusi Prediksi:
# [  0 184 380 424  63]
#
# Accuracy      : 0.9629
# Precision     : 0.9497
# Recall        : 0.9629
# F1-Score      : 0.9559
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 4
# ============================================================
#
# Distribusi Prediksi:
# [ 10 185 389 419  48]
#
# Accuracy      : 0.9667
# Precision     : 0.9653
# Recall        : 0.9667
# F1-Score      : 0.9651
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 5
# ============================================================
#
# Distribusi Prediksi:
# [  0 182 375 424  70]
#
# Accuracy      : 0.9572
# Precision     : 0.9467
# Recall        : 0.9572
# F1-Score      : 0.9511
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 1
# ============================================================
#
# Distribusi Prediksi:
# [  0 181 378 436  56]
#
# Accuracy      : 0.9524
# Precision     : 0.9379
# Recall        : 0.9524
# F1-Score      : 0.9451
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 2
# ============================================================
#
# Distribusi Prediksi:
# [  0 174 381 431  65]
#
# Accuracy      : 0.9543
# Precision     : 0.9429
# Recall        : 0.9543
# F1-Score      : 0.9481
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 3
# ============================================================
#
# Distribusi Prediksi:
# [  0 178 381 429  63]
#
# Accuracy      : 0.9591
# Precision     : 0.9464
# Recall        : 0.9591
# F1-Score      : 0.9524
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 4
# ============================================================
#
# Distribusi Prediksi:
# [  0 191 383 426  51]
#
# Accuracy      : 0.9486
# Precision     : 0.9332
# Recall        : 0.9486
# F1-Score      : 0.9408
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 5
# ============================================================
#
# Distribusi Prediksi:
# [  0 180 380 426  65]
#
# Accuracy      : 0.9458
# Precision     : 0.9351
# Recall        : 0.9458
# F1-Score      : 0.9401
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 1
# ============================================================
#
# Distribusi Prediksi:
# [  0 210 372 469]
#
# Accuracy      : 0.8934
# Precision     : 0.8383
# Recall        : 0.8934
# F1-Score      : 0.8641
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 2
# ============================================================
#
# Distribusi Prediksi:
# [  0 208 384 459]
#
# Accuracy      : 0.9039
# Precision     : 0.8467
# Recall        : 0.9039
# F1-Score      : 0.8739
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 3
# ============================================================
#
# Distribusi Prediksi:
# [  0 203 394 454]
#
# Accuracy      : 0.9039
# Precision     : 0.8457
# Recall        : 0.9039
# F1-Score      : 0.8737
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 4
# ============================================================
#
# Distribusi Prediksi:
# [  0 202 386 463]
#
# Accuracy      : 0.9020
# Precision     : 0.8441
# Recall        : 0.9020
# F1-Score      : 0.8718
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 5
# ============================================================
#
# Distribusi Prediksi:
# [  0 203 387 461]
#
# Accuracy      : 0.8991
# Precision     : 0.8415
# Recall        : 0.8991
# F1-Score      : 0.8691
#
# ============================================================
# PERBANDINGAN HASIL MODEL (semua dropout & fold)
# ============================================================
#                                model_name  dropout  fold  accuracy  precision  \
# 3   aspect_model_dropout_0_2_fold_4.keras      0.2     4  0.966698   0.965333
# 2   aspect_model_dropout_0_2_fold_3.keras      0.2     3  0.962892   0.949742
# 1   aspect_model_dropout_0_2_fold_2.keras      0.2     2  0.959087   0.957726
# 7   aspect_model_dropout_0_5_fold_3.keras      0.5     3  0.959087   0.946420
# 4   aspect_model_dropout_0_2_fold_5.keras      0.2     5  0.957184   0.946673
# 6   aspect_model_dropout_0_5_fold_2.keras      0.5     2  0.954329   0.942853
# 0   aspect_model_dropout_0_2_fold_1.keras      0.2     1  0.953378   0.940826
# 5   aspect_model_dropout_0_5_fold_1.keras      0.5     1  0.952426   0.937932
# 8   aspect_model_dropout_0_5_fold_4.keras      0.5     4  0.948620   0.933225
# 9   aspect_model_dropout_0_5_fold_5.keras      0.5     5  0.945766   0.935119
# 11  aspect_model_dropout_0_8_fold_2.keras      0.8     2  0.903901   0.846664
# 12  aspect_model_dropout_0_8_fold_3.keras      0.8     3  0.903901   0.845701
# 13  aspect_model_dropout_0_8_fold_4.keras      0.8     4  0.901998   0.844096
# 14  aspect_model_dropout_0_8_fold_5.keras      0.8     5  0.899144   0.841467
# 10  aspect_model_dropout_0_8_fold_1.keras      0.8     1  0.893435   0.838308
#
#       recall  f1_score
# 3   0.966698  0.965140
# 2   0.962892  0.955935
# 1   0.959087  0.956496
# 7   0.959087  0.952384
# 4   0.957184  0.951076
# 6   0.954329  0.948068
# 0   0.953378  0.946626
# 5   0.952426  0.945055
# 8   0.948620  0.940781
# 9   0.945766  0.940053
# 11  0.903901  0.873941
# 12  0.903901  0.873706
# 13  0.901998  0.871817
# 14  0.899144  0.869100
# 10  0.893435  0.864101
# ============================================================
# RATA-RATA AKURASI PER NILAI DROPOUT
# ============================================================
#          accuracy  precision    recall  f1_score
# dropout
# 0.2      0.959848   0.952060  0.959848  0.955054
# 0.5      0.952046   0.939110  0.952046  0.945268
# 0.8      0.900476   0.843247  0.900476  0.870533
# ============================================================
# EVALUASI ENSEMBLE (soft voting 5-fold) | Dropout = 0.2
# ============================================================
# Accuracy      : 0.9676
# Precision     : 0.9713
# Recall        : 0.9676
# F1-Score      : 0.9622
#
# Classification Report:
#                                    precision    recall  f1-score   support
#
#                     biaya layanan       1.00      0.06      0.11        17
#       fasilitas dan infrastruktur       0.97      0.96      0.96       181
# kualitas pelayanan medis dan staf       0.98      0.99      0.99       377
#                           lainnya       0.99      1.00      0.99       424
#                      waktu tunggu       0.71      0.88      0.79        52
#
#                          accuracy                           0.97      1051
#                         macro avg       0.93      0.78      0.77      1051
#                      weighted avg       0.97      0.97      0.96      1051
#
#
# Confusion Matrix:
# [[  1   0   0   0  16]
#  [  0 173   3   2   3]
#  [  0   0 375   2   0]
#  [  0   1   1 422   0]
#  [  0   4   2   0  46]]
#
# ============================================================
# EVALUASI ENSEMBLE (soft voting 5-fold) | Dropout = 0.5
# ============================================================
# Accuracy      : 0.9572
# Precision     : 0.9430
# Recall        : 0.9572
# F1-Score      : 0.9500
#
# Classification Report:
#                                    precision    recall  f1-score   support
#
#                     biaya layanan       0.00      0.00      0.00        17
#       fasilitas dan infrastruktur       0.95      0.95      0.95       181
# kualitas pelayanan medis dan staf       0.98      0.99      0.99       377
#                           lainnya       0.99      1.00      0.99       424
#                      waktu tunggu       0.63      0.69      0.66        52
#
#                          accuracy                           0.96      1051
#                         macro avg       0.71      0.73      0.72      1051
#                      weighted avg       0.94      0.96      0.95      1051
#
#
# Confusion Matrix:
# [[  0   0   1   0  16]
#  [  0 172   3   1   5]
#  [  0   0 374   3   0]
#  [  0   0   0 424   0]
#  [  0  10   4   2  36]]
#
# ============================================================
# EVALUASI ENSEMBLE (soft voting 5-fold) | Dropout = 0.8
# ============================================================
# Accuracy      : 0.9029
# Precision     : 0.8451
# Recall        : 0.9029
# F1-Score      : 0.8728
#
# Classification Report:
#                                    precision    recall  f1-score   support
#
#                     biaya layanan       0.00      0.00      0.00        17
#       fasilitas dan infrastruktur       0.79      0.90      0.84       181
# kualitas pelayanan medis dan staf       0.94      0.97      0.95       377
#                           lainnya       0.92      1.00      0.96       424
#                      waktu tunggu       0.00      0.00      0.00        52
#
#                          accuracy                           0.90      1051
#                         macro avg       0.53      0.57      0.55      1051
#                      weighted avg       0.85      0.90      0.87      1051
#
#
# Confusion Matrix:
# [[  0  12   1   4   0]
#  [  0 162  12   7   0]
#  [  0   0 364  13   0]
#  [  0   0   1 423   0]
#  [  0  30  10  12   0]]
#
# ############################################################
# # RINGKASAN ENSEMBLE PER DROPOUT (Klasifikasi Aspek)
# ############################################################
#    dropout  ensemble_accuracy  ensemble_precision  ensemble_recall  \
# 0      0.2           0.967650            0.971263         0.967650
# 1      0.5           0.957184            0.942993         0.957184
# 2      0.8           0.902950            0.845063         0.902950
#
#    ensemble_f1
# 0     0.962180
# 1     0.949983
# 2     0.872808

# %%
import os
from tensorflow.keras.models import load_model

# Ensure df_results exists and is not empty
if 'df_results' in globals() and not df_results.empty:
    # Get the name of the best model (highest accuracy, across ALL dropout & fold combinations)
    best_row = df_results.iloc[0]
    best_model_name = best_row['model_name']

    # Construct the full path to the best model
    # model_save_dir is already defined in the evaluation cell above
    source_best_model_path = os.path.join(model_save_dir, best_model_name)

    # Define the directory to save the best model
    best_models_dir = os.path.join(BASE_DRIVE_PATH, 'best_models')
    os.makedirs(best_models_dir, exist_ok=True)

    # Define the destination path for the best model with the new requested name
    destination_best_model_path = os.path.join(best_models_dir, 'best_model_aspek.keras')

    try:
        # Load the best model
        best_model = load_model(source_best_model_path)

        # Save the best model to the new location
        best_model.save(destination_best_model_path)

        print(
            f"✅ Best aspect classification model '{best_model_name}' "
            f"(Dropout: {best_row.get('dropout', 'N/A')}, Fold: {best_row.get('fold', 'N/A')}, "
            f"Accuracy: {best_row['accuracy']:.4f}) saved successfully to: {destination_best_model_path}"
        )
    except Exception as e:
        print(f"❌ Error saving the best aspect classification model: {e}")
else:
    print("❌ No model results found to determine the best model. Please ensure the evaluation cell ran successfully.")
# Out:
# ✅ Best aspect classification model 'aspect_model_dropout_0_2_fold_4.keras' (Dropout: 0.2, Fold: 4, Accuracy: 0.9667) saved successfully to: /kaggle/working/EPOCH_05/best_models/best_model_aspek.keras

# %% [markdown]
# #KLASIFIKASI SENTIMEN PER ASPEK

# %%
import pandas as pd
from IPython.display import display

if 'df_aspect_labeling' not in locals():
    # Use the already loaded df_loaded DataFrame
    if 'df_loaded' in globals():
        df_aspect_labeling = df_loaded.copy()
        print("Assigned df_loaded to df_aspect_labeling.")
    else:
        print("Error: df_loaded not found. Please ensure 'dataset_hasil_labelling_aspek.xlsx' was loaded successfully in a previous cell.")
        # Fallback to attempt loading if df_loaded is unexpectedly missing
        try:
            # Assuming PREPROCESSED_DATA_DIR is defined
            if 'PREPROCESSED_DATA_DIR' in globals():
                file_path = find_input_file('dataset_hasil_labelling_aspek.xlsx', base_dir=PREPROCESSED_DATA_DIR)
                df_aspect_labeling = pd.read_excel(file_path)
                print(f"Loaded df_aspect_labeling from '{file_path}' as fallback.")
            else:
                print("Error: PREPROCESSED_DATA_DIR not defined for fallback loading.")
                df_aspect_labeling = pd.DataFrame() # Initialize empty
        except FileNotFoundError:
            print("Error: 'dataset_hasil_labelling_aspek.xlsx' not found. Please ensure previous steps ran successfully.")
            df_aspect_labeling = pd.DataFrame() # Initialize empty

# Membuat dictionary untuk menyimpan DataFrame per aspek
data_per_aspek = {}

# Ensure df_aspect_labeling is not empty before proceeding
if not df_aspect_labeling.empty:
    unique_aspects = df_aspect_labeling['Aspek'].unique()

    print("Memisahkan data berdasarkan aspek...")
    for aspek in unique_aspects:
        data_per_aspek[aspek] = df_aspect_labeling[df_aspect_labeling['Aspek'] == aspek].copy()
        print(f"- Aspek '{aspek}': {len(data_per_aspek[aspek])} baris")

    print("Data berhasil dipisahkan per aspek.")

    # Contoh menampilkan data untuk aspek 'kualitas pelayanan medis dan staf'
    if 'kualitas pelayanan medis dan staf' in data_per_aspek:
        print("\nContoh data untuk aspek 'kualitas pelayanan medis dan staf':")
        display(data_per_aspek['kualitas pelayanan medis dan staf'].head())
    else:
        print("Aspek 'kualitas pelayanan medis dan staf' tidak ditemukan dalam data.")
else:
    print("df_aspect_labeling is empty, skipping aspect separation.")
# Out:
# Assigned df_loaded to df_aspect_labeling.
# Memisahkan data berdasarkan aspek...
# - Aspek 'fasilitas dan infrastruktur': 903 baris
# - Aspek 'kualitas pelayanan medis dan staf': 1886 baris
# - Aspek 'lainnya': 2119 baris
# - Aspek 'waktu tunggu': 261 baris
# - Aspek 'biaya layanan': 86 baris
# Data berhasil dipisahkan per aspek.
#
# Contoh data untuk aspek 'kualitas pelayanan medis dan staf':
#    Original_Review_ID                                             Review  \
# 1                   1  Ruang flamboyan rumah sakit mitra keluarga dar...
# 3                   3                           Pelayanan baik memuaskan
# 4                   4  Dirawat inap di kamar Flamboyan, setelah opera...
# 7                   7  RS yang nyaman, pelayan oke. Suster lantai-lan...
# 8                   8  Pelayanan baik cepat tanggap luar biasa baik. ...
#
#   Extracted_Opinion Translated_Opinion Cleaned_Opinion Casefolded_Opinion  \
# 1     perawat ramah     friendly nurse   perawat ramah      perawat ramah
# 3    Pelayanan baik       Good service  Pelayanan baik     pelayanan baik
# 4      tenaga medis  medical personnel    tenaga medis       tenaga medis
# 7    flamboyan baik    flamboyant good  flamboyan baik     flamboyan baik
# 8    Pelayanan baik       Good service  Pelayanan baik     pelayanan baik
#
#        Tokenized_Opinion Vader_Sentiment_Category  Sentiment_encoded  \
# 1   ['perawat', 'ramah']                 Positive                  2
# 3  ['pelayanan', 'baik']                 Positive                  2
# 4    ['tenaga', 'medis']                  Neutral                  1
# 7  ['flamboyan', 'baik']                 Positive                  2
# 8  ['pelayanan', 'baik']                 Positive                  2
#
#                                Aspek  Aspek_encoded
# 1  kualitas pelayanan medis dan staf              2
# 3  kualitas pelayanan medis dan staf              2
# 4  kualitas pelayanan medis dan staf              2
# 7  kualitas pelayanan medis dan staf              2
# 8  kualitas pelayanan medis dan staf              2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

if 'data_per_aspek' not in locals():
    try:
        if 'df_aspect_labeling' not in locals():
            # Use the already loaded df_loaded DataFrame
            if 'df_loaded' in globals():
                df_aspect_labeling = df_loaded.copy()
                print("Assigned df_loaded to df_aspect_labeling.")
            else:
                print("Error: df_loaded not found. Please ensure 'dataset_hasil_labelling_aspek.xlsx' was loaded successfully in a previous cell.")
                # Fallback to attempt loading if df_loaded is unexpectedly missing
                if 'PREPROCESSED_DATA_DIR' in globals():
                    file_path = find_input_file('dataset_hasil_labelling_aspek.xlsx', base_dir=PREPROCESSED_DATA_DIR)
                    df_aspect_labeling = pd.read_excel(file_path)
                    print(f"Loaded df_aspect_labeling from '{file_path}' as fallback.")
                else:
                    print("Error: PREPROCESSED_DATA_DIR not defined for fallback loading.")
                    df_aspect_labeling = pd.DataFrame() # Initialize empty

        if not df_aspect_labeling.empty:
            data_per_aspek = {}
            unique_aspects = df_aspect_labeling['Aspek'].unique()
            for aspek in unique_aspects:
                data_per_aspek[aspek] = df_aspect_labeling[df_aspect_labeling['Aspek'] == aspek].copy()
            print("Re-created data_per_aspek dictionary.")
        else:
            print("df_aspect_labeling is empty, cannot re-create data_per_aspek.")

    except FileNotFoundError:
        print("Error: 'dataset_hasil_labelling_aspek.xlsx' not found.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# 1. Initialize an empty dictionary to store split data
split_data_per_aspek = {}

print("Performing train-test split for each aspect...")

# 2. Iterate through each aspect and its corresponding DataFrame
if 'data_per_aspek' in locals() and data_per_aspek:
    for aspek_name, df_aspek in data_per_aspek.items():
        if len(df_aspek) == 0:
            print(f"Skipping empty aspect: {aspek_name}")
            continue

        # 3a. Define features (X) and target (Y)
        X = df_aspek['Tokenized_Opinion'] # Corrected column name
        Y = df_aspek['Sentiment_encoded']

        # Use KFold-like split, no stratification as requested
        # Check if there's enough data for splitting
        if len(df_aspek) > 1:
            X_train_aspect, X_test_aspect, Y_train_sentiment, Y_test_sentiment = train_test_split(
                X,
                Y,
                test_size=0.2,
                random_state=42
            )
            print(f"- Aspect '{aspek_name}': Data split. Train samples: {len(X_train_aspect)}, Test samples: {len(X_test_aspect)}")
        else:
            print(f"- Aspect '{aspek_name}': Skipping split due to insufficient data (only 1 sample).")
            continue

        split_data_per_aspek[aspek_name] = {
            'X_train': X_train_aspect,
            'X_test': X_test_aspect,
            'Y_train': Y_train_sentiment,
            'Y_test': Y_test_sentiment
        }

    print("Data splitting per aspect complete.")

    print("\nVerification of split data shapes (all aspects with splits):")
    for aspek_name, data in split_data_per_aspek.items():
        if 'X_train' in data and 'X_test' in data:
            print(f"\nAspect: {aspek_name}")
            print(f"  X_train shape: {data['X_train'].shape}")
            print(f"  X_test shape: {data['X_test'].shape}")
            print(f"  Y_train shape: {data['Y_train'].shape}")
            print(f"  Y_test shape: {data['Y_test'].shape}")
else:
    print("data_per_aspek is empty or not defined, skipping data splitting.")
# Out:
# Performing train-test split for each aspect...
# - Aspect 'fasilitas dan infrastruktur': Data split. Train samples: 722, Test samples: 181
# - Aspect 'kualitas pelayanan medis dan staf': Data split. Train samples: 1508, Test samples: 378
# - Aspect 'lainnya': Data split. Train samples: 1695, Test samples: 424
# - Aspect 'waktu tunggu': Data split. Train samples: 208, Test samples: 53
# - Aspect 'biaya layanan': Data split. Train samples: 68, Test samples: 18
# Data splitting per aspect complete.
#
# Verification of split data shapes (all aspects with splits):
#
# Aspect: fasilitas dan infrastruktur
#   X_train shape: (722,)
#   X_test shape: (181,)
#   Y_train shape: (722,)
#   Y_test shape: (181,)
#
# Aspect: kualitas pelayanan medis dan staf
#   X_train shape: (1508,)
#   X_test shape: (378,)
#   Y_train shape: (1508,)
#   Y_test shape: (378,)
#
# Aspect: lainnya
#   X_train shape: (1695,)
#   X_test shape: (424,)
#   Y_train shape: (1695,)
#   Y_test shape: (424,)
#
# Aspect: waktu tunggu
#   X_train shape: (208,)
#   X_test shape: (53,)
#   Y_train shape: (208,)
#   Y_test shape: (53,)
#
# Aspect: biaya layanan
#   X_train shape: (68,)
#   X_test shape: (18,)
#   Y_train shape: (68,)
#   Y_test shape: (18,)

# %%
import pickle
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
import ast
import pandas as pd # Ensure pandas is imported

# Use SAVE_ROOT_PATH which correctly points to WORK_DIR/EPOCH 05 (folder kerja Kaggle)
# for constructing the path to the experiment_states directory.
# BASE_DRIVE_PATH currently holds a different WORK_DIR subfolder, which is not correct here.
with open(os.path.join(SAVE_ROOT_PATH, 'experiment_states', 'tokenizer_lstm.pkl'), "rb") as f:
    tokenizer = pickle.load(f)
print("Tokenizer loaded successfully.")

maxlen = 20 # Standardized maxlen
print("Sequences dan padding untuk tiap aspek")
for aspek_name, data in split_data_per_aspek.items():
    print(f"Processing aspek: {aspek_name}")

    def prepare_for_tokenizer(series):
        processed_texts = []
        for item in series:
            if isinstance(item, str):
                try:
                    item = ast.literal_eval(item)
                except (ValueError, SyntaxError):
                    item = []
            if isinstance(item, list) and item:
                processed_texts.append(' '.join(item))
            else:
                processed_texts.append('')
        return pd.Series(processed_texts, index=series.index)

    X_train_texts = prepare_for_tokenizer(data['X_train'])
    X_test_texts = prepare_for_tokenizer(data['X_test'])

    X_train_seq = tokenizer.texts_to_sequences(X_train_texts)
    X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

    # Pad sequences
    X_train_padded = pad_sequences(X_train_seq, maxlen=maxlen, padding='post', truncating='post')
    X_test_padded = pad_sequences(X_test_seq, maxlen=maxlen, padding='post', truncating='post')

    data['X_train_padded'] = X_train_padded
    data['X_test_padded'] = X_test_padded

print("Tokenization and padding complete for all aspek.")

print("Verification of padded data shapes (all aspek):")
for aspek_name, data in split_data_per_aspek.items():
    if 'X_train_padded' in data and 'X_test_padded' in data:
        print(f"aspek: {aspek_name}")
        print(f"  X_train_padded shape: {data['X_train_padded'].shape}")
        print(f"  X_test_padded shape: {data['X_test_padded'].shape}")
# Out:
# Tokenizer loaded successfully.
# Sequences dan padding untuk tiap aspek
# Processing aspek: fasilitas dan infrastruktur
# Processing aspek: kualitas pelayanan medis dan staf
# Processing aspek: lainnya
# Processing aspek: waktu tunggu
# Processing aspek: biaya layanan
# Tokenization and padding complete for all aspek.
# Verification of padded data shapes (all aspek):
# aspek: fasilitas dan infrastruktur
#   X_train_padded shape: (722, 20)
#   X_test_padded shape: (181, 20)
# aspek: kualitas pelayanan medis dan staf
#   X_train_padded shape: (1508, 20)
#   X_test_padded shape: (378, 20)
# aspek: lainnya
#   X_train_padded shape: (1695, 20)
#   X_test_padded shape: (424, 20)
# aspek: waktu tunggu
#   X_train_padded shape: (208, 20)
#   X_test_padded shape: (53, 20)
# aspek: biaya layanan
#   X_train_padded shape: (68, 20)
#   X_test_padded shape: (18, 20)

# %%
import pickle
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
import ast
import pandas as pd # Ensure pandas is imported

# Use SAVE_ROOT_PATH which correctly points to WORK_DIR/EPOCH 05 (folder kerja Kaggle)
# for constructing the path to the experiment_states directory.
# BASE_DRIVE_PATH currently holds a different WORK_DIR subfolder, which is not correct here.
with open(os.path.join(SAVE_ROOT_PATH, 'experiment_states', 'tokenizer_lstm.pkl'), "rb") as f:
    tokenizer = pickle.load(f)
print("Tokenizer loaded successfully.")

maxlen = 20 # Standardized maxlen
print("Sequences dan padding untuk tiap aspek")
for aspek_name, data in split_data_per_aspek.items():
    print(f"Processing aspek: {aspek_name}")

    def prepare_for_tokenizer(series):
        processed_texts = []
        for item in series:
            if isinstance(item, str):
                try:
                    item = ast.literal_eval(item)
                except (ValueError, SyntaxError):
                    item = []
            if isinstance(item, list) and item:
                processed_texts.append(' '.join(item))
            else:
                processed_texts.append('')
        return pd.Series(processed_texts, index=series.index)

    X_train_texts = prepare_for_tokenizer(data['X_train'])
    X_test_texts = prepare_for_tokenizer(data['X_test'])

    X_train_seq = tokenizer.texts_to_sequences(X_train_texts)
    X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

    # Pad sequences
    X_train_padded = pad_sequences(X_train_seq, maxlen=maxlen, padding='post', truncating='post')
    X_test_padded = pad_sequences(X_test_seq, maxlen=maxlen, padding='post', truncating='post')

    data['X_train_padded'] = X_train_padded
    data['X_test_padded'] = X_test_padded

print("Tokenization and padding complete for all aspek.")

print("Verification of padded data shapes (all aspek):")
for aspek_name, data in split_data_per_aspek.items():
    if 'X_train_padded' in data and 'X_test_padded' in data:
        print(f"aspek: {aspek_name}")
        print(f"  X_train_padded shape: {data['X_train_padded'].shape}")
        print(f"  X_test_padded shape: {data['X_test_padded'].shape}")
# Out:
# Tokenizer loaded successfully.
# Sequences dan padding untuk tiap aspek
# Processing aspek: fasilitas dan infrastruktur
# Processing aspek: kualitas pelayanan medis dan staf
# Processing aspek: lainnya
# Processing aspek: waktu tunggu
# Processing aspek: biaya layanan
# Tokenization and padding complete for all aspek.
# Verification of padded data shapes (all aspek):
# aspek: fasilitas dan infrastruktur
#   X_train_padded shape: (722, 20)
#   X_test_padded shape: (181, 20)
# aspek: kualitas pelayanan medis dan staf
#   X_train_padded shape: (1508, 20)
#   X_test_padded shape: (378, 20)
# aspek: lainnya
#   X_train_padded shape: (1695, 20)
#   X_test_padded shape: (424, 20)
# aspek: waktu tunggu
#   X_train_padded shape: (208, 20)
#   X_test_padded shape: (53, 20)
# aspek: biaya layanan
#   X_train_padded shape: (68, 20)
#   X_test_padded shape: (18, 20)

# %%
import tensorflow as tf
import numpy as np
import random
import os

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import (
    Dropout,
    Dense,
    LSTM,
    Embedding
)
from tensorflow.keras.models import Sequential
# from tensorflow.keras.callbacks import EarlyStopping # Removed EarlyStopping

from sklearn.model_selection import KFold

# =========================
# RANDOM SEED
# =========================
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# =========================
# PARAMETER
# =========================
vocab_size = 5000
max_len = 20
EPOCHS = 5

# =========================
# PARAMETER UJI COBA DROPOUT
# =========================
if 'DROPOUT_VALUES' not in globals():
    DROPOUT_VALUES = [0.2, 0.5, 0.8]

print(f"Dropout yang akan diuji untuk sentimen per aspek: {DROPOUT_VALUES}")

# =========================
# LOOP TIAP ASPEK
# =========================
for aspek_name, data in split_data_per_aspek.items():

    print("="*70)
    print(f"TRAINING SENTIMEN UNTUK ASPEK: {aspek_name}")
    print("="*70)

    # =========================
    # DATA
    # =========================
    X_pad = data['X_train_padded']
    y = np.array(data['Y_train'])

    num_classes = len(np.unique(y))

    # =========================
    # FOLDER SAVE
    # =========================
    if 'BASE_DRIVE_PATH' not in globals():

        print("❌ BASE_DRIVE_PATH not found.")

        raise SystemExit(
            "Stopping execution: BASE_DRIVE_PATH is not defined."
        )

    save_dir_relative = (
        f"sentiment_models_per_aspect/epoch_{EPOCHS}"
    )

    save_dir_full_path = os.path.join(
        BASE_DRIVE_PATH,
        save_dir_relative
    )

    os.makedirs(
        save_dir_full_path,
        exist_ok=True
    )

    # =========================
    # LOOP TIAP NILAI DROPOUT
    # =========================
    for dropout_rate in DROPOUT_VALUES:

        dropout_tag = str(dropout_rate).replace('.', '_')

        print("\n" + "#"*60)
        print(f"# ASPEK '{aspek_name}' | DROPOUT = {dropout_rate}")
        print("#"*60)

        # =========================
        # KFOLD
        # =========================
        skf = KFold(
            n_splits=5,
            shuffle=True,
            random_state=SEED
        )

        print("="*60)
        print(f"TRAINING DENGAN MAX EPOCH = {EPOCHS}")
        print("="*60)

        # best_val_loss = float('inf') # Removed as EarlyStopping is removed
        fold_no = 1

        fold_accuracies = []

        # =========================
        # KFOLD LOOP
        # =========================
        for train_idx, val_idx in skf.split(X_pad):

            print(f"\n====== Dropout {dropout_rate} | Fold {fold_no} ======")

            # =========================
            # SPLIT DATA
            # =========================
            X_tr = X_pad[train_idx]
            X_val = X_pad[val_idx]

            y_tr = y[train_idx]
            y_val = y[val_idx]

            # =========================
            # MODEL LSTM
            # =========================
            model = Sequential([

                Embedding(
                    input_dim=vocab_size,
                    output_dim=128,
                    mask_zero=True
                ),

                LSTM(
                    128,
                    return_sequences=True,
                    dropout=dropout_rate,
                    recurrent_dropout=dropout_rate
                ),

                LSTM(
                    64,
                    dropout=dropout_rate,
                    recurrent_dropout=dropout_rate
                ),

                Dense(
                    128,
                    activation='relu'
                ),

                Dropout(dropout_rate),

                Dense(
                    num_classes,
                    activation='softmax'
                )
            ])

            # =========================
            # COMPILE
            # =========================
            model.compile(
                optimizer=Adam(
                    learning_rate=0.0005
                ),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']
            )

            # =========================
            # EARLY STOPPING - REMOVED
            # =========================
            # early_stopping = EarlyStopping(
            #     monitor='val_loss',
            #     patience=2,
            #     restore_best_weights=True,
            #     verbose=1
            # )

            # =========================
            # TRAINING
            # =========================
            history = model.fit(
                X_tr,
                y_tr,
                epochs=EPOCHS,
                batch_size=32,
                validation_data=(X_val, y_val),
                # callbacks=[early_stopping], # Removed early_stopping from callbacks
                verbose=1
            )

            # =========================
            # EVALUASI
            # =========================
            scores = model.evaluate(
                X_val,
                y_val,
                verbose=0
            )

            print(f"\nDropout {dropout_rate} | Fold {fold_no}")
            print(f"Loss     : {scores[0]:.4f}")
            print(f"Accuracy : {scores[1]:.4f}")

            fold_accuracies.append(
                scores[1]
            )

            # =========================
            # SAVE MODEL FOR EACH FOLD
            # =========================
            # Nama file sekarang menyertakan nilai dropout supaya tiap konfigurasi
            # bisa dibandingkan pada cell evaluasi berikutnya.
            file_name = (
                f"sentiment_model_{aspek_name.replace(' ', '_').replace('/', '_').lower()}"
                f"_dropout_{dropout_tag}_fold_{fold_no}.keras"
            )

            model.save(
                os.path.join(
                    save_dir_full_path,
                    file_name
                )
            )

            print(
                f"Model for '{aspek_name}' Dropout {dropout_rate} Fold {fold_no} saved to:\n"
                f"{os.path.join(save_dir_full_path, file_name)}"
            )

            fold_no += 1

        # =========================
        # RATA-RATA KFOLD UNTUK DROPOUT INI
        # =========================
        avg_acc = np.mean(
            fold_accuracies
        )

        print("\n" + "="*60)
        print(f"RATA-RATA AKURASI ASPEK '{aspek_name}' | DROPOUT {dropout_rate}")
        print("="*60)

        print(
            f"Average Accuracy : "
            f"{avg_acc:.4f}"
        )
# Out:
# Dropout yang akan diuji untuk sentimen per aspek: [0.2, 0.5, 0.8]
# ======================================================================
# TRAINING SENTIMEN UNTUK ASPEK: fasilitas dan infrastruktur
# ======================================================================
#
# ############################################################
# # ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.2
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.2 | Fold 1 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - accuracy: 0.6863 - loss: 1.0642 - val_accuracy: 0.6621 - val_loss: 1.0011
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.6932 - loss: 0.8740 - val_accuracy: 0.6621 - val_loss: 0.8165
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6950 - loss: 0.6625 - val_accuracy: 0.6690 - val_loss: 0.7040
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.7938 - loss: 0.5406 - val_accuracy: 0.7586 - val_loss: 0.6171
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.8544 - loss: 0.4321 - val_accuracy: 0.7931 - val_loss: 0.5059
#
# Dropout 0.2 | Fold 1
# Loss     : 0.5059
# Accuracy : 0.7931
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_1.keras
#
# ====== Dropout 0.2 | Fold 2 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - accuracy: 0.6638 - loss: 1.0727 - val_accuracy: 0.6897 - val_loss: 1.0266
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.6863 - loss: 0.9318 - val_accuracy: 0.6897 - val_loss: 0.7794
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.6863 - loss: 0.6909 - val_accuracy: 0.6897 - val_loss: 0.6722
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.7608 - loss: 0.5515 - val_accuracy: 0.7586 - val_loss: 0.5853
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.8475 - loss: 0.4412 - val_accuracy: 0.7931 - val_loss: 0.4963
#
# Dropout 0.2 | Fold 2
# Loss     : 0.4963
# Accuracy : 0.7931
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_2.keras
#
# ====== Dropout 0.2 | Fold 3 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 180ms/step - accuracy: 0.6592 - loss: 1.0689 - val_accuracy: 0.7014 - val_loss: 1.0070
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.6834 - loss: 0.9148 - val_accuracy: 0.7014 - val_loss: 0.7038
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6834 - loss: 0.6950 - val_accuracy: 0.7014 - val_loss: 0.5729
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.7474 - loss: 0.5515 - val_accuracy: 0.7917 - val_loss: 0.4409
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.8512 - loss: 0.4228 - val_accuracy: 0.9028 - val_loss: 0.3263
#
# Dropout 0.2 | Fold 3
# Loss     : 0.3263
# Accuracy : 0.9028
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_3.keras
#
# ====== Dropout 0.2 | Fold 4 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.6782 - loss: 1.0664 - val_accuracy: 0.7014 - val_loss: 1.0047
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.6834 - loss: 0.8980 - val_accuracy: 0.7014 - val_loss: 0.7039
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6834 - loss: 0.6948 - val_accuracy: 0.7014 - val_loss: 0.5723
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.7474 - loss: 0.5556 - val_accuracy: 0.7917 - val_loss: 0.4543
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.8322 - loss: 0.4228 - val_accuracy: 0.8889 - val_loss: 0.3548
#
# Dropout 0.2 | Fold 4
# Loss     : 0.3548
# Accuracy : 0.8889
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_4.keras
#
# ====== Dropout 0.2 | Fold 5 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 175ms/step - accuracy: 0.6782 - loss: 1.0741 - val_accuracy: 0.6806 - val_loss: 1.0313
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.6886 - loss: 0.9390 - val_accuracy: 0.6806 - val_loss: 0.7884
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.6886 - loss: 0.6873 - val_accuracy: 0.6944 - val_loss: 0.6428
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.7958 - loss: 0.5297 - val_accuracy: 0.7986 - val_loss: 0.5181
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.8616 - loss: 0.3794 - val_accuracy: 0.8472 - val_loss: 0.4154
#
# Dropout 0.2 | Fold 5
# Loss     : 0.4154
# Accuracy : 0.8472
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'fasilitas dan infrastruktur' | DROPOUT 0.2
# ============================================================
# Average Accuracy : 0.8450
#
# ############################################################
# # ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.5
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.5 | Fold 1 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.6690 - loss: 1.0729 - val_accuracy: 0.6621 - val_loss: 1.0340
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6932 - loss: 0.9730 - val_accuracy: 0.6621 - val_loss: 0.8782
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6932 - loss: 0.7647 - val_accuracy: 0.6621 - val_loss: 0.8021
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6932 - loss: 0.6433 - val_accuracy: 0.6621 - val_loss: 0.6747
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.7522 - loss: 0.5194 - val_accuracy: 0.7517 - val_loss: 0.6098
#
# Dropout 0.5 | Fold 1
# Loss     : 0.6098
# Accuracy : 0.7517
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_1.keras
#
# ====== Dropout 0.5 | Fold 2 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 172ms/step - accuracy: 0.6586 - loss: 1.0762 - val_accuracy: 0.6897 - val_loss: 1.0384
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6863 - loss: 0.9868 - val_accuracy: 0.6897 - val_loss: 0.8943
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6863 - loss: 0.8005 - val_accuracy: 0.6897 - val_loss: 0.7318
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6863 - loss: 0.6642 - val_accuracy: 0.6897 - val_loss: 0.6575
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.7383 - loss: 0.5549 - val_accuracy: 0.7517 - val_loss: 0.5785
#
# Dropout 0.5 | Fold 2
# Loss     : 0.5785
# Accuracy : 0.7517
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_2.keras
#
# ====== Dropout 0.5 | Fold 3 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - accuracy: 0.6592 - loss: 1.0767 - val_accuracy: 0.7014 - val_loss: 1.0376
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.6834 - loss: 0.9918 - val_accuracy: 0.7014 - val_loss: 0.8740
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.6834 - loss: 0.8013 - val_accuracy: 0.7014 - val_loss: 0.6524
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.6851 - loss: 0.6645 - val_accuracy: 0.7014 - val_loss: 0.5491
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.7266 - loss: 0.5494 - val_accuracy: 0.8056 - val_loss: 0.4365
#
# Dropout 0.5 | Fold 3
# Loss     : 0.4365
# Accuracy : 0.8056
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_3.keras
#
# ====== Dropout 0.5 | Fold 4 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 172ms/step - accuracy: 0.6488 - loss: 1.0751 - val_accuracy: 0.7014 - val_loss: 1.0366
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.6834 - loss: 0.9871 - val_accuracy: 0.7014 - val_loss: 0.8793
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.6834 - loss: 0.7923 - val_accuracy: 0.7014 - val_loss: 0.6625
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.6886 - loss: 0.6875 - val_accuracy: 0.7014 - val_loss: 0.5719
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.7370 - loss: 0.5676 - val_accuracy: 0.8056 - val_loss: 0.4638
#
# Dropout 0.5 | Fold 4
# Loss     : 0.4638
# Accuracy : 0.8056
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_4.keras
#
# ====== Dropout 0.5 | Fold 5 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - accuracy: 0.6661 - loss: 1.0737 - val_accuracy: 0.6806 - val_loss: 1.0352
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.6886 - loss: 0.9723 - val_accuracy: 0.6806 - val_loss: 0.8733
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6886 - loss: 0.7696 - val_accuracy: 0.6806 - val_loss: 0.7214
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.6920 - loss: 0.6420 - val_accuracy: 0.7014 - val_loss: 0.6234
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.7664 - loss: 0.5328 - val_accuracy: 0.7708 - val_loss: 0.5559
#
# Dropout 0.5 | Fold 5
# Loss     : 0.5559
# Accuracy : 0.7708
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'fasilitas dan infrastruktur' | DROPOUT 0.5
# ============================================================
# Average Accuracy : 0.7771
#
# ############################################################
# # ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.8
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.8 | Fold 1 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 181ms/step - accuracy: 0.5581 - loss: 1.0843 - val_accuracy: 0.6621 - val_loss: 1.0654
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.6915 - loss: 1.0435 - val_accuracy: 0.6621 - val_loss: 1.0187
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.6932 - loss: 0.9881 - val_accuracy: 0.6621 - val_loss: 0.9502
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - accuracy: 0.6932 - loss: 0.8969 - val_accuracy: 0.6621 - val_loss: 0.8542
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.6932 - loss: 0.8116 - val_accuracy: 0.6621 - val_loss: 0.7982
#
# Dropout 0.8 | Fold 1
# Loss     : 0.7982
# Accuracy : 0.6621
# Model for 'fasilitas dan infrastruktur' Dropout 0.8 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_8_fold_1.keras
#
# ====== Dropout 0.8 | Fold 2 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 182ms/step - accuracy: 0.5130 - loss: 1.0859 - val_accuracy: 0.6897 - val_loss: 1.0608
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6863 - loss: 1.0430 - val_accuracy: 0.6897 - val_loss: 1.0101
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.6863 - loss: 0.9853 - val_accuracy: 0.6897 - val_loss: 0.9388
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.6863 - loss: 0.9030 - val_accuracy: 0.6897 - val_loss: 0.8480
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.6863 - loss: 0.8261 - val_accuracy: 0.6897 - val_loss: 0.7824
#
# Dropout 0.8 | Fold 2
# Loss     : 0.7824
# Accuracy : 0.6897
# Model for 'fasilitas dan infrastruktur' Dropout 0.8 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 174ms/step - accuracy: 0.5727 - loss: 1.0835 - val_accuracy: 0.7014 - val_loss: 1.0600
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.6851 - loss: 1.0406 - val_accuracy: 0.7014 - val_loss: 1.0073
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6834 - loss: 0.9836 - val_accuracy: 0.7014 - val_loss: 0.9283
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.6817 - loss: 0.9118 - val_accuracy: 0.7014 - val_loss: 0.8247
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6834 - loss: 0.8300 - val_accuracy: 0.7014 - val_loss: 0.7489
#
# Dropout 0.8 | Fold 3
# Loss     : 0.7489
# Accuracy : 0.7014
# Model for 'fasilitas dan infrastruktur' Dropout 0.8 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_8_fold_3.keras
#
# ====== Dropout 0.8 | Fold 4 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 196ms/step - accuracy: 0.5260 - loss: 1.0827 - val_accuracy: 0.7014 - val_loss: 1.0569
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6799 - loss: 1.0422 - val_accuracy: 0.7014 - val_loss: 1.0007
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - accuracy: 0.6817 - loss: 0.9751 - val_accuracy: 0.7014 - val_loss: 0.9142
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6834 - loss: 0.8833 - val_accuracy: 0.7014 - val_loss: 0.7998
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.6834 - loss: 0.8216 - val_accuracy: 0.7014 - val_loss: 0.7303
#
# Dropout 0.8 | Fold 4
# Loss     : 0.7303
# Accuracy : 0.7014
# Model for 'fasilitas dan infrastruktur' Dropout 0.8 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_8_fold_4.keras
#
# ====== Dropout 0.8 | Fold 5 ======
# Epoch 1/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 179ms/step - accuracy: 0.5190 - loss: 1.0860 - val_accuracy: 0.6806 - val_loss: 1.0666
# Epoch 2/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 123ms/step - accuracy: 0.6834 - loss: 1.0448 - val_accuracy: 0.6806 - val_loss: 1.0184
# Epoch 3/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.6903 - loss: 0.9844 - val_accuracy: 0.6806 - val_loss: 0.9456
# Epoch 4/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.6886 - loss: 0.9003 - val_accuracy: 0.6806 - val_loss: 0.8470
# Epoch 5/5
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 124ms/step - accuracy: 0.6886 - loss: 0.8364 - val_accuracy: 0.6806 - val_loss: 0.7801
#
# Dropout 0.8 | Fold 5
# Loss     : 0.7801
# Accuracy : 0.6806
# Model for 'fasilitas dan infrastruktur' Dropout 0.8 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_8_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'fasilitas dan infrastruktur' | DROPOUT 0.8
# ============================================================
# Average Accuracy : 0.6870
# ======================================================================
# TRAINING SENTIMEN UNTUK ASPEK: kualitas pelayanan medis dan staf
# ======================================================================
#
# ############################################################
# # ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.2
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.2 | Fold 1 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 149ms/step - accuracy: 0.6526 - loss: 0.9922 - val_accuracy: 0.6954 - val_loss: 0.7359
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6965 - loss: 0.6087 - val_accuracy: 0.7748 - val_loss: 0.5207
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.8806 - loss: 0.3600 - val_accuracy: 0.9238 - val_loss: 0.3189
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9420 - loss: 0.1955 - val_accuracy: 0.9040 - val_loss: 0.2720
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9577 - loss: 0.1352 - val_accuracy: 0.9139 - val_loss: 0.2994
#
# Dropout 0.2 | Fold 1
# Loss     : 0.2994
# Accuracy : 0.9139
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.2 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_2_fold_1.keras
#
# ====== Dropout 0.2 | Fold 2 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - accuracy: 0.6791 - loss: 0.9658 - val_accuracy: 0.6788 - val_loss: 0.7261
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7148 - loss: 0.5892 - val_accuracy: 0.7815 - val_loss: 0.4478
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.8972 - loss: 0.3759 - val_accuracy: 0.9272 - val_loss: 0.2628
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9403 - loss: 0.2154 - val_accuracy: 0.9338 - val_loss: 0.1923
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9469 - loss: 0.1595 - val_accuracy: 0.9338 - val_loss: 0.1759
#
# Dropout 0.2 | Fold 2
# Loss     : 0.1759
# Accuracy : 0.9338
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.2 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_2_fold_2.keras
#
# ====== Dropout 0.2 | Fold 3 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - accuracy: 0.6741 - loss: 0.9581 - val_accuracy: 0.6788 - val_loss: 0.7015
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.6891 - loss: 0.6022 - val_accuracy: 0.7450 - val_loss: 0.4900
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.8706 - loss: 0.3905 - val_accuracy: 0.8974 - val_loss: 0.3404
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9461 - loss: 0.2351 - val_accuracy: 0.9205 - val_loss: 0.2226
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9561 - loss: 0.1507 - val_accuracy: 0.9272 - val_loss: 0.2091
#
# Dropout 0.2 | Fold 3
# Loss     : 0.2091
# Accuracy : 0.9272
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.2 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_2_fold_3.keras
#
# ====== Dropout 0.2 | Fold 4 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 145ms/step - accuracy: 0.6678 - loss: 0.9672 - val_accuracy: 0.7043 - val_loss: 0.6883
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.6976 - loss: 0.5940 - val_accuracy: 0.7442 - val_loss: 0.4770
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.8865 - loss: 0.3880 - val_accuracy: 0.9236 - val_loss: 0.3119
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9478 - loss: 0.2135 - val_accuracy: 0.9269 - val_loss: 0.2304
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9594 - loss: 0.1439 - val_accuracy: 0.9269 - val_loss: 0.2259
#
# Dropout 0.2 | Fold 4
# Loss     : 0.2259
# Accuracy : 0.9269
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.2 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_2_fold_4.keras
#
# ====== Dropout 0.2 | Fold 5 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 144ms/step - accuracy: 0.6835 - loss: 0.9654 - val_accuracy: 0.6512 - val_loss: 0.7443
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 126ms/step - accuracy: 0.6943 - loss: 0.6329 - val_accuracy: 0.6777 - val_loss: 0.5429
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.8219 - loss: 0.4399 - val_accuracy: 0.8837 - val_loss: 0.3999
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9403 - loss: 0.2631 - val_accuracy: 0.9236 - val_loss: 0.2573
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9594 - loss: 0.1440 - val_accuracy: 0.9369 - val_loss: 0.2407
#
# Dropout 0.2 | Fold 5
# Loss     : 0.2407
# Accuracy : 0.9369
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.2 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_2_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT 0.2
# ============================================================
# Average Accuracy : 0.9277
#
# ############################################################
# # ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.5
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.5 | Fold 1 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 145ms/step - accuracy: 0.6567 - loss: 1.0156 - val_accuracy: 0.6954 - val_loss: 0.8315
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.6783 - loss: 0.6886 - val_accuracy: 0.6954 - val_loss: 0.5938
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.7297 - loss: 0.5009 - val_accuracy: 0.8278 - val_loss: 0.4650
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9146 - loss: 0.3534 - val_accuracy: 0.9073 - val_loss: 0.3452
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9411 - loss: 0.2109 - val_accuracy: 0.9007 - val_loss: 0.3136
#
# Dropout 0.5 | Fold 1
# Loss     : 0.3136
# Accuracy : 0.9007
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.5 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_5_fold_1.keras
#
# ====== Dropout 0.5 | Fold 2 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 146ms/step - accuracy: 0.6600 - loss: 1.0312 - val_accuracy: 0.6788 - val_loss: 0.8873
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.6824 - loss: 0.7161 - val_accuracy: 0.6788 - val_loss: 0.5939
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.7537 - loss: 0.5230 - val_accuracy: 0.8278 - val_loss: 0.3824
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9245 - loss: 0.3220 - val_accuracy: 0.9272 - val_loss: 0.2282
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9362 - loss: 0.2199 - val_accuracy: 0.9371 - val_loss: 0.1800
#
# Dropout 0.5 | Fold 2
# Loss     : 0.1800
# Accuracy : 0.9371
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.5 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_5_fold_2.keras
#
# ====== Dropout 0.5 | Fold 3 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step - accuracy: 0.6493 - loss: 1.0404 - val_accuracy: 0.6788 - val_loss: 0.9192
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.6833 - loss: 0.7339 - val_accuracy: 0.6788 - val_loss: 0.5850
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.7587 - loss: 0.5003 - val_accuracy: 0.8642 - val_loss: 0.4096
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9179 - loss: 0.3126 - val_accuracy: 0.9272 - val_loss: 0.2585
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9502 - loss: 0.1928 - val_accuracy: 0.9139 - val_loss: 0.2351
#
# Dropout 0.5 | Fold 3
# Loss     : 0.2351
# Accuracy : 0.9139
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.5 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_5_fold_3.keras
#
# ====== Dropout 0.5 | Fold 4 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - accuracy: 0.6636 - loss: 1.0009 - val_accuracy: 0.7043 - val_loss: 0.7792
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6761 - loss: 0.6739 - val_accuracy: 0.7043 - val_loss: 0.5719
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7332 - loss: 0.5128 - val_accuracy: 0.8439 - val_loss: 0.4213
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.9130 - loss: 0.3502 - val_accuracy: 0.9236 - val_loss: 0.2894
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9470 - loss: 0.2212 - val_accuracy: 0.9169 - val_loss: 0.2312
#
# Dropout 0.5 | Fold 4
# Loss     : 0.2312
# Accuracy : 0.9169
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.5 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_5_fold_4.keras
#
# ====== Dropout 0.5 | Fold 5 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 144ms/step - accuracy: 0.6703 - loss: 1.0295 - val_accuracy: 0.6512 - val_loss: 0.8840
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.6893 - loss: 0.7065 - val_accuracy: 0.6512 - val_loss: 0.6093
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.7291 - loss: 0.5173 - val_accuracy: 0.8106 - val_loss: 0.4401
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.9080 - loss: 0.3329 - val_accuracy: 0.9103 - val_loss: 0.2933
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9412 - loss: 0.2052 - val_accuracy: 0.9236 - val_loss: 0.2459
#
# Dropout 0.5 | Fold 5
# Loss     : 0.2459
# Accuracy : 0.9236
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.5 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_5_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT 0.5
# ============================================================
# Average Accuracy : 0.9184
#
# ############################################################
# # ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.8
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.8 | Fold 1 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 145ms/step - accuracy: 0.6020 - loss: 1.0595 - val_accuracy: 0.6954 - val_loss: 0.9976
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6791 - loss: 0.8974 - val_accuracy: 0.6954 - val_loss: 0.7576
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6774 - loss: 0.7450 - val_accuracy: 0.6954 - val_loss: 0.6810
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.6824 - loss: 0.6770 - val_accuracy: 0.6954 - val_loss: 0.6131
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7197 - loss: 0.5804 - val_accuracy: 0.7351 - val_loss: 0.5135
#
# Dropout 0.8 | Fold 1
# Loss     : 0.5135
# Accuracy : 0.7351
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.8 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_8_fold_1.keras
#
# ====== Dropout 0.8 | Fold 2 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 147ms/step - accuracy: 0.6426 - loss: 1.0520 - val_accuracy: 0.6788 - val_loss: 0.9816
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.6824 - loss: 0.8779 - val_accuracy: 0.6788 - val_loss: 0.7462
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.6824 - loss: 0.7246 - val_accuracy: 0.6788 - val_loss: 0.6570
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.6816 - loss: 0.6507 - val_accuracy: 0.6788 - val_loss: 0.5560
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.7289 - loss: 0.5505 - val_accuracy: 0.7682 - val_loss: 0.4395
#
# Dropout 0.8 | Fold 2
# Loss     : 0.4395
# Accuracy : 0.7682
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.8 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - accuracy: 0.6227 - loss: 1.0475 - val_accuracy: 0.6788 - val_loss: 0.9735
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6799 - loss: 0.8715 - val_accuracy: 0.6788 - val_loss: 0.7352
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.6816 - loss: 0.7403 - val_accuracy: 0.6788 - val_loss: 0.6695
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.6833 - loss: 0.6882 - val_accuracy: 0.6788 - val_loss: 0.6097
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6833 - loss: 0.5999 - val_accuracy: 0.6954 - val_loss: 0.5134
#
# Dropout 0.8 | Fold 3
# Loss     : 0.5134
# Accuracy : 0.6954
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.8 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_8_fold_3.keras
#
# ====== Dropout 0.8 | Fold 4 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 13s 147ms/step - accuracy: 0.6073 - loss: 1.0632 - val_accuracy: 0.7043 - val_loss: 0.9998
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.6744 - loss: 0.9219 - val_accuracy: 0.7043 - val_loss: 0.7778
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.6752 - loss: 0.7557 - val_accuracy: 0.7043 - val_loss: 0.6637
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6736 - loss: 0.6894 - val_accuracy: 0.7043 - val_loss: 0.5794
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.7001 - loss: 0.5859 - val_accuracy: 0.7243 - val_loss: 0.4675
#
# Dropout 0.8 | Fold 4
# Loss     : 0.4675
# Accuracy : 0.7243
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.8 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_8_fold_4.keras
#
# ====== Dropout 0.8 | Fold 5 ======
# Epoch 1/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 12s 146ms/step - accuracy: 0.6645 - loss: 1.0453 - val_accuracy: 0.6512 - val_loss: 0.9787
# Epoch 2/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6893 - loss: 0.8635 - val_accuracy: 0.6512 - val_loss: 0.7651
# Epoch 3/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6893 - loss: 0.7272 - val_accuracy: 0.6512 - val_loss: 0.6859
# Epoch 4/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.6885 - loss: 0.6580 - val_accuracy: 0.6512 - val_loss: 0.6071
# Epoch 5/5
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.7001 - loss: 0.5814 - val_accuracy: 0.6811 - val_loss: 0.5165
#
# Dropout 0.8 | Fold 5
# Loss     : 0.5165
# Accuracy : 0.6811
# Model for 'kualitas pelayanan medis dan staf' Dropout 0.8 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_kualitas_pelayanan_medis_dan_staf_dropout_0_8_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT 0.8
# ============================================================
# Average Accuracy : 0.7208
# ======================================================================
# TRAINING SENTIMEN UNTUK ASPEK: lainnya
# ======================================================================
#
# ############################################################
# # ASPEK 'lainnya' | DROPOUT = 0.2
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.2 | Fold 1 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 144ms/step - accuracy: 0.5612 - loss: 1.0494 - val_accuracy: 0.5782 - val_loss: 0.9658
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5701 - loss: 0.8901 - val_accuracy: 0.6431 - val_loss: 0.7961
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.7552 - loss: 0.6650 - val_accuracy: 0.7670 - val_loss: 0.6465
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.8606 - loss: 0.3953 - val_accuracy: 0.7965 - val_loss: 0.6041
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9233 - loss: 0.2438 - val_accuracy: 0.8319 - val_loss: 0.6185
#
# Dropout 0.2 | Fold 1
# Loss     : 0.6185
# Accuracy : 0.8319
# Model for 'lainnya' Dropout 0.2 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_2_fold_1.keras
#
# ====== Dropout 0.2 | Fold 2 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 144ms/step - accuracy: 0.5656 - loss: 1.0442 - val_accuracy: 0.5546 - val_loss: 0.9644
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5833 - loss: 0.8755 - val_accuracy: 0.6313 - val_loss: 0.8503
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.7301 - loss: 0.6764 - val_accuracy: 0.7611 - val_loss: 0.7264
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.8510 - loss: 0.4485 - val_accuracy: 0.7729 - val_loss: 0.6649
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9027 - loss: 0.2972 - val_accuracy: 0.7788 - val_loss: 0.6894
#
# Dropout 0.2 | Fold 2
# Loss     : 0.6894
# Accuracy : 0.7788
# Model for 'lainnya' Dropout 0.2 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_2_fold_2.keras
#
# ====== Dropout 0.2 | Fold 3 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 144ms/step - accuracy: 0.5730 - loss: 1.0464 - val_accuracy: 0.5310 - val_loss: 0.9828
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5981 - loss: 0.8740 - val_accuracy: 0.5959 - val_loss: 0.8597
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.7065 - loss: 0.6862 - val_accuracy: 0.7375 - val_loss: 0.7218
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.8562 - loss: 0.4528 - val_accuracy: 0.7345 - val_loss: 0.6644
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9027 - loss: 0.2909 - val_accuracy: 0.7699 - val_loss: 0.6344
#
# Dropout 0.2 | Fold 3
# Loss     : 0.6344
# Accuracy : 0.7699
# Model for 'lainnya' Dropout 0.2 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_2_fold_3.keras
#
# ====== Dropout 0.2 | Fold 4 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 142ms/step - accuracy: 0.5686 - loss: 1.0476 - val_accuracy: 0.5605 - val_loss: 0.9665
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.5981 - loss: 0.8604 - val_accuracy: 0.6195 - val_loss: 0.8436
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7353 - loss: 0.6639 - val_accuracy: 0.7404 - val_loss: 0.7386
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.8562 - loss: 0.4355 - val_accuracy: 0.7670 - val_loss: 0.7335
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9078 - loss: 0.2921 - val_accuracy: 0.7935 - val_loss: 0.7561
#
# Dropout 0.2 | Fold 4
# Loss     : 0.7561
# Accuracy : 0.7935
# Model for 'lainnya' Dropout 0.2 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_2_fold_4.keras
#
# ====== Dropout 0.2 | Fold 5 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 149ms/step - accuracy: 0.5516 - loss: 1.0471 - val_accuracy: 0.6195 - val_loss: 0.9171
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.5752 - loss: 0.8786 - val_accuracy: 0.6785 - val_loss: 0.7654
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.7264 - loss: 0.7113 - val_accuracy: 0.7847 - val_loss: 0.6593
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.8311 - loss: 0.5055 - val_accuracy: 0.8142 - val_loss: 0.5809
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.8953 - loss: 0.3376 - val_accuracy: 0.8142 - val_loss: 0.5584
#
# Dropout 0.2 | Fold 5
# Loss     : 0.5584
# Accuracy : 0.8142
# Model for 'lainnya' Dropout 0.2 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_2_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'lainnya' | DROPOUT 0.2
# ============================================================
# Average Accuracy : 0.7976
#
# ############################################################
# # ASPEK 'lainnya' | DROPOUT = 0.5
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.5 | Fold 1 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 143ms/step - accuracy: 0.5612 - loss: 1.0614 - val_accuracy: 0.5782 - val_loss: 1.0001
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5664 - loss: 0.9499 - val_accuracy: 0.5782 - val_loss: 0.8813
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6084 - loss: 0.8196 - val_accuracy: 0.6814 - val_loss: 0.7485
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.7765 - loss: 0.6348 - val_accuracy: 0.7906 - val_loss: 0.6351
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.8459 - loss: 0.4506 - val_accuracy: 0.8024 - val_loss: 0.5805
#
# Dropout 0.5 | Fold 1
# Loss     : 0.5805
# Accuracy : 0.8024
# Model for 'lainnya' Dropout 0.5 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_5_fold_1.keras
#
# ====== Dropout 0.5 | Fold 2 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 142ms/step - accuracy: 0.5664 - loss: 1.0543 - val_accuracy: 0.5546 - val_loss: 0.9962
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.5723 - loss: 0.9329 - val_accuracy: 0.5546 - val_loss: 0.8960
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.6217 - loss: 0.8009 - val_accuracy: 0.6932 - val_loss: 0.8047
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7588 - loss: 0.6449 - val_accuracy: 0.7640 - val_loss: 0.7358
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.8215 - loss: 0.5103 - val_accuracy: 0.7493 - val_loss: 0.7084
#
# Dropout 0.5 | Fold 2
# Loss     : 0.7084
# Accuracy : 0.7493
# Model for 'lainnya' Dropout 0.5 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_5_fold_2.keras
#
# ====== Dropout 0.5 | Fold 3 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 141ms/step - accuracy: 0.5619 - loss: 1.0587 - val_accuracy: 0.5310 - val_loss: 1.0143
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.5782 - loss: 0.9336 - val_accuracy: 0.5310 - val_loss: 0.9249
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.6173 - loss: 0.8141 - val_accuracy: 0.6106 - val_loss: 0.8260
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7397 - loss: 0.6660 - val_accuracy: 0.7434 - val_loss: 0.7345
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.8319 - loss: 0.5002 - val_accuracy: 0.7493 - val_loss: 0.6931
#
# Dropout 0.5 | Fold 3
# Loss     : 0.6931
# Accuracy : 0.7493
# Model for 'lainnya' Dropout 0.5 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_5_fold_3.keras
#
# ====== Dropout 0.5 | Fold 4 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 142ms/step - accuracy: 0.5656 - loss: 1.0551 - val_accuracy: 0.5605 - val_loss: 0.9957
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5715 - loss: 0.9263 - val_accuracy: 0.5605 - val_loss: 0.9044
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6276 - loss: 0.8101 - val_accuracy: 0.6372 - val_loss: 0.8242
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.7441 - loss: 0.6534 - val_accuracy: 0.7345 - val_loss: 0.7529
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.8496 - loss: 0.4737 - val_accuracy: 0.7463 - val_loss: 0.7621
#
# Dropout 0.5 | Fold 4
# Loss     : 0.7621
# Accuracy : 0.7463
# Model for 'lainnya' Dropout 0.5 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_5_fold_4.keras
#
# ====== Dropout 0.5 | Fold 5 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 142ms/step - accuracy: 0.5354 - loss: 1.0619 - val_accuracy: 0.6195 - val_loss: 0.9789
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5560 - loss: 0.9491 - val_accuracy: 0.6165 - val_loss: 0.8336
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.6150 - loss: 0.8183 - val_accuracy: 0.6903 - val_loss: 0.7304
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.7235 - loss: 0.6912 - val_accuracy: 0.7906 - val_loss: 0.6464
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.8230 - loss: 0.5338 - val_accuracy: 0.8201 - val_loss: 0.5971
#
# Dropout 0.5 | Fold 5
# Loss     : 0.5971
# Accuracy : 0.8201
# Model for 'lainnya' Dropout 0.5 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_5_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'lainnya' | DROPOUT 0.5
# ============================================================
# Average Accuracy : 0.7735
#
# ############################################################
# # ASPEK 'lainnya' | DROPOUT = 0.8
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.8 | Fold 1 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 143ms/step - accuracy: 0.5501 - loss: 1.0679 - val_accuracy: 0.5782 - val_loss: 1.0276
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5664 - loss: 0.9943 - val_accuracy: 0.5782 - val_loss: 0.9531
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.5664 - loss: 0.9619 - val_accuracy: 0.5782 - val_loss: 0.9319
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 124ms/step - accuracy: 0.5664 - loss: 0.9521 - val_accuracy: 0.5782 - val_loss: 0.9079
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.5664 - loss: 0.9162 - val_accuracy: 0.5752 - val_loss: 0.8513
#
# Dropout 0.8 | Fold 1
# Loss     : 0.8513
# Accuracy : 0.5752
# Model for 'lainnya' Dropout 0.8 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_8_fold_1.keras
#
# ====== Dropout 0.8 | Fold 2 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 155ms/step - accuracy: 0.5324 - loss: 1.0724 - val_accuracy: 0.5546 - val_loss: 1.0428
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.5723 - loss: 1.0093 - val_accuracy: 0.5546 - val_loss: 0.9795
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.5723 - loss: 0.9655 - val_accuracy: 0.5546 - val_loss: 0.9605
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.5723 - loss: 0.9537 - val_accuracy: 0.5546 - val_loss: 0.9412
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5715 - loss: 0.9105 - val_accuracy: 0.5546 - val_loss: 0.8976
#
# Dropout 0.8 | Fold 2
# Loss     : 0.8976
# Accuracy : 0.5546
# Model for 'lainnya' Dropout 0.8 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 141ms/step - accuracy: 0.5317 - loss: 1.0744 - val_accuracy: 0.5310 - val_loss: 1.0514
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5782 - loss: 1.0057 - val_accuracy: 0.5310 - val_loss: 0.9946
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.5774 - loss: 0.9587 - val_accuracy: 0.5310 - val_loss: 0.9802
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5782 - loss: 0.9449 - val_accuracy: 0.5310 - val_loss: 0.9593
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.5782 - loss: 0.9118 - val_accuracy: 0.5310 - val_loss: 0.9134
#
# Dropout 0.8 | Fold 3
# Loss     : 0.9134
# Accuracy : 0.5310
# Model for 'lainnya' Dropout 0.8 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_8_fold_3.keras
#
# ====== Dropout 0.8 | Fold 4 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 14s 145ms/step - accuracy: 0.5376 - loss: 1.0732 - val_accuracy: 0.5605 - val_loss: 1.0418
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.5708 - loss: 1.0006 - val_accuracy: 0.5605 - val_loss: 0.9732
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.5708 - loss: 0.9560 - val_accuracy: 0.5605 - val_loss: 0.9556
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5701 - loss: 0.9379 - val_accuracy: 0.5605 - val_loss: 0.9321
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.5774 - loss: 0.9021 - val_accuracy: 0.5693 - val_loss: 0.8880
#
# Dropout 0.8 | Fold 4
# Loss     : 0.8880
# Accuracy : 0.5693
# Model for 'lainnya' Dropout 0.8 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_8_fold_4.keras
#
# ====== Dropout 0.8 | Fold 5 ======
# Epoch 1/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 13s 140ms/step - accuracy: 0.5295 - loss: 1.0789 - val_accuracy: 0.6195 - val_loss: 1.0373
# Epoch 2/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 123ms/step - accuracy: 0.5568 - loss: 1.0218 - val_accuracy: 0.6195 - val_loss: 0.9500
# Epoch 3/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.5553 - loss: 0.9749 - val_accuracy: 0.6195 - val_loss: 0.9044
# Epoch 4/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.5553 - loss: 0.9636 - val_accuracy: 0.6195 - val_loss: 0.8861
# Epoch 5/5
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.5568 - loss: 0.9317 - val_accuracy: 0.6165 - val_loss: 0.8391
#
# Dropout 0.8 | Fold 5
# Loss     : 0.8391
# Accuracy : 0.6165
# Model for 'lainnya' Dropout 0.8 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_lainnya_dropout_0_8_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'lainnya' | DROPOUT 0.8
# ============================================================
# Average Accuracy : 0.5693
# ======================================================================
# TRAINING SENTIMEN UNTUK ASPEK: waktu tunggu
# ======================================================================
#
# ############################################################
# # ASPEK 'waktu tunggu' | DROPOUT = 0.2
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.2 | Fold 1 ======
# Epoch 1/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 9s 319ms/step - accuracy: 0.6807 - loss: 1.0902 - val_accuracy: 0.8571 - val_loss: 1.0708
# Epoch 2/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - accuracy: 0.7711 - loss: 1.0622 - val_accuracy: 0.8571 - val_loss: 1.0343
# Epoch 3/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.7711 - loss: 1.0241 - val_accuracy: 0.8571 - val_loss: 0.9828
# Epoch 4/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.7711 - loss: 0.9706 - val_accuracy: 0.8571 - val_loss: 0.9050
# Epoch 5/5
# ...
# Epoch 2/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.6826 - loss: 1.0768 - val_accuracy: 0.7805 - val_loss: 1.0693
# Epoch 3/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.7305 - loss: 1.0634 - val_accuracy: 0.7805 - val_loss: 1.0511
# Epoch 4/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - accuracy: 0.7665 - loss: 1.0455 - val_accuracy: 0.7805 - val_loss: 1.0304
# Epoch 5/5
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.7904 - loss: 1.0183 - val_accuracy: 0.7805 - val_loss: 1.0063
#
# Dropout 0.8 | Fold 5
# Loss     : 1.0063
# Accuracy : 0.7805
# Model for 'waktu tunggu' Dropout 0.8 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_waktu_tunggu_dropout_0_8_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'waktu tunggu' | DROPOUT 0.8
# ============================================================
# Average Accuracy : 0.7890
# ======================================================================
# TRAINING SENTIMEN UNTUK ASPEK: biaya layanan
# ======================================================================
#
# ############################################################
# # ASPEK 'biaya layanan' | DROPOUT = 0.2
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.2 | Fold 1 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.3889 - loss: 1.0982 - val_accuracy: 0.7857 - val_loss: 1.0936
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.6852 - loss: 1.0931 - val_accuracy: 0.7857 - val_loss: 1.0885
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.6852 - loss: 1.0885 - val_accuracy: 0.7857 - val_loss: 1.0830
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6852 - loss: 1.0838 - val_accuracy: 0.7857 - val_loss: 1.0770
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.6852 - loss: 1.0777 - val_accuracy: 0.7857 - val_loss: 1.0706
#
# Dropout 0.2 | Fold 1
# Loss     : 1.0706
# Accuracy : 0.7857
# Model for 'biaya layanan' Dropout 0.2 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_2_fold_1.keras
#
# ====== Dropout 0.2 | Fold 2 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3333 - loss: 1.0980 - val_accuracy: 0.7143 - val_loss: 1.0932
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.7037 - loss: 1.0919 - val_accuracy: 0.7143 - val_loss: 1.0874
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.7037 - loss: 1.0852 - val_accuracy: 0.7143 - val_loss: 1.0810
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7037 - loss: 1.0789 - val_accuracy: 0.7143 - val_loss: 1.0740
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.7037 - loss: 1.0714 - val_accuracy: 0.7143 - val_loss: 1.0662
#
# Dropout 0.2 | Fold 2
# Loss     : 1.0662
# Accuracy : 0.7143
# Model for 'biaya layanan' Dropout 0.2 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_2_fold_2.keras
#
# ====== Dropout 0.2 | Fold 3 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.5741 - loss: 1.0963 - val_accuracy: 0.7857 - val_loss: 1.0907
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.6852 - loss: 1.0900 - val_accuracy: 0.7857 - val_loss: 1.0830
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.6852 - loss: 1.0829 - val_accuracy: 0.7857 - val_loss: 1.0747
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.6852 - loss: 1.0748 - val_accuracy: 0.7857 - val_loss: 1.0658
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.6852 - loss: 1.0661 - val_accuracy: 0.7857 - val_loss: 1.0560
#
# Dropout 0.2 | Fold 3
# Loss     : 1.0560
# Accuracy : 0.7857
# Model for 'biaya layanan' Dropout 0.2 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_2_fold_3.keras
#
# ====== Dropout 0.2 | Fold 4 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.5273 - loss: 1.0978 - val_accuracy: 0.5385 - val_loss: 1.0948
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.7455 - loss: 1.0910 - val_accuracy: 0.5385 - val_loss: 1.0907
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7455 - loss: 1.0852 - val_accuracy: 0.5385 - val_loss: 1.0862
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7455 - loss: 1.0776 - val_accuracy: 0.5385 - val_loss: 1.0813
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.7455 - loss: 1.0700 - val_accuracy: 0.5385 - val_loss: 1.0759
#
# Dropout 0.2 | Fold 4
# Loss     : 1.0759
# Accuracy : 0.5385
# Model for 'biaya layanan' Dropout 0.2 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_2_fold_4.keras
#
# ====== Dropout 0.2 | Fold 5 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.4000 - loss: 1.0981 - val_accuracy: 0.6923 - val_loss: 1.0939
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7091 - loss: 1.0922 - val_accuracy: 0.6923 - val_loss: 1.0896
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7091 - loss: 1.0866 - val_accuracy: 0.6923 - val_loss: 1.0850
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7091 - loss: 1.0810 - val_accuracy: 0.6923 - val_loss: 1.0801
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7091 - loss: 1.0742 - val_accuracy: 0.6923 - val_loss: 1.0747
#
# Dropout 0.2 | Fold 5
# Loss     : 1.0747
# Accuracy : 0.6923
# Model for 'biaya layanan' Dropout 0.2 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_2_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'biaya layanan' | DROPOUT 0.2
# ============================================================
# Average Accuracy : 0.7033
#
# ############################################################
# # ASPEK 'biaya layanan' | DROPOUT = 0.5
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.5 | Fold 1 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3704 - loss: 1.0977 - val_accuracy: 0.7857 - val_loss: 1.0936
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.7037 - loss: 1.0936 - val_accuracy: 0.7857 - val_loss: 1.0881
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.6667 - loss: 1.0889 - val_accuracy: 0.7857 - val_loss: 1.0825
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.6852 - loss: 1.0823 - val_accuracy: 0.7857 - val_loss: 1.0765
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6852 - loss: 1.0776 - val_accuracy: 0.7857 - val_loss: 1.0699
#
# Dropout 0.5 | Fold 1
# Loss     : 1.0699
# Accuracy : 0.7857
# Model for 'biaya layanan' Dropout 0.5 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_5_fold_1.keras
#
# ====== Dropout 0.5 | Fold 2 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.3519 - loss: 1.0987 - val_accuracy: 0.7143 - val_loss: 1.0943
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.6481 - loss: 1.0938 - val_accuracy: 0.7143 - val_loss: 1.0893
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7037 - loss: 1.0900 - val_accuracy: 0.7143 - val_loss: 1.0843
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.7037 - loss: 1.0839 - val_accuracy: 0.7143 - val_loss: 1.0788
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7037 - loss: 1.0802 - val_accuracy: 0.7143 - val_loss: 1.0731
#
# Dropout 0.5 | Fold 2
# Loss     : 1.0731
# Accuracy : 0.7143
# Model for 'biaya layanan' Dropout 0.5 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_5_fold_2.keras
#
# ====== Dropout 0.5 | Fold 3 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.4815 - loss: 1.0973 - val_accuracy: 0.7857 - val_loss: 1.0925
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.6667 - loss: 1.0921 - val_accuracy: 0.7857 - val_loss: 1.0864
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.6852 - loss: 1.0870 - val_accuracy: 0.7857 - val_loss: 1.0799
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6852 - loss: 1.0809 - val_accuracy: 0.7857 - val_loss: 1.0730
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6852 - loss: 1.0740 - val_accuracy: 0.7857 - val_loss: 1.0656
#
# Dropout 0.5 | Fold 3
# Loss     : 1.0656
# Accuracy : 0.7857
# Model for 'biaya layanan' Dropout 0.5 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_5_fold_3.keras
#
# ====== Dropout 0.5 | Fold 4 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.5273 - loss: 1.0971 - val_accuracy: 0.5385 - val_loss: 1.0948
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.7455 - loss: 1.0918 - val_accuracy: 0.5385 - val_loss: 1.0910
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7455 - loss: 1.0850 - val_accuracy: 0.5385 - val_loss: 1.0871
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.7455 - loss: 1.0805 - val_accuracy: 0.5385 - val_loss: 1.0829
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.7455 - loss: 1.0722 - val_accuracy: 0.5385 - val_loss: 1.0783
#
# Dropout 0.5 | Fold 4
# Loss     : 1.0783
# Accuracy : 0.5385
# Model for 'biaya layanan' Dropout 0.5 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_5_fold_4.keras
#
# ====== Dropout 0.5 | Fold 5 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.4909 - loss: 1.0966 - val_accuracy: 0.6923 - val_loss: 1.0946
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.7273 - loss: 1.0916 - val_accuracy: 0.6923 - val_loss: 1.0903
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.7091 - loss: 1.0858 - val_accuracy: 0.6923 - val_loss: 1.0856
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7273 - loss: 1.0794 - val_accuracy: 0.6923 - val_loss: 1.0805
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.7091 - loss: 1.0739 - val_accuracy: 0.6923 - val_loss: 1.0749
#
# Dropout 0.5 | Fold 5
# Loss     : 1.0749
# Accuracy : 0.6923
# Model for 'biaya layanan' Dropout 0.5 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_5_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'biaya layanan' | DROPOUT 0.5
# ============================================================
# Average Accuracy : 0.7033
#
# ############################################################
# # ASPEK 'biaya layanan' | DROPOUT = 0.8
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 5
# ============================================================
#
# ====== Dropout 0.8 | Fold 1 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.2963 - loss: 1.0990 - val_accuracy: 0.7857 - val_loss: 1.0944
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.4444 - loss: 1.0930 - val_accuracy: 0.7857 - val_loss: 1.0899
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.5556 - loss: 1.0887 - val_accuracy: 0.7857 - val_loss: 1.0853
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.5926 - loss: 1.0841 - val_accuracy: 0.7857 - val_loss: 1.0803
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6667 - loss: 1.0806 - val_accuracy: 0.7857 - val_loss: 1.0751
#
# Dropout 0.8 | Fold 1
# Loss     : 1.0751
# Accuracy : 0.7857
# Model for 'biaya layanan' Dropout 0.8 Fold 1 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_8_fold_1.keras
#
# ====== Dropout 0.8 | Fold 2 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.4444 - loss: 1.1014 - val_accuracy: 0.7143 - val_loss: 1.0941
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.3889 - loss: 1.0933 - val_accuracy: 0.7143 - val_loss: 1.0896
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.5556 - loss: 1.0890 - val_accuracy: 0.7143 - val_loss: 1.0848
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 0.6111 - loss: 1.0815 - val_accuracy: 0.7143 - val_loss: 1.0798
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6111 - loss: 1.0833 - val_accuracy: 0.7143 - val_loss: 1.0748
#
# Dropout 0.8 | Fold 2
# Loss     : 1.0748
# Accuracy : 0.7143
# Model for 'biaya layanan' Dropout 0.8 Fold 2 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3519 - loss: 1.0990 - val_accuracy: 0.7857 - val_loss: 1.0935
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.4444 - loss: 1.0932 - val_accuracy: 0.7857 - val_loss: 1.0889
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.6296 - loss: 1.0873 - val_accuracy: 0.7857 - val_loss: 1.0838
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.6296 - loss: 1.0845 - val_accuracy: 0.7857 - val_loss: 1.0784
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - accuracy: 0.6481 - loss: 1.0828 - val_accuracy: 0.7857 - val_loss: 1.0729
#
# Dropout 0.8 | Fold 3
# Loss     : 1.0729
# Accuracy : 0.7857
# Model for 'biaya layanan' Dropout 0.8 Fold 3 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_8_fold_3.keras
#
# ====== Dropout 0.8 | Fold 4 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.3818 - loss: 1.0996 - val_accuracy: 0.5385 - val_loss: 1.0960
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 0.4727 - loss: 1.0928 - val_accuracy: 0.5385 - val_loss: 1.0929
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.5636 - loss: 1.0822 - val_accuracy: 0.5385 - val_loss: 1.0898
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.6182 - loss: 1.0836 - val_accuracy: 0.5385 - val_loss: 1.0864
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 0.6909 - loss: 1.0785 - val_accuracy: 0.5385 - val_loss: 1.0829
#
# Dropout 0.8 | Fold 4
# Loss     : 1.0829
# Accuracy : 0.5385
# Model for 'biaya layanan' Dropout 0.8 Fold 4 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_8_fold_4.keras
#
# ====== Dropout 0.8 | Fold 5 ======
# Epoch 1/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3818 - loss: 1.0968 - val_accuracy: 0.6923 - val_loss: 1.0944
# Epoch 2/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 0.4000 - loss: 1.0917 - val_accuracy: 0.6923 - val_loss: 1.0904
# Epoch 3/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5818 - loss: 1.0870 - val_accuracy: 0.6923 - val_loss: 1.0863
# Epoch 4/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 0.7273 - loss: 1.0774 - val_accuracy: 0.6923 - val_loss: 1.0820
# Epoch 5/5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.6727 - loss: 1.0764 - val_accuracy: 0.6923 - val_loss: 1.0776
#
# Dropout 0.8 | Fold 5
# Loss     : 1.0776
# Accuracy : 0.6923
# Model for 'biaya layanan' Dropout 0.8 Fold 5 saved to:
# /kaggle/working/EPOCH_05/sentiment_models_per_aspect/epoch_5/sentiment_model_biaya_layanan_dropout_0_8_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'biaya layanan' | DROPOUT 0.8
# ============================================================
# Average Accuracy : 0.7033

# %%
import os
import re
import numpy as np
import pandas as pd

from tensorflow.keras.models import load_model

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# ============================================================
# CEK VARIABEL YANG DIBUTUHKAN
# ============================================================

if 'BASE_DRIVE_PATH' not in globals():
    print("Error: BASE_DRIVE_PATH tidak ditemukan.")
    raise SystemExit()

if 'sentiment_le' not in globals():
    print("Warning: sentiment_le tidak ditemukan.")
    sentiment_target_names = [str(i) for i in range(3)]
else:
    sentiment_target_names = list(sentiment_le.classes_)

if 'DROPOUT_VALUES' not in globals():
    DROPOUT_VALUES = [0.2, 0.5, 0.8]

# ============================================================
# LOKASI MODEL
# ============================================================

save_dir_relative = f"sentiment_models_per_aspect/epoch_{EPOCHS}"

sentiment_models_base_dir = os.path.join(
    BASE_DRIVE_PATH,
    save_dir_relative
)

print("="*70)
print("EVALUASI ENSEMBLE MODEL SENTIMEN PER ASPEK (per nilai dropout)")
print("="*70)

def get_fold_number(filename):
    match = re.search(r'fold_(\d+)\.keras', filename)
    if match:
        return int(match.group(1))
    return -1

# Menyimpan ringkasan ensemble untuk semua kombinasi aspek x dropout
all_ensemble_rows = []

# ============================================================
# LOOP SETIAP ASPEK
# ============================================================

for aspek_name, data in split_data_per_aspek.items():

    print("\n")
    print("="*70)
    print(f"EVALUASI ASPEK : {aspek_name}")
    print("="*70)

    # --------------------------------------------------------
    # CEK DATA TEST
    # --------------------------------------------------------

    if (
        'X_test_padded' not in data
        or
        'Y_test' not in data
    ):
        print("Data test tidak ditemukan.")
        continue

    X_test_aspect = data['X_test_padded']
    Y_test_aspect = np.array(data['Y_test'])

    if len(Y_test_aspect) == 0:
        print("Data test kosong.")
        continue

    cleaned_aspek_name = aspek_name.replace(' ', '_').replace('/', '_').lower()

    # --------------------------------------------------------
    # LOOP SETIAP NILAI DROPOUT
    # --------------------------------------------------------

    for dropout_rate in DROPOUT_VALUES:

        dropout_tag = str(dropout_rate).replace('.', '_')

        print("\n" + "-"*70)
        print(f"ASPEK '{aspek_name}' | DROPOUT = {dropout_rate}")
        print("-"*70)

        # --------------------------------------------------------
        # CARI MODEL UNTUK ASPEK + DROPOUT INI
        # --------------------------------------------------------

        prefix = f"sentiment_model_{cleaned_aspek_name}_dropout_{dropout_tag}_fold_"

        aspect_model_files = [
            f for f in os.listdir(sentiment_models_base_dir)
            if f.startswith(prefix) and f.endswith('.keras')
        ]

        if not aspect_model_files:
            print(f"Tidak ditemukan model untuk aspek '{aspek_name}' dengan dropout {dropout_rate}")
            continue

        aspect_model_files = sorted(aspect_model_files, key=get_fold_number)

        print(f"Jumlah model ditemukan : {len(aspect_model_files)}")

        # --------------------------------------------------------
        # LOAD SEMUA MODEL (5-fold) UNTUK DROPOUT INI
        # --------------------------------------------------------

        all_y_pred_probs = []

        for model_file in aspect_model_files:

            full_model_path = os.path.join(sentiment_models_base_dir, model_file)

            try:
                model = load_model(full_model_path)
                y_pred_prob = model.predict(X_test_aspect, verbose=0)
                all_y_pred_probs.append(y_pred_prob)
            except Exception as e:
                print(f"Error model {model_file}: {e}")

        if len(all_y_pred_probs) == 0:
            print("Tidak ada prediksi yang berhasil.")
            continue

        # --------------------------------------------------------
        # ENSEMBLE SOFT VOTING (antar 5 fold, untuk dropout ini)
        # --------------------------------------------------------

        avg_y_pred_prob = np.mean(all_y_pred_probs, axis=0)
        y_pred_ensemble = np.argmax(avg_y_pred_prob, axis=1)

        # --------------------------------------------------------
        # METRICS
        # --------------------------------------------------------

        accuracy = accuracy_score(Y_test_aspect, y_pred_ensemble)
        precision = precision_score(Y_test_aspect, y_pred_ensemble, average='weighted', zero_division=0)
        recall = recall_score(Y_test_aspect, y_pred_ensemble, average='weighted', zero_division=0)
        f1 = f1_score(Y_test_aspect, y_pred_ensemble, average='weighted', zero_division=0)

        all_ensemble_rows.append({
            'aspek': aspek_name,
            'dropout': dropout_rate,
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1_score': f1
        })

        print("\n" + "-"*60)
        print("HASIL EVALUASI ENSEMBLE")
        print("-"*60)

        print(f"Accuracy      : {accuracy:.4f}")
        print(f"Precision     : {precision:.4f}")
        print(f"Recall        : {recall:.4f}")
        print(f"F1-Score      : {f1:.4f}")

        print("\nClassification Report:")
        print(
            classification_report(
                Y_test_aspect,
                y_pred_ensemble,
                target_names=sentiment_target_names,
                zero_division=0
            )
        )

        print("\nConfusion Matrix:")
        print(confusion_matrix(Y_test_aspect, y_pred_ensemble))

# ============================================================
# RINGKASAN SEMUA ASPEK x DROPOUT
# ============================================================

if all_ensemble_rows:
    df_sentiment_dropout_summary = pd.DataFrame(all_ensemble_rows)

    print("\n" + "#"*70)
    print("# RINGKASAN ENSEMBLE SENTIMEN PER ASPEK x DROPOUT")
    print("#"*70)
    display(df_sentiment_dropout_summary.sort_values(by=['aspek', 'accuracy'], ascending=[True, False]))

    print("\n" + "#"*70)
    print("# RATA-RATA AKURASI PER DROPOUT (semua aspek digabung)")
    print("#"*70)
    display(
        df_sentiment_dropout_summary
        .groupby('dropout')[['accuracy', 'precision', 'recall', 'f1_score']]
        .mean()
        .sort_values(by='accuracy', ascending=False)
    )

# ============================================================
# SELESAI
# ============================================================

print("\n")
print("="*70)
print("EVALUASI MODEL SENTIMEN PER ASPEK SELESAI")
print("="*70)
# Out:
# ======================================================================
# EVALUASI ENSEMBLE MODEL SENTIMEN PER ASPEK (per nilai dropout)
# ======================================================================
#
#
# ======================================================================
# EVALUASI ASPEK : fasilitas dan infrastruktur
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
# WARNING:tensorflow:5 out of the last 40 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d3db2d47e20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7d3e1020f100> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.8453
# Precision     : 0.7742
# Recall        : 0.8453
# F1-Score      : 0.8074
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00        15
#      Neutral       0.81      0.80      0.80        44
#     Positive       0.86      0.97      0.91       122
#
#     accuracy                           0.85       181
#    macro avg       0.56      0.59      0.57       181
# weighted avg       0.77      0.85      0.81       181
#
#
# Confusion Matrix:
# [[  0   4  11]
#  [  0  35   9]
#  [  0   4 118]]
#
# ----------------------------------------------------------------------
# ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.7901
# Precision     : 0.7323
# Recall        : 0.7901
# F1-Score      : 0.7436
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00        15
#      Neutral       0.85      0.52      0.65        44
#     Positive       0.78      0.98      0.87       122
#
#     accuracy                           0.79       181
#    macro avg       0.54      0.50      0.51       181
# weighted avg       0.73      0.79      0.74       181
#
#
# Confusion Matrix:
# [[  0   2  13]
#  [  0  23  21]
#  [  0   2 120]]
#
# ----------------------------------------------------------------------
# ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.6740
# Precision     : 0.4543
# Recall        : 0.6740
# F1-Score      : 0.5428
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00        15
#      Neutral       0.00      0.00      0.00        44
#     Positive       0.67      1.00      0.81       122
#
#     accuracy                           0.67       181
#    macro avg       0.22      0.33      0.27       181
# weighted avg       0.45      0.67      0.54       181
#
#
# Confusion Matrix:
# [[  0   0  15]
#  [  0   0  44]
#  [  0   0 122]]
#
#
# ======================================================================
# EVALUASI ASPEK : kualitas pelayanan medis dan staf
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.9259
# Precision     : 0.9182
# Recall        : 0.9259
# F1-Score      : 0.9190
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.50      0.11      0.18         9
#      Neutral       0.89      0.92      0.90       124
#     Positive       0.95      0.96      0.95       245
#
#     accuracy                           0.93       378
#    macro avg       0.78      0.66      0.68       378
# weighted avg       0.92      0.93      0.92       378
#
#
# Confusion Matrix:
# [[  1   5   3]
#  [  0 114  10]
#  [  1   9 235]]
#
# ----------------------------------------------------------------------
# ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.9233
# Precision     : 0.9020
# Recall        : 0.9233
# F1-Score      : 0.9124
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         9
#      Neutral       0.88      0.93      0.90       124
#     Positive       0.95      0.96      0.95       245
#
#     accuracy                           0.92       378
#    macro avg       0.61      0.63      0.62       378
# weighted avg       0.90      0.92      0.91       378
#
#
# Confusion Matrix:
# [[  0   5   4]
#  [  0 115   9]
#  [  0  11 234]]
#
# ----------------------------------------------------------------------
# ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.6825
# Precision     : 0.7418
# Recall        : 0.6825
# F1-Score      : 0.5863
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         9
#      Neutral       0.93      0.11      0.20       124
#     Positive       0.67      1.00      0.80       245
#
#     accuracy                           0.68       378
#    macro avg       0.54      0.37      0.33       378
# weighted avg       0.74      0.68      0.59       378
#
#
# Confusion Matrix:
# [[  0   0   9]
#  [  0  14 110]
#  [  0   1 244]]
#
#
# ======================================================================
# EVALUASI ASPEK : lainnya
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'lainnya' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.8373
# Precision     : 0.8408
# Recall        : 0.8373
# F1-Score      : 0.8360
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.98      0.73      0.84        56
#      Neutral       0.85      0.91      0.88       237
#     Positive       0.77      0.75      0.76       131
#
#     accuracy                           0.84       424
#    macro avg       0.86      0.80      0.82       424
# weighted avg       0.84      0.84      0.84       424
#
#
# Confusion Matrix:
# [[ 41   7   8]
#  [  0 216  21]
#  [  1  32  98]]
#
# ----------------------------------------------------------------------
# ASPEK 'lainnya' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.8278
# Precision     : 0.8315
# Recall        : 0.8278
# F1-Score      : 0.8241
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.64      0.77        56
#      Neutral       0.83      0.93      0.88       237
#     Positive       0.78      0.73      0.75       131
#
#     accuracy                           0.83       424
#    macro avg       0.85      0.77      0.80       424
# weighted avg       0.83      0.83      0.82       424
#
#
# Confusion Matrix:
# [[ 36  10  10]
#  [  0 220  17]
#  [  2  34  95]]
#
# ----------------------------------------------------------------------
# ASPEK 'lainnya' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.5590
# Precision     : 0.3124
# Recall        : 0.5590
# F1-Score      : 0.4008
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00        56
#      Neutral       0.56      1.00      0.72       237
#     Positive       0.00      0.00      0.00       131
#
#     accuracy                           0.56       424
#    macro avg       0.19      0.33      0.24       424
# weighted avg       0.31      0.56      0.40       424
#
#
# Confusion Matrix:
# [[  0  56   0]
#  [  0 237   0]
#  [  0 131   0]]
#
#
# ======================================================================
# EVALUASI ASPEK : waktu tunggu
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'waktu tunggu' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.7547
# Precision     : 0.5696
# Recall        : 0.7547
# F1-Score      : 0.6492
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         4
#      Neutral       0.75      1.00      0.86        40
#     Positive       0.00      0.00      0.00         9
#
#     accuracy                           0.75        53
#    macro avg       0.25      0.33      0.29        53
# weighted avg       0.57      0.75      0.65        53
#
#
# Confusion Matrix:
# [[ 0  4  0]
#  [ 0 40  0]
#  [ 0  9  0]]
#
# ----------------------------------------------------------------------
# ASPEK 'waktu tunggu' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.7547
# Precision     : 0.5696
# Recall        : 0.7547
# F1-Score      : 0.6492
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         4
#      Neutral       0.75      1.00      0.86        40
#     Positive       0.00      0.00      0.00         9
#
#     accuracy                           0.75        53
#    macro avg       0.25      0.33      0.29        53
# weighted avg       0.57      0.75      0.65        53
#
#
# Confusion Matrix:
# [[ 0  4  0]
#  [ 0 40  0]
#  [ 0  9  0]]
#
# ----------------------------------------------------------------------
# ASPEK 'waktu tunggu' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.7547
# Precision     : 0.5696
# Recall        : 0.7547
# F1-Score      : 0.6492
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         4
#      Neutral       0.75      1.00      0.86        40
#     Positive       0.00      0.00      0.00         9
#
#     accuracy                           0.75        53
#    macro avg       0.25      0.33      0.29        53
# weighted avg       0.57      0.75      0.65        53
#
#
# Confusion Matrix:
# [[ 0  4  0]
#  [ 0 40  0]
#  [ 0  9  0]]
#
#
# ======================================================================
# EVALUASI ASPEK : biaya layanan
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'biaya layanan' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.5556
# Precision     : 0.3086
# Recall        : 0.5556
# F1-Score      : 0.3968
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         3
#      Neutral       0.56      1.00      0.71        10
#     Positive       0.00      0.00      0.00         5
#
#     accuracy                           0.56        18
#    macro avg       0.19      0.33      0.24        18
# weighted avg       0.31      0.56      0.40        18
#
#
# Confusion Matrix:
# [[ 0  3  0]
#  [ 0 10  0]
#  [ 0  5  0]]
#
# ----------------------------------------------------------------------
# ASPEK 'biaya layanan' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.5556
# Precision     : 0.3086
# Recall        : 0.5556
# F1-Score      : 0.3968
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         3
#      Neutral       0.56      1.00      0.71        10
#     Positive       0.00      0.00      0.00         5
#
#     accuracy                           0.56        18
#    macro avg       0.19      0.33      0.24        18
# weighted avg       0.31      0.56      0.40        18
#
#
# Confusion Matrix:
# [[ 0  3  0]
#  [ 0 10  0]
#  [ 0  5  0]]
#
# ----------------------------------------------------------------------
# ASPEK 'biaya layanan' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.5556
# Precision     : 0.3086
# Recall        : 0.5556
# F1-Score      : 0.3968
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         3
#      Neutral       0.56      1.00      0.71        10
#     Positive       0.00      0.00      0.00         5
#
#     accuracy                           0.56        18
#    macro avg       0.19      0.33      0.24        18
# weighted avg       0.31      0.56      0.40        18
#
#
# Confusion Matrix:
# [[ 0  3  0]
#  [ 0 10  0]
#  [ 0  5  0]]
#
# ######################################################################
# # RINGKASAN ENSEMBLE SENTIMEN PER ASPEK x DROPOUT
# ######################################################################
#                                 aspek  dropout  accuracy  precision    recall  \
# 12                      biaya layanan      0.2  0.555556   0.308642  0.555556
# 13                      biaya layanan      0.5  0.555556   0.308642  0.555556
# 14                      biaya layanan      0.8  0.555556   0.308642  0.555556
# 0         fasilitas dan infrastruktur      0.2  0.845304   0.774214  0.845304
# 1         fasilitas dan infrastruktur      0.5  0.790055   0.732301  0.790055
# 2         fasilitas dan infrastruktur      0.8  0.674033   0.454321  0.674033
# 3   kualitas pelayanan medis dan staf      0.2  0.925926   0.918240  0.925926
# 4   kualitas pelayanan medis dan staf      0.5  0.923280   0.902011  0.923280
# 5   kualitas pelayanan medis dan staf      0.8  0.682540   0.741843  0.682540
# 6                             lainnya      0.2  0.837264   0.840817  0.837264
# 7                             lainnya      0.5  0.827830   0.831511  0.827830
# 8                             lainnya      0.8  0.558962   0.312439  0.558962
# 9                        waktu tunggu      0.2  0.754717   0.569598  0.754717
# 10                       waktu tunggu      0.5  0.754717   0.569598  0.754717
# 11                       waktu tunggu      0.8  0.754717   0.569598  0.754717
#
#     f1_score
# 12  0.396825
# 13  0.396825
# 14  0.396825
# 0   0.807408
# 1   0.743613
# 2   0.542786
# 3   0.919039
# 4   0.912412
# 5   0.586305
# 6   0.836024
# 7   0.824096
# 8   0.400829
# 9   0.649219
# 10  0.649219
# 11  0.649219
# ######################################################################
# # RATA-RATA AKURASI PER DROPOUT (semua aspek digabung)
# ######################################################################
#          accuracy  precision    recall  f1_score
# dropout
# 0.2      0.783753   0.682302  0.783753  0.721703
# 0.5      0.770288   0.668813  0.770288  0.705233
# 0.8      0.645162   0.477368  0.645162  0.515193
# ======================================================================
# EVALUASI MODEL SENTIMEN PER ASPEK SELESAI
# ======================================================================

# %%
import os
import re
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score

# Define the directory to save the best sentiment models
best_sentiment_models_dir = os.path.join(BASE_DRIVE_PATH, 'best_sentiment_models')
os.makedirs(best_sentiment_models_dir, exist_ok=True)

# Path where individual fold models for each aspect are saved
# Assuming EPOCHS is still defined and correct for the folder name
if 'EPOCHS' not in globals():
    EPOCHS = 5 # Fallback if EPOCHS is not defined
sentiment_models_base_dir = os.path.join(BASE_DRIVE_PATH, f"sentiment_models_per_aspect/epoch_{EPOCHS}")

print("Menyimpan model terbaik untuk setiap klasifikasi sentimen per aspek (lintas semua nilai dropout)...")

def parse_dropout_fold(filename):
    match = re.search(r'dropout_([0-9_]+)_fold_(\d+)\.keras', filename)
    if match:
        return float(match.group(1).replace('_', '.')), int(match.group(2))
    return None, -1

# Iterate through each aspect's split data
if 'split_data_per_aspek' in globals() and split_data_per_aspek:
    for aspek_name, data in split_data_per_aspek.items():
        print(f"\n--- Memproses aspek: {aspek_name} ---")

        # Check if test data exists for this aspect
        if 'X_test_padded' not in data or 'Y_test' not in data:
            print(f"  Tidak ada data uji yang diproses untuk aspek '{aspek_name}'. Melewatkan.")
            continue
        if len(data['Y_test']) == 0:
            print(f"  Data uji kosong untuk aspek '{aspek_name}'. Melewatkan.")
            continue

        X_test_aspect = data['X_test_padded']
        Y_test_aspect = np.array(data['Y_test'])

        # Clean aspect_name for filename matching (replace spaces/slashes with underscores and lowercase)
        cleaned_aspek_name = aspek_name.replace(' ', '_').replace('/', '_').lower()

        # Filter model files for the current aspect (semua nilai dropout & fold)
        aspect_model_files = [
            f for f in os.listdir(sentiment_models_base_dir)
            if f.startswith(f"sentiment_model_{cleaned_aspek_name}_dropout_") and f.endswith('.keras')
        ]

        if not aspect_model_files:
            print(f"  Tidak ditemukan model untuk aspek '{aspek_name}' di '{sentiment_models_base_dir}'.")
            continue

        best_accuracy_for_aspect = -1
        best_model_filename = ""
        best_dropout_for_aspect = None
        best_fold_for_aspect = None

        # Evaluate each model (semua dropout & fold) for the current aspect to find the best one
        for model_file in aspect_model_files:
            full_model_path = os.path.join(sentiment_models_base_dir, model_file)
            try:
                model = load_model(full_model_path)

                # Predict probabilities
                y_pred_prob = model.predict(X_test_aspect, verbose=0)
                # Get predicted classes
                y_pred = np.argmax(y_pred_prob, axis=1)

                # Calculate accuracy
                current_accuracy = accuracy_score(Y_test_aspect, y_pred)

                if current_accuracy > best_accuracy_for_aspect:
                    best_accuracy_for_aspect = current_accuracy
                    best_model_filename = model_file
                    best_dropout_for_aspect, best_fold_for_aspect = parse_dropout_fold(model_file)

            except Exception as e:
                print(f"  Error saat mengevaluasi model '{model_file}': {e}")
                continue

        if best_model_filename:
            source_best_model_path = os.path.join(sentiment_models_base_dir, best_model_filename)
            destination_best_model_path = os.path.join(best_sentiment_models_dir, f"{cleaned_aspek_name}_best_model.keras")

            try:
                # Load the best model again to save it in the new location
                best_model = load_model(source_best_model_path)
                best_model.save(destination_best_model_path)
                print(
                    f"  ✅ Model terbaik untuk aspek '{aspek_name}' "
                    f"(Dropout: {best_dropout_for_aspect}, Fold: {best_fold_for_aspect}, "
                    f"Akurasi: {best_accuracy_for_aspect:.4f}) disimpan sebagai: '{destination_best_model_path}'"
                )
            except Exception as e:
                print(f"  ❌ Error saat menyimpan model terbaik untuk aspek '{aspek_name}': {e}")
        else:
            print(f"  Tidak ada model terbaik yang ditemukan untuk aspek '{aspek_name}'.")

else:
    print("❌ Variabel 'split_data_per_aspek' tidak ditemukan atau kosong. Pastikan data telah dibagi per aspek.")

print("\nProses penyimpanan model terbaik per aspek selesai.")
# Out:
# Menyimpan model terbaik untuk setiap klasifikasi sentimen per aspek (lintas semua nilai dropout)...
#
# --- Memproses aspek: fasilitas dan infrastruktur ---
#   ✅ Model terbaik untuk aspek 'fasilitas dan infrastruktur' (Dropout: 0.2, Fold: 5, Akurasi: 0.8508) disimpan sebagai: '/kaggle/working/EPOCH_05/best_sentiment_models/fasilitas_dan_infrastruktur_best_model.keras'
#
# --- Memproses aspek: kualitas pelayanan medis dan staf ---
#   ✅ Model terbaik untuk aspek 'kualitas pelayanan medis dan staf' (Dropout: 0.2, Fold: 5, Akurasi: 0.9392) disimpan sebagai: '/kaggle/working/EPOCH_05/best_sentiment_models/kualitas_pelayanan_medis_dan_staf_best_model.keras'
#
# --- Memproses aspek: lainnya ---
#   ✅ Model terbaik untuk aspek 'lainnya' (Dropout: 0.2, Fold: 1, Akurasi: 0.8443) disimpan sebagai: '/kaggle/working/EPOCH_05/best_sentiment_models/lainnya_best_model.keras'
#
# --- Memproses aspek: waktu tunggu ---
#   ✅ Model terbaik untuk aspek 'waktu tunggu' (Dropout: 0.8, Fold: 4, Akurasi: 0.7547) disimpan sebagai: '/kaggle/working/EPOCH_05/best_sentiment_models/waktu_tunggu_best_model.keras'
#
# --- Memproses aspek: biaya layanan ---
#   ✅ Model terbaik untuk aspek 'biaya layanan' (Dropout: 0.8, Fold: 1, Akurasi: 0.5556) disimpan sebagai: '/kaggle/working/EPOCH_05/best_sentiment_models/biaya_layanan_best_model.keras'
#
# Proses penyimpanan model terbaik per aspek selesai.
