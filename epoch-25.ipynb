# %% [markdown]
# # CATATAN ADAPTASI UNTUK KAGGLE
#
# Notebook ini awalnya dibuat untuk **Google Colab** (memakai `google.colab.drive` dan folder
# `MyDrive/NEW/...`). Sekarang sudah disesuaikan untuk **Kaggle Notebook**, dengan dataset
# bernama **`new-dataset`** yang isinya SEMUA file (xlsx & pkl) langsung di root dataset —
# **benar-benar flat, tanpa subfolder apapun** (tidak ada `preprocessed_data`, tidak ada
# `processed-data`, tidak ada `experiment_states`, dst).
#
# ## Langkah yang perlu kamu lakukan di Kaggle (sebelum run):
#
# 1. **Dataset `new-dataset` sudah kamu buat di Kaggle** berisi semua file (xlsx & pkl) langsung
#    di root dataset (tidak ada subfolder sama sekali).
# 2. **Tambahkan dataset ke notebook** — klik **+ Add Input** (panel kanan) -> cari `new-dataset`
#    -> **Add**, lalu restart session.
# 3. **Aktifkan GPU** (Settings -> Accelerator -> GPU) karena training dilakukan untuk 3 nilai
#    dropout (0.2, 0.5, 0.8), masing-masing dengan 5-fold K-Fold.
#
# ## Perbaikan di versi ini:
# - Semua pembacaan file dari dataset (`dataset_hasil_labelling_aspek.xlsx`, `aspect_le.pkl`,
#   `sentiment_le.pkl`) sekarang lewat helper `find_input_file(...)` yang mencari file
#   **langsung di root `INPUT_DIR`**, dan otomatis mencari satu tingkat ke bawah kalau ternyata
#   Kaggle tetap membungkusnya dalam folder tambahan. Kalau file benar-benar tidak ada, cell akan
#   menampilkan **isi folder dataset yang sebenarnya** supaya gampang di-debug — bukan cuma error
#   generik.
# - `INPUT_DIR` dideteksi otomatis dari `/kaggle/input` (bukan hardcode `new-dataset` saja), jadi
#   kalau slug dataset kamu sedikit berbeda, notebook tetap jalan dan akan memberi peringatan.
# - `drive.mount(...)` dihapus total (Kaggle tidak pakai Google Drive).
# - Semua path pakai dua variabel utama:
#   - `INPUT_DIR` = dataset Kaggle (read-only, FLAT, tanpa subfolder).
#   - `WORK_DIR` = `/kaggle/working` (semua model, pickle, dataset olahan disimpan di sini;
#     otomatis ikut tersimpan saat kamu klik **Save Version**).
# - `BASE_DRIVE_PATH`, `SAVE_ROOT_PATH` tetap dipakai di cell-cell berikutnya (supaya struktur kode
#   asli tidak perlu diubah total), tapi sekarang jadi subfolder di dalam `WORK_DIR` (writable).
# - **Penting**: `/kaggle/input` bersifat *read-only* — semua hasil (model .keras, tokenizer.pkl,
#   dataset olahan) disimpan ke `/kaggle/working`.
#
# ## Uji coba parameter Dropout (0.2 / 0.5 / 0.8)
# - `DROPOUT_VALUES = [0.2, 0.5, 0.8]` di cell konfigurasi paling atas.
# - Cell training **klasifikasi aspek** dan **sentimen per aspek** melatih model untuk
#   **setiap nilai dropout**, masing-masing dengan 5-fold K-Fold (total training jauh lebih
#   lama — pastikan GPU aktif).
# - Nama file model menyertakan nilai dropout, misal:
#   `aspect_model_dropout_0_2_fold_1.keras`, `sentiment_model_<aspek>_dropout_0_5_fold_3.keras`.
# - Cell evaluasi menampilkan **perbandingan akurasi per nilai dropout** (per fold, rata-rata
#   K-Fold, dan ensemble soft-voting).
# - Model terbaik yang disimpan ke `best_models/` dan `best_sentiment_models/` dipilih dari
#   akurasi tertinggi **lintas semua nilai dropout & fold**.

# %% [markdown]
# #SAVE DATA

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

# %%
import os
from IPython.display import display  # sudah otomatis tersedia di notebook Kaggle, import ini jaga-jaga saja

# ==========================================================
# KONFIGURASI PATH UNTUK KAGGLE
# ==========================================================
# Dataset 'new-dataset' berisi SEMUA file (xlsx & pkl) LANGSUNG di root-nya,
# TIDAK ADA subfolder apapun (tidak ada 'preprocessed_data', tidak ada
# 'processed-data', tidak ada 'experiment_states', dst). Semua file dibaca
# langsung dari INPUT_DIR.

_KAGGLE_INPUT_ROOT = '/kaggle/input'
_PREFERRED_SLUG = 'new-dataset'

if os.path.isdir(_KAGGLE_INPUT_ROOT):
    _available_datasets = sorted(os.listdir(_KAGGLE_INPUT_ROOT))
else:
    _available_datasets = []

if _PREFERRED_SLUG in _available_datasets:
    INPUT_DIR = os.path.join(_KAGGLE_INPUT_ROOT, _PREFERRED_SLUG)
elif _available_datasets:
    # Fallback: kalau slug persis 'new-dataset' tidak ketemu, otomatis pakai
    # dataset pertama yang tersedia supaya notebook tetap bisa jalan.
    INPUT_DIR = os.path.join(_KAGGLE_INPUT_ROOT, _available_datasets[0])
    print(f"Peringatan: slug '{_PREFERRED_SLUG}' tidak ditemukan di /kaggle/input, "
          f"otomatis pakai dataset pertama yang tersedia: '{_available_datasets[0]}'")
else:
    INPUT_DIR = os.path.join(_KAGGLE_INPUT_ROOT, _PREFERRED_SLUG)
    print("Peringatan: /kaggle/input kosong atau tidak ada. Pastikan dataset sudah "
          "ditambahkan lewat '+ Add Input' lalu restart session.")

# WORK_DIR -> folder kerja Kaggle, tempat semua output (model, pickle,
# dataset hasil olahan) disimpan. Isinya otomatis ikut tersimpan saat
# kamu klik "Save Version".
WORK_DIR = '/kaggle/working'
os.makedirs(WORK_DIR, exist_ok=True)

# DROPOUT_VALUES -> daftar nilai dropout yang ingin diuji coba pada
# training LSTM (klasifikasi aspek maupun sentimen per aspek).
DROPOUT_VALUES = [0.2, 0.5, 0.8]

# ==========================================================
# HELPER: cari file di dalam dataset
# ==========================================================
def find_input_file(filename, base_dir=None, required=True):
    """Cari `filename` di dalam base_dir (default INPUT_DIR).
    Dataset SEHARUSNYA flat (file langsung ada di root), tapi helper ini
    tetap mencari satu tingkat ke bawah untuk jaga-jaga. Kalau tidak
    ketemu, isi folder dataset ditampilkan supaya gampang di-debug."""
    base_dir = base_dir or INPUT_DIR

    direct_path = os.path.join(base_dir, filename)
    if os.path.isfile(direct_path):
        return direct_path

    if os.path.isdir(base_dir):
        for root, _dirs, files in os.walk(base_dir):
            if filename in files:
                return os.path.join(root, filename)

    if required:
        print(f"File '{filename}' tidak ditemukan di dalam '{base_dir}'.")
        if os.path.isdir(base_dir):
            print("Isi folder dataset saat ini:")
            found_any = False
            for root, _dirs, files in os.walk(base_dir):
                for f in files:
                    found_any = True
                    print(" -", os.path.relpath(os.path.join(root, f), base_dir))
            if not found_any:
                print(" (folder kosong)")
        else:
            print(f"Folder '{base_dir}' tidak ada sama sekali.")
        raise FileNotFoundError(
            f"'{filename}' tidak ditemukan di '{base_dir}'. Pastikan dataset "
            f"'{_PREFERRED_SLUG}' sudah ditambahkan via '+ Add Input', berisi file ini "
            f"langsung di root, dan session sudah di-restart setelah menambahkannya."
        )
    return None

print(f"Dataset yang terdeteksi di /kaggle/input : {_available_datasets}")
print(f"INPUT_DIR (dataset flat, semua file di root) : {INPUT_DIR}")
print(f"WORK_DIR  (folder kerja / output)             : {WORK_DIR}")
print(f"DROPOUT_VALUES (uji coba dropout)             : {DROPOUT_VALUES}")
# Out:
# Peringatan: slug 'new-dataset' tidak ditemukan di /kaggle/input, otomatis pakai dataset pertama yang tersedia: 'datasets'
# Dataset yang terdeteksi di /kaggle/input : ['datasets']
# INPUT_DIR (dataset flat, semua file di root) : /kaggle/input/datasets
# WORK_DIR  (folder kerja / output)             : /kaggle/working
# DROPOUT_VALUES (uji coba dropout)             : [0.2, 0.5, 0.8]

# %%
import os

# Sebelumnya ada DUA folder root berbeda (BASE_DRIVE_PATH = 'epoch_lima' dan
# SAVE_ROOT_PATH = 'EPOCH 05'), sehingga model, tokenizer, dan dataset olahan
# tersebar di dua tempat berbeda. Sekarang disatukan jadi SATU folder saja:
# WORK_DIR/EPOCH_15 -- dipakai bersama oleh BASE_DRIVE_PATH & SAVE_ROOT_PATH.
BASE_DRIVE_PATH = os.path.join(WORK_DIR, 'EPOCH_25')
SAVE_ROOT_PATH = BASE_DRIVE_PATH  # alias, disatukan supaya tidak ada folder duplikat

os.makedirs(BASE_DRIVE_PATH, exist_ok=True)
os.makedirs(os.path.join(BASE_DRIVE_PATH, 'experiment_states'), exist_ok=True)

print(f"Base path (disatukan) untuk semua output disetel ke: {BASE_DRIVE_PATH}")
# Out:
# Base path (disatukan) untuk semua output disetel ke: /kaggle/working/EPOCH_25

# %%
import pandas as pd
import os

# Dataset 'new-dataset' FLAT -> file langsung ada di root INPUT_DIR (tidak ada
# subfolder 'preprocessed_data' / 'processed-data' sama sekali).
# PREPROCESSED_DATA_DIR dipertahankan sebagai alias supaya cell-cell
# berikutnya tidak perlu diubah strukturnya.
PREPROCESSED_DATA_DIR = INPUT_DIR
# CATATAN: /kaggle/input bersifat READ-ONLY -> tidak perlu (dan tidak bisa) os.makedirs di sini.

try:
    file_path_to_load = find_input_file("dataset_hasil_labelling_aspek.xlsx", base_dir=PREPROCESSED_DATA_DIR)
    print(f"Mencoba memuat file dari: {file_path_to_load}")

    df_loaded = pd.read_excel(file_path_to_load)

    print("File berhasil dimuat! Berikut adalah 5 baris pertama:")
    display(df_loaded.head())

except FileNotFoundError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"Terjadi kesalahan saat memuat file: {e}")
# Out:
# Mencoba memuat file dari: /kaggle/input/datasets/mellychanwardani/new-dataset/dataset_hasil_labelling_aspek.xlsx
# File berhasil dimuat! Berikut adalah 5 baris pertama:
#    Original_Review_ID                                             Review  \
# 0                   0  Ruang flamboyan rumah sakit mitra keluarga dar...
# 1                   1  Ruang flamboyan rumah sakit mitra keluarga dar...
# 2                   2  nilai plusnya -dekat dari rumah -obat yang dib...
# 3                   3                           Pelayanan baik memuaskan
# 4                   4  Dirawat inap di kamar Flamboyan, setelah opera...
#
#   Extracted_Opinion      Translated_Opinion  Cleaned_Opinion  \
# 0       kamar penuh               full room      kamar penuh
# 1     perawat ramah          friendly nurse    perawat ramah
# 2   kebetulan cocok  coincidentally matched  kebetulan cocok
# 3    Pelayanan baik            Good service   Pelayanan baik
# 4      tenaga medis       medical personnel     tenaga medis
#
#   Casefolded_Opinion       Tokenized_Opinion Vader_Sentiment_Category  \
# 0        kamar penuh      ['kamar', 'penuh']                  Neutral
# 1      perawat ramah    ['perawat', 'ramah']                 Positive
# 2    kebetulan cocok  ['kebetulan', 'cocok']                  Neutral
# 3     pelayanan baik   ['pelayanan', 'baik']                 Positive
# 4       tenaga medis     ['tenaga', 'medis']                  Neutral
#
#    Sentiment_encoded                              Aspek  Aspek_encoded
# 0                  1        fasilitas dan infrastruktur              1
# 1                  2  kualitas pelayanan medis dan staf              2
# 2                  1                            lainnya              3
# 3                  2  kualitas pelayanan medis dan staf              2
# 4                  1  kualitas pelayanan medis dan staf              2

# %%
import os
import pandas as pd

# Ensure SAVE_ROOT_PATH is defined (it should be from previous cells)
if 'SAVE_ROOT_PATH' not in globals():
    SAVE_ROOT_PATH = os.path.join(WORK_DIR, 'EPOCH_25')  # Fallback value if not defined (disatukan dengan BASE_DRIVE_PATH)
    print("Warning: SAVE_ROOT_PATH not found, using default fallback path.")

# Define the directory where you want to save the file
save_directory = SAVE_ROOT_PATH

# Ensure the save directory exists
os.makedirs(save_directory, exist_ok=True)

# Define the full path for the output file
output_file_path = os.path.join(save_directory, 'dataset_hasil_labelling_aspek.xlsx')

# Check if df_loaded exists and is a DataFrame before saving
if 'df_loaded' in globals() and isinstance(df_loaded, pd.DataFrame):
    try:
        # Save the DataFrame to an Excel file
        df_loaded.to_excel(output_file_path, index=False)
        print(f"✅ Dataset 'dataset_hasil_labelling_aspek' berhasil disimpan ke: {output_file_path}")
    except Exception as e:
        print(f"❌ Terjadi kesalahan saat menyimpan file: {e}")
else:
    print("❌ DataFrame 'df_loaded' tidak ditemukan atau bukan DataFrame. Pastikan telah dimuat sebelumnya.")
# Out:
# ✅ Dataset 'dataset_hasil_labelling_aspek' berhasil disimpan ke: /kaggle/working/EPOCH_25/dataset_hasil_labelling_aspek.xlsx

# %%
# !pip install -q scikit-learn==1.8.0
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 62.7 MB/s eta 0:00:0000:0100:01

# %%
import os
import pickle
from sklearn.preprocessing import LabelEncoder  # Import LabelEncoder for potential fallback initialization

# aspect_le.pkl & sentiment_le.pkl diharapkan ada LANGSUNG di root dataset
# 'new-dataset' (flat, tanpa subfolder 'experiment_states').
EXPERIMENT_STATES_DIR = INPUT_DIR  # alias, dipertahankan untuk kompatibilitas
# CATATAN: /kaggle/input bersifat READ-ONLY -> tidak perlu os.makedirs di sini.

# --- Load aspect_le.pkl ---
aspect_le = None  # Initialize aspect_le
try:
    aspect_le_path = find_input_file('aspect_le.pkl', base_dir=EXPERIMENT_STATES_DIR)
    with open(aspect_le_path, 'rb') as f:
        aspect_le = pickle.load(f)
    print(f"'aspect_le.pkl' berhasil dimuat dari: {aspect_le_path}")
    print(f"Kelas aspek yang dimuat: {aspect_le.classes_}")
except FileNotFoundError as e:
    print(f"Error: {e}")
    # Optionally, initialize with a dummy LabelEncoder if file not found
    aspect_le = LabelEncoder()
except Exception as e:
    print(f"Terjadi kesalahan saat memuat 'aspect_le.pkl': {e}")
    aspect_le = LabelEncoder()

# --- Load sentiment_le.pkl ---
sentiment_le = None  # Initialize sentiment_le
try:
    sentiment_le_path = find_input_file('sentiment_le.pkl', base_dir=EXPERIMENT_STATES_DIR)
    with open(sentiment_le_path, 'rb') as f:
        sentiment_le = pickle.load(f)
    print(f"'sentiment_le.pkl' berhasil dimuat dari: {sentiment_le_path}")
    print(f"Kelas sentimen yang dimuat: {sentiment_le.classes_}")
except FileNotFoundError as e:
    print(f"Error: {e}")
    # Optionally, initialize with a dummy LabelEncoder if file not found
    sentiment_le = LabelEncoder()
except Exception as e:
    print(f"Terjadi kesalahan saat memuat 'sentiment_le.pkl': {e}")
    sentiment_le = LabelEncoder()
# Out:
# 'aspect_le.pkl' berhasil dimuat dari: /kaggle/input/datasets/mellychanwardani/new-dataset/aspect_le.pkl
# Kelas aspek yang dimuat: ['biaya layanan' 'fasilitas dan infrastruktur'
#  'kualitas pelayanan medis dan staf' 'lainnya' 'waktu tunggu']
# 'sentiment_le.pkl' berhasil dimuat dari: /kaggle/input/datasets/mellychanwardani/new-dataset/sentiment_le.pkl
# Kelas sentimen yang dimuat: ['Negative' 'Neutral' 'Positive']

# %%
import pickle
import os

# Ensure EXPERIMENT_DIR_FULL_PATH is defined and correct
if 'EXPERIMENT_DIR_FULL_PATH' not in globals():
    # Fallback if EXPERIMENT_DIR_FULL_PATH somehow wasn't defined
    SAVE_ROOT_PATH = os.path.join(WORK_DIR, 'EPOCH_25')
    EXPERIMENT_DIR_FULL_PATH = os.path.join(SAVE_ROOT_PATH, 'experiment_states')
    os.makedirs(EXPERIMENT_DIR_FULL_PATH, exist_ok=True)
    print("Warning: EXPERIMENT_DIR_FULL_PATH not defined, using default fallback path.")

# Save aspect_le.pkl
if 'aspect_le' in globals():
    aspect_le_save_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'aspect_le.pkl')
    with open(aspect_le_save_path, "wb") as f:
        pickle.dump(aspect_le, f)
    print(f"'aspect_le.pkl' saved successfully to: '{aspect_le_save_path}'")
else:
    print("Error: 'aspect_le' object not found in current session. Not saving aspect_le.pkl.")

# Save sentiment_le.pkl
if 'sentiment_le' in globals():
    sentiment_le_save_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'sentiment_le.pkl')
    with open(sentiment_le_save_path, "wb") as f:
        pickle.dump(sentiment_le, f)
    print(f"'sentiment_le.pkl' saved successfully to: '{sentiment_le_save_path}'")
else:
    print("Error: 'sentiment_le' object not found in current session. Not saving sentiment_le.pkl.")
# Out:
# Warning: EXPERIMENT_DIR_FULL_PATH not defined, using default fallback path.
# 'aspect_le.pkl' saved successfully to: '/kaggle/working/EPOCH_25/experiment_states/aspect_le.pkl'
# 'sentiment_le.pkl' saved successfully to: '/kaggle/working/EPOCH_25/experiment_states/sentiment_le.pkl'

# %% [markdown]
# #KLASIFIKASI ASPEK

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

# Ensure PREPROCESSED_DATA_DIR is defined
# (It should be defined in previous cells, but we ensure its availability)
if 'PREPROCESSED_DATA_DIR' not in globals():
    # Dataset Kaggle diupload FLAT (tanpa subfolder) -> langsung pakai INPUT_DIR
    print("Warning: PREPROCESSED_DATA_DIR not found, falling back to INPUT_DIR.")
    PREPROCESSED_DATA_DIR = INPUT_DIR

df_data = pd.read_excel(find_input_file('dataset_hasil_labelling_aspek.xlsx', base_dir=PREPROCESSED_DATA_DIR))
X_data = df_data[['Tokenized_Opinion']]
Y_aspect_data = df_data['Aspek_encoded']
Y_sentiment_data = df_data['Sentiment_encoded']

X_train_full, X_test_full, Y_train_aspect, Y_test_aspect = train_test_split(
    X_data,
    Y_aspect_data,
    test_size=0.2,
    random_state=42,
    stratify=Y_aspect_data
)

Y_train_sent = Y_sentiment_data.loc[X_train_full.index]
Y_test_sent = Y_sentiment_data.loc[X_test_full.index]

print("--- Hasil Split ---")
print("Data Training:", X_train_full.shape[0], "baris")
print("Data Testing:", X_test_full.shape[0], "baris")
# Out:
# --- Hasil Split ---
# Data Training: 4204 baris
# Data Testing: 1051 baris

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import ast
import os
import pickle

def ensure_list(text):
    if isinstance(text, str) and text.startswith('['):
        try:
            return ast.literal_eval(text)
        except (ValueError, SyntaxError):
            return []
    elif isinstance(text, list):
        return text
    return []

X_train_texts = X_train_full['Tokenized_Opinion'].apply(ensure_list).apply(lambda x: ' '.join(x) if x else '')
X_test_texts = X_test_full['Tokenized_Opinion'].apply(ensure_list).apply(lambda x: ' '.join(x) if x else '')

print(f"  Training samples (X_train_texts): {len(X_train_texts)}")
print(f"  Testing samples (X_test_texts): {len(X_test_texts)}")
print(f"  Example X_train_texts (first row): {X_train_texts.head(1).iloc[0]}")

# Tokenizer
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train_texts)  # fit only on training data texts

# Convert texts to sequences of indices
X_train_seq = tokenizer.texts_to_sequences(X_train_texts)
X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

# Padding
maxlen = 20  # Max length for sequences
X_train_pad = pad_sequences(X_train_seq, maxlen=maxlen, padding='post', truncating='post')
X_test_pad = pad_sequences(X_test_seq, maxlen=maxlen, padding='post', truncating='post')

# Info results
print("Tokenization & Padding complete.")
print(f"  Vocabulary size   : {len(tokenizer.word_index)} unique words")
print(f"  Train data shape  : {X_train_pad.shape}")
print(f"  Test data shape   : {X_test_pad.shape}")

if X_train_seq:
    print(f"  Example first train sequence (first 20 tokens):\n{X_train_seq[0][:20]}")
else:
    print("  No training sequences generated.")

# Save tokenizer ke WORK_DIR (Kaggle)
# SAVE_ROOT_PATH sudah disatukan dengan BASE_DRIVE_PATH di cell konfigurasi
# (WORK_DIR/EPOCH_05), jadi tidak perlu didefinisikan ulang ke folder lain.
if 'SAVE_ROOT_PATH' not in globals():
    SAVE_ROOT_PATH = os.path.join(WORK_DIR, 'EPOCH_05')
EXPERIMENT_DIR_FULL_PATH = os.path.join(SAVE_ROOT_PATH, 'experiment_states')

os.makedirs(EXPERIMENT_DIR_FULL_PATH, exist_ok=True)
tokenizer_save_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'tokenizer_lstm.pkl')
with open(tokenizer_save_path, "wb") as f:
    pickle.dump(tokenizer, f)
print(f"Tokenizer saved to '{tokenizer_save_path}'")
# Out:
#   Training samples (X_train_texts): 4204
#   Testing samples (X_test_texts): 1051
#   Example X_train_texts (first row): sakit sebelah perlu rujukan
# Tokenization & Padding complete.
#   Vocabulary size   : 1503 unique words
#   Train data shape  : (4204, 20)
#   Test data shape   : (1051, 20)
#   Example first train sequence (first 20 tokens):
# [3, 380, 241, 323]
# Tokenizer saved to '/kaggle/working/EPOCH_25/experiment_states/tokenizer_lstm.pkl'

# %%
import pickle
from sklearn.preprocessing import LabelEncoder

# Load the aspect label encoder from the drive
aspect_le_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'aspect_le.pkl') # Corrected: consistency with 'sentiment_le.pkl' to match global testing

try:
    with open(aspect_le_path, 'rb') as f:
        aspect_le = pickle.load(f)
    print(f"Aspect LabelEncoder loaded from '{aspect_le_path}'")
    print(f"Number of aspect classes: {len(aspect_le.classes_)}")
except FileNotFoundError:
    print(f"Error: '{aspect_le_path}' not found. Please ensure the aspect label encoder is saved at this location.")
    aspect_le = LabelEncoder()
    if 'df_data' in globals():
        aspect_le.fit(df_data['Aspek'])
        print("Warning: Aspect LabelEncoder not found, a new one was created from df_data['Aspek']. Please ensure this is the intended behavior.")
        print(f"Number of aspect classes (newly created): {len(aspect_le.classes_)}")
    else:
        print("Error: df_data not found to create aspect_le. Please check previous cells.")

# Load or create the sentiment label encoder
sentiment_le_path = os.path.join(EXPERIMENT_DIR_FULL_PATH, 'sentiment_le.pkl') # Corrected: consistent naming with saving in Lx5RY78R5SW4 and loading in f11050e1

try:
    with open(sentiment_le_path, 'rb') as f:
        sentiment_le = pickle.load(f)
    print(f"Sentiment LabelEncoder loaded from '{sentiment_le_path}'")
    print(f"Sentiment classes: {sentiment_le.classes_}")
except FileNotFoundError:
    print(f"Error: '{sentiment_le_path}' not found. Please ensure the sentiment label encoder is saved at this location.")
    sentiment_le = LabelEncoder()
    if 'df_data' in globals():
        sentiment_le.fit(df_data['Vader_Sentiment_Category'])
        print("Warning: Sentiment LabelEncoder not found, a new one was created from df_data['Vader_Sentiment_Category']. Please ensure this is the intended behavior.")
        print(f"Sentiment classes (newly created): {sentiment_le.classes_}")
        # Optionally save it for future runs
        try:
            with open(sentiment_le_path, "wb") as f:
                pickle.dump(sentiment_le, f)
            print(f"Newly created Sentiment LabelEncoder saved to '{sentiment_le_path}'")
        except Exception as e:
            print(f"Could not save sentiment_le to drive: {e}")
    else:
        print("Error: df_data not found to create sentiment_le. Please check previous cells.")
# Out:
# Aspect LabelEncoder loaded from '/kaggle/working/EPOCH_25/experiment_states/aspect_le.pkl'
# Number of aspect classes: 5
# Sentiment LabelEncoder loaded from '/kaggle/working/EPOCH_25/experiment_states/sentiment_le.pkl'
# Sentiment classes: ['Negative' 'Neutral' 'Positive']

# %%
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
# from tensorflow.keras.callbacks import EarlyStopping # Removed EarlyStopping

import numpy as np
import tensorflow as tf
import random
import os # Added os import for saving models correctly

# =========================
# RANDOM SEED
# =========================
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# =========================
# PARAMETER
# =========================
vocab_size = 5000
max_len = 20
num_classes = len(aspect_le.classes_)

EPOCHS = 25

# =========================
# PARAMETER UJI COBA DROPOUT
# =========================
# DROPOUT_VALUES didefinisikan di cell konfigurasi paling atas.
# Kalau belum ada (misal cell konfigurasi belum dijalankan), fallback ke default berikut.
if 'DROPOUT_VALUES' not in globals():
    DROPOUT_VALUES = [0.2, 0.5, 0.8]

print(f"Dropout yang akan diuji untuk klasifikasi aspek: {DROPOUT_VALUES}")

# =========================
# KFOLD
# =========================
skf = KFold(
    n_splits=5,
    shuffle=True,
    random_state=SEED
)

# Define directory for saving models
model_save_dir = os.path.join(BASE_DRIVE_PATH, 'aspect_classification_models')
os.makedirs(model_save_dir, exist_ok=True)

# Menyimpan ringkasan rata-rata akurasi per nilai dropout
dropout_summary = []

# =========================
# LOOP TIAP NILAI DROPOUT
# =========================
for dropout_rate in DROPOUT_VALUES:

    dropout_tag = str(dropout_rate).replace('.', '_')

    print("\n" + "#"*60)
    print(f"# TRAINING KLASIFIKASI ASPEK DENGAN DROPOUT = {dropout_rate}")
    print("#"*60)

    print("="*60)
    print(f"TRAINING DENGAN MAX EPOCH = {EPOCHS}")
    print("="*60)

    # best_val_loss = float('inf') # Removed as EarlyStopping is removed
    fold_no = 1

    fold_accuracies = []

    # =========================
    # KFOLD LOOP
    # =========================
    for train_index, val_index in skf.split(X_train_pad, Y_train_aspect):

        print(f"\n====== Dropout {dropout_rate} | Fold {fold_no} ======")

        # =========================
        # SPLIT DATA
        # =========================
        X_tr = X_train_pad[train_index]
        X_val = X_train_pad[val_index]

        y_tr = Y_train_aspect.iloc[train_index]
        y_val = Y_train_aspect.iloc[val_index]

        # =========================
        # MODEL
        # =========================
        model = Sequential([

            Embedding(
                input_dim=vocab_size,
                output_dim=128,
                mask_zero=True
            ),

            LSTM(
                128,
                return_sequences=True,
                dropout=dropout_rate,
                recurrent_dropout=dropout_rate
            ),

            LSTM(
                64,
                dropout=dropout_rate,
                recurrent_dropout=dropout_rate
            ),

            Dense(128, activation='relu'),

            Dropout(dropout_rate),

            Dense(num_classes, activation='softmax')
        ])

        # =========================
        # COMPILE
        # =========================
        model.compile(
            optimizer=Adam(learning_rate=0.0005),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        # =========================
        # EARLY STOPPING - REMOVED
        # =========================
        # early_stopping = EarlyStopping(
        #     monitor='val_loss',
        #     patience=2,
        #     restore_best_weights=True,
        #     verbose=1
        # )

        # =========================
        # TRAINING
        # =========================
        history = model.fit(
            X_tr,
            y_tr,
            epochs=EPOCHS,
            batch_size=32,
            validation_data=(X_val, y_val),
            # callbacks=[early_stopping], # Removed early_stopping from callbacks
            verbose=1
        )

        # =========================
        # EVALUASI
        # =========================
        scores = model.evaluate(
            X_val,
            y_val,
            verbose=0
        )

        print(f"\nDropout {dropout_rate} | Fold {fold_no}")
        print(f"Loss     : {scores[0]:.4f}")
        print(f"Accuracy : {scores[1]:.4f}")

        fold_accuracies.append(scores[1])

        # =========================
        # SAVE MODEL FOR EACH FOLD
        # =========================
        # Nama file sekarang menyertakan nilai dropout supaya tiap konfigurasi
        # bisa dibandingkan pada cell evaluasi berikutnya.
        model_filename = os.path.join(
            model_save_dir,
            f"aspect_model_dropout_{dropout_tag}_fold_{fold_no}.keras"
        )
        model.save(model_filename)
        print(f"Model for Dropout {dropout_rate} Fold {fold_no} saved to: {model_filename}")

        fold_no += 1

    # =========================
    # RATA-RATA AKURASI UNTUK DROPOUT INI
    # =========================
    avg_acc = np.mean(fold_accuracies)
    dropout_summary.append({'dropout': dropout_rate, 'avg_accuracy': avg_acc})

    print("\n" + "="*60)
    print(f"HASIL AKHIR DROPOUT = {dropout_rate}")
    print("="*60)

    print(f"Average Accuracy : {avg_acc:.4f}")

# =========================
# RINGKASAN PERBANDINGAN SEMUA DROPOUT
# =========================
print("\n" + "#"*60)
print("# RINGKASAN PERBANDINGAN DROPOUT (Klasifikasi Aspek)")
print("#"*60)
for row in dropout_summary:
    print(f"Dropout {row['dropout']}: rata-rata accuracy (K-Fold) = {row['avg_accuracy']:.4f}")
# Out:
# Dropout yang akan diuji untuk klasifikasi aspek: [0.2, 0.5, 0.8]
#
# ############################################################
# # TRAINING KLASIFIKASI ASPEK DENGAN DROPOUT = 0.2
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 25
# ============================================================
#
# ====== Dropout 0.2 | Fold 1 ======
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782928099.059231      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1782928099.065110      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 28s 143ms/step - accuracy: 0.6408 - loss: 1.1681 - val_accuracy: 0.8098 - val_loss: 0.6995
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.8891 - loss: 0.4208 - val_accuracy: 0.9144 - val_loss: 0.3001
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9575 - loss: 0.1535 - val_accuracy: 0.9489 - val_loss: 0.1861
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9712 - loss: 0.0843 - val_accuracy: 0.9560 - val_loss: 0.1463
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9786 - loss: 0.0515 - val_accuracy: 0.9631 - val_loss: 0.1198
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9875 - loss: 0.0361 - val_accuracy: 0.9727 - val_loss: 0.1003
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9932 - loss: 0.0254 - val_accuracy: 0.9774 - val_loss: 0.0786
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9955 - loss: 0.0168 - val_accuracy: 0.9845 - val_loss: 0.0675
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9970 - loss: 0.0109 - val_accuracy: 0.9822 - val_loss: 0.0710
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9979 - loss: 0.0083 - val_accuracy: 0.9845 - val_loss: 0.0653
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9991 - loss: 0.0054 - val_accuracy: 0.9857 - val_loss: 0.0651
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9991 - loss: 0.0041 - val_accuracy: 0.9869 - val_loss: 0.0632
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9961 - loss: 0.0141 - val_accuracy: 0.9822 - val_loss: 0.0754
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9970 - loss: 0.0105 - val_accuracy: 0.9786 - val_loss: 0.0757
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9994 - loss: 0.0032 - val_accuracy: 0.9810 - val_loss: 0.0711
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9994 - loss: 0.0023 - val_accuracy: 0.9822 - val_loss: 0.0692
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9994 - loss: 0.0018 - val_accuracy: 0.9810 - val_loss: 0.0687
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9810 - val_loss: 0.0743
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9976 - loss: 0.0102 - val_accuracy: 0.9869 - val_loss: 0.0676
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9991 - loss: 0.0036 - val_accuracy: 0.9893 - val_loss: 0.0561
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9869 - val_loss: 0.0598
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9994 - loss: 0.0014 - val_accuracy: 0.9881 - val_loss: 0.0591
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9893 - val_loss: 0.0571
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 1.0000 - loss: 4.9432e-04 - val_accuracy: 0.9881 - val_loss: 0.0581
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9997 - loss: 0.0011 - val_accuracy: 0.9881 - val_loss: 0.0599
#
# Dropout 0.2 | Fold 1
# Loss     : 0.0599
# Accuracy : 0.9881
# Model for Dropout 0.2 Fold 1 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_2_fold_1.keras
#
# ====== Dropout 0.2 | Fold 2 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 23s 142ms/step - accuracy: 0.6438 - loss: 1.1637 - val_accuracy: 0.8074 - val_loss: 0.6600
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.8799 - loss: 0.4434 - val_accuracy: 0.9227 - val_loss: 0.2779
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9387 - loss: 0.1721 - val_accuracy: 0.9477 - val_loss: 0.1890
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9694 - loss: 0.0872 - val_accuracy: 0.9572 - val_loss: 0.1534
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9762 - loss: 0.0565 - val_accuracy: 0.9620 - val_loss: 0.1427
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9848 - loss: 0.0430 - val_accuracy: 0.9655 - val_loss: 0.1368
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9926 - loss: 0.0269 - val_accuracy: 0.9679 - val_loss: 0.1349
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9955 - loss: 0.0175 - val_accuracy: 0.9727 - val_loss: 0.1244
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.9973 - loss: 0.0128 - val_accuracy: 0.9738 - val_loss: 0.1142
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9949 - loss: 0.0158 - val_accuracy: 0.9727 - val_loss: 0.1315
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9979 - loss: 0.0105 - val_accuracy: 0.9798 - val_loss: 0.1116
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9964 - loss: 0.0137 - val_accuracy: 0.9774 - val_loss: 0.1063
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9786 - val_loss: 0.1001
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9786 - val_loss: 0.1040
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9798 - val_loss: 0.1041
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9994 - loss: 0.0022 - val_accuracy: 0.9798 - val_loss: 0.1043
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9822 - val_loss: 0.1015
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.9822 - val_loss: 0.1021
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9994 - loss: 0.0015 - val_accuracy: 0.9822 - val_loss: 0.1068
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9810 - val_loss: 0.1133
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 0.9798 - val_loss: 0.1119
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 0.9810 - val_loss: 0.1063
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 1.0000 - loss: 3.9217e-04 - val_accuracy: 0.9810 - val_loss: 0.1069
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 1.0000 - loss: 3.4243e-04 - val_accuracy: 0.9810 - val_loss: 0.1089
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9997 - loss: 8.0599e-04 - val_accuracy: 0.9810 - val_loss: 0.1086
#
# Dropout 0.2 | Fold 2
# Loss     : 0.1086
# Accuracy : 0.9810
# Model for Dropout 0.2 Fold 2 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_2_fold_2.keras
#
# ====== Dropout 0.2 | Fold 3 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.6461 - loss: 1.1721 - val_accuracy: 0.8407 - val_loss: 0.6727
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.8956 - loss: 0.4108 - val_accuracy: 0.9037 - val_loss: 0.3076
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9411 - loss: 0.1778 - val_accuracy: 0.9382 - val_loss: 0.1847
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9688 - loss: 0.0909 - val_accuracy: 0.9512 - val_loss: 0.1480
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9756 - loss: 0.0605 - val_accuracy: 0.9596 - val_loss: 0.1376
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9828 - loss: 0.0430 - val_accuracy: 0.9620 - val_loss: 0.1339
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9851 - loss: 0.0343 - val_accuracy: 0.9620 - val_loss: 0.1326
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9896 - loss: 0.0265 - val_accuracy: 0.9608 - val_loss: 0.1499
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9929 - loss: 0.0245 - val_accuracy: 0.9703 - val_loss: 0.1244
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9961 - loss: 0.0159 - val_accuracy: 0.9703 - val_loss: 0.1198
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9979 - loss: 0.0115 - val_accuracy: 0.9679 - val_loss: 0.1461
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9979 - loss: 0.0080 - val_accuracy: 0.9643 - val_loss: 0.1372
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9985 - loss: 0.0058 - val_accuracy: 0.9691 - val_loss: 0.1471
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9976 - loss: 0.0066 - val_accuracy: 0.9643 - val_loss: 0.1439
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9691 - val_loss: 0.1484
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9994 - loss: 0.0036 - val_accuracy: 0.9691 - val_loss: 0.1529
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 140ms/step - accuracy: 0.9985 - loss: 0.0061 - val_accuracy: 0.9703 - val_loss: 0.1628
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 140ms/step - accuracy: 0.9985 - loss: 0.0042 - val_accuracy: 0.9691 - val_loss: 0.1704
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 143ms/step - accuracy: 0.9991 - loss: 0.0028 - val_accuracy: 0.9679 - val_loss: 0.1710
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9715 - val_loss: 0.1645
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 0.9679 - val_loss: 0.1737
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9985 - loss: 0.0072 - val_accuracy: 0.9691 - val_loss: 0.1912
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9979 - loss: 0.0107 - val_accuracy: 0.9715 - val_loss: 0.1487
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9961 - loss: 0.0097 - val_accuracy: 0.9786 - val_loss: 0.1234
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9985 - loss: 0.0065 - val_accuracy: 0.9786 - val_loss: 0.1310
#
# Dropout 0.2 | Fold 3
# Loss     : 0.1310
# Accuracy : 0.9786
# Model for Dropout 0.2 Fold 3 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_2_fold_3.keras
#
# ====== Dropout 0.2 | Fold 4 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - accuracy: 0.6539 - loss: 1.1674 - val_accuracy: 0.8454 - val_loss: 0.6271
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.8986 - loss: 0.4227 - val_accuracy: 0.9239 - val_loss: 0.2524
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9512 - loss: 0.1606 - val_accuracy: 0.9536 - val_loss: 0.1391
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9685 - loss: 0.0830 - val_accuracy: 0.9679 - val_loss: 0.1149
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9780 - loss: 0.0538 - val_accuracy: 0.9655 - val_loss: 0.1058
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9890 - loss: 0.0331 - val_accuracy: 0.9691 - val_loss: 0.0918
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9944 - loss: 0.0214 - val_accuracy: 0.9691 - val_loss: 0.0803
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9944 - loss: 0.0171 - val_accuracy: 0.9715 - val_loss: 0.0777
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9920 - loss: 0.0412 - val_accuracy: 0.9715 - val_loss: 0.0764
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9964 - loss: 0.0114 - val_accuracy: 0.9750 - val_loss: 0.0814
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9979 - loss: 0.0080 - val_accuracy: 0.9750 - val_loss: 0.0816
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9979 - loss: 0.0059 - val_accuracy: 0.9750 - val_loss: 0.0810
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9982 - loss: 0.0061 - val_accuracy: 0.9750 - val_loss: 0.0832
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9994 - loss: 0.0039 - val_accuracy: 0.9750 - val_loss: 0.0843
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9985 - loss: 0.0040 - val_accuracy: 0.9762 - val_loss: 0.0874
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9991 - loss: 0.0025 - val_accuracy: 0.9762 - val_loss: 0.0877
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9994 - loss: 0.0027 - val_accuracy: 0.9762 - val_loss: 0.0888
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.9988 - loss: 0.0028 - val_accuracy: 0.9762 - val_loss: 0.0948
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9985 - loss: 0.0032 - val_accuracy: 0.9715 - val_loss: 0.1206
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9786 - val_loss: 0.1047
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9997 - loss: 0.0014 - val_accuracy: 0.9786 - val_loss: 0.1059
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 140ms/step - accuracy: 0.9988 - loss: 0.0029 - val_accuracy: 0.9786 - val_loss: 0.1051
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 1.0000 - loss: 7.8857e-04 - val_accuracy: 0.9798 - val_loss: 0.1013
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 141ms/step - accuracy: 0.9997 - loss: 9.4496e-04 - val_accuracy: 0.9798 - val_loss: 0.1046
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9991 - loss: 0.0016 - val_accuracy: 0.9774 - val_loss: 0.1039
#
# Dropout 0.2 | Fold 4
# Loss     : 0.1039
# Accuracy : 0.9774
# Model for Dropout 0.2 Fold 4 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_2_fold_4.keras
#
# ====== Dropout 0.2 | Fold 5 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 23s 148ms/step - accuracy: 0.5779 - loss: 1.2011 - val_accuracy: 0.7917 - val_loss: 0.7244
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.8861 - loss: 0.4226 - val_accuracy: 0.9214 - val_loss: 0.2864
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9548 - loss: 0.1547 - val_accuracy: 0.9619 - val_loss: 0.1616
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.9729 - loss: 0.0772 - val_accuracy: 0.9607 - val_loss: 0.1382
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.9777 - loss: 0.0596 - val_accuracy: 0.9595 - val_loss: 0.1282
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9819 - loss: 0.0441 - val_accuracy: 0.9607 - val_loss: 0.1197
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.9866 - loss: 0.0324 - val_accuracy: 0.9690 - val_loss: 0.1101
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9932 - loss: 0.0268 - val_accuracy: 0.9714 - val_loss: 0.1200
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9938 - loss: 0.0202 - val_accuracy: 0.9774 - val_loss: 0.0913
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9970 - loss: 0.0126 - val_accuracy: 0.9810 - val_loss: 0.0847
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.9985 - loss: 0.0077 - val_accuracy: 0.9833 - val_loss: 0.0875
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9982 - loss: 0.0070 - val_accuracy: 0.9833 - val_loss: 0.0794
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9988 - loss: 0.0052 - val_accuracy: 0.9821 - val_loss: 0.0782
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9988 - loss: 0.0045 - val_accuracy: 0.9833 - val_loss: 0.0768
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9988 - loss: 0.0040 - val_accuracy: 0.9845 - val_loss: 0.0821
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9991 - loss: 0.0035 - val_accuracy: 0.9845 - val_loss: 0.0857
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9833 - val_loss: 0.0866
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9988 - loss: 0.0028 - val_accuracy: 0.9857 - val_loss: 0.0899
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9991 - loss: 0.0022 - val_accuracy: 0.9833 - val_loss: 0.0932
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9994 - loss: 0.0016 - val_accuracy: 0.9833 - val_loss: 0.0970
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9857 - val_loss: 0.0870
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9991 - loss: 0.0019 - val_accuracy: 0.9845 - val_loss: 0.0927
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9821 - val_loss: 0.1032
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 140ms/step - accuracy: 0.9994 - loss: 0.0014 - val_accuracy: 0.9798 - val_loss: 0.1121
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9994 - loss: 0.0015 - val_accuracy: 0.9810 - val_loss: 0.0894
#
# Dropout 0.2 | Fold 5
# Loss     : 0.0894
# Accuracy : 0.9810
# Model for Dropout 0.2 Fold 5 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_2_fold_5.keras
#
# ============================================================
# HASIL AKHIR DROPOUT = 0.2
# ============================================================
# Average Accuracy : 0.9812
#
# ############################################################
# # TRAINING KLASIFIKASI ASPEK DENGAN DROPOUT = 0.5
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 25
# ============================================================
#
# ====== Dropout 0.5 | Fold 1 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 24s 147ms/step - accuracy: 0.5204 - loss: 1.2923 - val_accuracy: 0.7895 - val_loss: 0.7971
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 137ms/step - accuracy: 0.8543 - loss: 0.5987 - val_accuracy: 0.8918 - val_loss: 0.4407
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9072 - loss: 0.3367 - val_accuracy: 0.9180 - val_loss: 0.2658
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9453 - loss: 0.1883 - val_accuracy: 0.9477 - val_loss: 0.1764
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9610 - loss: 0.1206 - val_accuracy: 0.9584 - val_loss: 0.1411
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9682 - loss: 0.0943 - val_accuracy: 0.9620 - val_loss: 0.1221
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9759 - loss: 0.0687 - val_accuracy: 0.9655 - val_loss: 0.1068
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9836 - loss: 0.0467 - val_accuracy: 0.9727 - val_loss: 0.0976
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9860 - loss: 0.0415 - val_accuracy: 0.9774 - val_loss: 0.0908
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9899 - loss: 0.0402 - val_accuracy: 0.9786 - val_loss: 0.0901
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9905 - loss: 0.0314 - val_accuracy: 0.9774 - val_loss: 0.0883
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9935 - loss: 0.0236 - val_accuracy: 0.9822 - val_loss: 0.0828
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9949 - loss: 0.0196 - val_accuracy: 0.9822 - val_loss: 0.0771
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 140ms/step - accuracy: 0.9949 - loss: 0.0146 - val_accuracy: 0.9857 - val_loss: 0.0766
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.9941 - loss: 0.0187 - val_accuracy: 0.9834 - val_loss: 0.0782
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9958 - loss: 0.0140 - val_accuracy: 0.9798 - val_loss: 0.0830
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 139ms/step - accuracy: 0.9973 - loss: 0.0122 - val_accuracy: 0.9845 - val_loss: 0.0763
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9973 - loss: 0.0101 - val_accuracy: 0.9857 - val_loss: 0.0782
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9985 - loss: 0.0089 - val_accuracy: 0.9869 - val_loss: 0.0736
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9982 - loss: 0.0069 - val_accuracy: 0.9881 - val_loss: 0.0784
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9976 - loss: 0.0080 - val_accuracy: 0.9845 - val_loss: 0.0798
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9988 - loss: 0.0058 - val_accuracy: 0.9857 - val_loss: 0.0789
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 138ms/step - accuracy: 0.9970 - loss: 0.0073 - val_accuracy: 0.9834 - val_loss: 0.0864
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9961 - loss: 0.0150 - val_accuracy: 0.9834 - val_loss: 0.0844
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9976 - loss: 0.0061 - val_accuracy: 0.9857 - val_loss: 0.0810
#
# Dropout 0.5 | Fold 1
# Loss     : 0.0810
# Accuracy : 0.9857
# Model for Dropout 0.5 Fold 1 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_5_fold_1.keras
#
# ====== Dropout 0.5 | Fold 2 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 23s 145ms/step - accuracy: 0.5394 - loss: 1.2945 - val_accuracy: 0.7241 - val_loss: 0.7685
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.8353 - loss: 0.6188 - val_accuracy: 0.9013 - val_loss: 0.3552
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9087 - loss: 0.2795 - val_accuracy: 0.9263 - val_loss: 0.2422
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9450 - loss: 0.1602 - val_accuracy: 0.9524 - val_loss: 0.1863
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9649 - loss: 0.1030 - val_accuracy: 0.9548 - val_loss: 0.1600
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9718 - loss: 0.0774 - val_accuracy: 0.9596 - val_loss: 0.1464
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9729 - loss: 0.0711 - val_accuracy: 0.9608 - val_loss: 0.1441
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9792 - loss: 0.0562 - val_accuracy: 0.9643 - val_loss: 0.1299
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9819 - loss: 0.0460 - val_accuracy: 0.9738 - val_loss: 0.1311
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9863 - loss: 0.0409 - val_accuracy: 0.9727 - val_loss: 0.1369
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9911 - loss: 0.0296 - val_accuracy: 0.9798 - val_loss: 0.1261
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9923 - loss: 0.0248 - val_accuracy: 0.9845 - val_loss: 0.1221
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 129ms/step - accuracy: 0.9946 - loss: 0.0230 - val_accuracy: 0.9810 - val_loss: 0.1206
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9970 - loss: 0.0169 - val_accuracy: 0.9810 - val_loss: 0.1233
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9970 - loss: 0.0141 - val_accuracy: 0.9810 - val_loss: 0.1180
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9970 - loss: 0.0134 - val_accuracy: 0.9834 - val_loss: 0.1084
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9952 - loss: 0.0124 - val_accuracy: 0.9810 - val_loss: 0.1160
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9964 - loss: 0.0169 - val_accuracy: 0.9786 - val_loss: 0.1134
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9979 - loss: 0.0108 - val_accuracy: 0.9798 - val_loss: 0.1155
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9982 - loss: 0.0087 - val_accuracy: 0.9798 - val_loss: 0.1110
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9982 - loss: 0.0067 - val_accuracy: 0.9810 - val_loss: 0.1086
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9970 - loss: 0.0089 - val_accuracy: 0.9798 - val_loss: 0.1069
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9985 - loss: 0.0072 - val_accuracy: 0.9822 - val_loss: 0.1111
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.9810 - val_loss: 0.1120
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9982 - loss: 0.0084 - val_accuracy: 0.9845 - val_loss: 0.1070
#
# Dropout 0.5 | Fold 2
# Loss     : 0.1070
# Accuracy : 0.9845
# Model for Dropout 0.5 Fold 2 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_5_fold_2.keras
#
# ====== Dropout 0.5 | Fold 3 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 22s 142ms/step - accuracy: 0.4784 - loss: 1.3218 - val_accuracy: 0.7432 - val_loss: 0.9005
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.8347 - loss: 0.6176 - val_accuracy: 0.8942 - val_loss: 0.4240
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9105 - loss: 0.3123 - val_accuracy: 0.9168 - val_loss: 0.2485
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9468 - loss: 0.1626 - val_accuracy: 0.9382 - val_loss: 0.1760
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9646 - loss: 0.1043 - val_accuracy: 0.9489 - val_loss: 0.1558
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9718 - loss: 0.0808 - val_accuracy: 0.9572 - val_loss: 0.1429
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 15s 137ms/step - accuracy: 0.9753 - loss: 0.0641 - val_accuracy: 0.9524 - val_loss: 0.1438
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9813 - loss: 0.0481 - val_accuracy: 0.9620 - val_loss: 0.1309
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9822 - loss: 0.0432 - val_accuracy: 0.9620 - val_loss: 0.1393
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9860 - loss: 0.0392 - val_accuracy: 0.9655 - val_loss: 0.1228
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9875 - loss: 0.0385 - val_accuracy: 0.9643 - val_loss: 0.1262
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9899 - loss: 0.0252 - val_accuracy: 0.9750 - val_loss: 0.1230
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9932 - loss: 0.0222 - val_accuracy: 0.9750 - val_loss: 0.1206
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9958 - loss: 0.0178 - val_accuracy: 0.9810 - val_loss: 0.1069
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9949 - loss: 0.0192 - val_accuracy: 0.9822 - val_loss: 0.1025
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9958 - loss: 0.0160 - val_accuracy: 0.9810 - val_loss: 0.0987
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9964 - loss: 0.0130 - val_accuracy: 0.9810 - val_loss: 0.1032
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9967 - loss: 0.0105 - val_accuracy: 0.9786 - val_loss: 0.1074
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9964 - loss: 0.0114 - val_accuracy: 0.9798 - val_loss: 0.1011
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9970 - loss: 0.0102 - val_accuracy: 0.9810 - val_loss: 0.1021
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9970 - loss: 0.0124 - val_accuracy: 0.9822 - val_loss: 0.0995
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9982 - loss: 0.0071 - val_accuracy: 0.9845 - val_loss: 0.0955
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9982 - loss: 0.0062 - val_accuracy: 0.9834 - val_loss: 0.0911
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9985 - loss: 0.0073 - val_accuracy: 0.9822 - val_loss: 0.0944
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9982 - loss: 0.0076 - val_accuracy: 0.9822 - val_loss: 0.0899
#
# Dropout 0.5 | Fold 3
# Loss     : 0.0899
# Accuracy : 0.9822
# Model for Dropout 0.5 Fold 3 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_5_fold_3.keras
#
# ====== Dropout 0.5 | Fold 4 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.4588 - loss: 1.3306 - val_accuracy: 0.7194 - val_loss: 0.9259
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.8052 - loss: 0.6884 - val_accuracy: 0.8954 - val_loss: 0.4010
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9060 - loss: 0.3450 - val_accuracy: 0.9144 - val_loss: 0.2540
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9185 - loss: 0.2205 - val_accuracy: 0.9227 - val_loss: 0.1914
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9408 - loss: 0.1524 - val_accuracy: 0.9560 - val_loss: 0.1503
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9587 - loss: 0.1099 - val_accuracy: 0.9655 - val_loss: 0.1230
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9670 - loss: 0.0853 - val_accuracy: 0.9655 - val_loss: 0.1126
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 129ms/step - accuracy: 0.9744 - loss: 0.0661 - val_accuracy: 0.9655 - val_loss: 0.1052
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9762 - loss: 0.0597 - val_accuracy: 0.9703 - val_loss: 0.1054
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9825 - loss: 0.0443 - val_accuracy: 0.9727 - val_loss: 0.1039
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9884 - loss: 0.0361 - val_accuracy: 0.9774 - val_loss: 0.0942
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9932 - loss: 0.0250 - val_accuracy: 0.9762 - val_loss: 0.0979
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9941 - loss: 0.0233 - val_accuracy: 0.9786 - val_loss: 0.0953
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9955 - loss: 0.0170 - val_accuracy: 0.9786 - val_loss: 0.0942
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9961 - loss: 0.0169 - val_accuracy: 0.9798 - val_loss: 0.0923
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9976 - loss: 0.0129 - val_accuracy: 0.9798 - val_loss: 0.0946
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9970 - loss: 0.0133 - val_accuracy: 0.9798 - val_loss: 0.1057
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9955 - loss: 0.0114 - val_accuracy: 0.9810 - val_loss: 0.1015
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9982 - loss: 0.0096 - val_accuracy: 0.9822 - val_loss: 0.1079
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9964 - loss: 0.0116 - val_accuracy: 0.9810 - val_loss: 0.1122
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9964 - loss: 0.0092 - val_accuracy: 0.9810 - val_loss: 0.0998
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9979 - loss: 0.0070 - val_accuracy: 0.9810 - val_loss: 0.0985
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9994 - loss: 0.0038 - val_accuracy: 0.9810 - val_loss: 0.0948
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9982 - loss: 0.0096 - val_accuracy: 0.9834 - val_loss: 0.1016
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9994 - loss: 0.0048 - val_accuracy: 0.9822 - val_loss: 0.0979
#
# Dropout 0.5 | Fold 4
# Loss     : 0.0979
# Accuracy : 0.9822
# Model for Dropout 0.5 Fold 4 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_5_fold_4.keras
#
# ====== Dropout 0.5 | Fold 5 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 22s 141ms/step - accuracy: 0.4596 - loss: 1.3624 - val_accuracy: 0.7131 - val_loss: 0.9976
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.8133 - loss: 0.6618 - val_accuracy: 0.8833 - val_loss: 0.4385
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9117 - loss: 0.2973 - val_accuracy: 0.9083 - val_loss: 0.2757
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9293 - loss: 0.1896 - val_accuracy: 0.9286 - val_loss: 0.2166
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9530 - loss: 0.1303 - val_accuracy: 0.9476 - val_loss: 0.1758
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9664 - loss: 0.0919 - val_accuracy: 0.9536 - val_loss: 0.1626
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9718 - loss: 0.0716 - val_accuracy: 0.9583 - val_loss: 0.1285
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9807 - loss: 0.0592 - val_accuracy: 0.9607 - val_loss: 0.1065
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9839 - loss: 0.0456 - val_accuracy: 0.9655 - val_loss: 0.0951
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9866 - loss: 0.0380 - val_accuracy: 0.9702 - val_loss: 0.0999
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9923 - loss: 0.0247 - val_accuracy: 0.9714 - val_loss: 0.1021
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9941 - loss: 0.0228 - val_accuracy: 0.9810 - val_loss: 0.0891
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9946 - loss: 0.0184 - val_accuracy: 0.9786 - val_loss: 0.0968
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9961 - loss: 0.0154 - val_accuracy: 0.9810 - val_loss: 0.0857
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9967 - loss: 0.0129 - val_accuracy: 0.9833 - val_loss: 0.0792
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9970 - loss: 0.0104 - val_accuracy: 0.9857 - val_loss: 0.0892
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9970 - loss: 0.0144 - val_accuracy: 0.9869 - val_loss: 0.0935
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9964 - loss: 0.0094 - val_accuracy: 0.9821 - val_loss: 0.0907
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9976 - loss: 0.0105 - val_accuracy: 0.9869 - val_loss: 0.0949
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9973 - loss: 0.0094 - val_accuracy: 0.9893 - val_loss: 0.0751
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9982 - loss: 0.0073 - val_accuracy: 0.9881 - val_loss: 0.0742
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9982 - loss: 0.0093 - val_accuracy: 0.9810 - val_loss: 0.0959
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9988 - loss: 0.0082 - val_accuracy: 0.9881 - val_loss: 0.0773
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9979 - loss: 0.0075 - val_accuracy: 0.9845 - val_loss: 0.0928
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9979 - loss: 0.0078 - val_accuracy: 0.9893 - val_loss: 0.0565
#
# Dropout 0.5 | Fold 5
# Loss     : 0.0565
# Accuracy : 0.9893
# Model for Dropout 0.5 Fold 5 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_5_fold_5.keras
#
# ============================================================
# HASIL AKHIR DROPOUT = 0.5
# ============================================================
# Average Accuracy : 0.9848
#
# ############################################################
# # TRAINING KLASIFIKASI ASPEK DENGAN DROPOUT = 0.8
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 25
# ============================================================
#
# ====== Dropout 0.8 | Fold 1 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 23s 148ms/step - accuracy: 0.3764 - loss: 1.4709 - val_accuracy: 0.6326 - val_loss: 1.2668
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.4680 - loss: 1.2108 - val_accuracy: 0.7051 - val_loss: 0.9627
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.7217 - loss: 0.8710 - val_accuracy: 0.8264 - val_loss: 0.6870
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.8153 - loss: 0.6664 - val_accuracy: 0.8811 - val_loss: 0.5129
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.8573 - loss: 0.5274 - val_accuracy: 0.8930 - val_loss: 0.3861
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.8784 - loss: 0.4210 - val_accuracy: 0.9061 - val_loss: 0.3056
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.8989 - loss: 0.3439 - val_accuracy: 0.9108 - val_loss: 0.2566
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9040 - loss: 0.3019 - val_accuracy: 0.9156 - val_loss: 0.2258
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9156 - loss: 0.2536 - val_accuracy: 0.9215 - val_loss: 0.2032
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9215 - loss: 0.2309 - val_accuracy: 0.9227 - val_loss: 0.1902
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9209 - loss: 0.2137 - val_accuracy: 0.9275 - val_loss: 0.1722
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9319 - loss: 0.1800 - val_accuracy: 0.9346 - val_loss: 0.1692
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9358 - loss: 0.1714 - val_accuracy: 0.9512 - val_loss: 0.1596
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9447 - loss: 0.1562 - val_accuracy: 0.9536 - val_loss: 0.1449
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9500 - loss: 0.1503 - val_accuracy: 0.9572 - val_loss: 0.1411
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9545 - loss: 0.1256 - val_accuracy: 0.9584 - val_loss: 0.1303
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9628 - loss: 0.1195 - val_accuracy: 0.9501 - val_loss: 0.1345
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9625 - loss: 0.1044 - val_accuracy: 0.9584 - val_loss: 0.1250
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9643 - loss: 0.1040 - val_accuracy: 0.9572 - val_loss: 0.1181
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9694 - loss: 0.0973 - val_accuracy: 0.9596 - val_loss: 0.1230
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9670 - loss: 0.0908 - val_accuracy: 0.9608 - val_loss: 0.1233
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9697 - loss: 0.0860 - val_accuracy: 0.9620 - val_loss: 0.1207
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9694 - loss: 0.0894 - val_accuracy: 0.9620 - val_loss: 0.1186
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9744 - loss: 0.0762 - val_accuracy: 0.9631 - val_loss: 0.1162
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - accuracy: 0.9741 - loss: 0.0810 - val_accuracy: 0.9620 - val_loss: 0.1216
#
# Dropout 0.8 | Fold 1
# Loss     : 0.1216
# Accuracy : 0.9620
# Model for Dropout 0.8 Fold 1 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_8_fold_1.keras
#
# ====== Dropout 0.8 | Fold 2 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.4014 - loss: 1.4720 - val_accuracy: 0.4055 - val_loss: 1.2678
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.4267 - loss: 1.2538 - val_accuracy: 0.6849 - val_loss: 1.0440
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.6789 - loss: 0.9191 - val_accuracy: 0.8751 - val_loss: 0.5729
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.8213 - loss: 0.6336 - val_accuracy: 0.9001 - val_loss: 0.3970
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.8644 - loss: 0.4820 - val_accuracy: 0.9156 - val_loss: 0.3072
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.8864 - loss: 0.3943 - val_accuracy: 0.9239 - val_loss: 0.2656
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.8986 - loss: 0.3155 - val_accuracy: 0.9275 - val_loss: 0.2518
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9102 - loss: 0.2641 - val_accuracy: 0.9287 - val_loss: 0.2364
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9144 - loss: 0.2514 - val_accuracy: 0.9310 - val_loss: 0.2206
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9206 - loss: 0.2184 - val_accuracy: 0.9346 - val_loss: 0.2047
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9286 - loss: 0.2011 - val_accuracy: 0.9453 - val_loss: 0.1874
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9355 - loss: 0.1867 - val_accuracy: 0.9501 - val_loss: 0.1759
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9447 - loss: 0.1521 - val_accuracy: 0.9512 - val_loss: 0.1656
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9518 - loss: 0.1364 - val_accuracy: 0.9560 - val_loss: 0.1693
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9530 - loss: 0.1336 - val_accuracy: 0.9584 - val_loss: 0.1584
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9521 - loss: 0.1303 - val_accuracy: 0.9620 - val_loss: 0.1513
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9584 - loss: 0.1235 - val_accuracy: 0.9643 - val_loss: 0.1400
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9593 - loss: 0.1141 - val_accuracy: 0.9643 - val_loss: 0.1408
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9652 - loss: 0.1041 - val_accuracy: 0.9679 - val_loss: 0.1380
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9655 - loss: 0.0942 - val_accuracy: 0.9691 - val_loss: 0.1435
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9691 - loss: 0.0907 - val_accuracy: 0.9679 - val_loss: 0.1396
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9679 - loss: 0.0915 - val_accuracy: 0.9703 - val_loss: 0.1342
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9706 - loss: 0.0851 - val_accuracy: 0.9715 - val_loss: 0.1398
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9691 - loss: 0.0804 - val_accuracy: 0.9727 - val_loss: 0.1351
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9756 - loss: 0.0725 - val_accuracy: 0.9727 - val_loss: 0.1376
#
# Dropout 0.8 | Fold 2
# Loss     : 0.1376
# Accuracy : 0.9727
# Model for Dropout 0.8 Fold 2 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 23s 141ms/step - accuracy: 0.3973 - loss: 1.5028 - val_accuracy: 0.3591 - val_loss: 1.3386
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.4321 - loss: 1.2718 - val_accuracy: 0.6932 - val_loss: 1.1716
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.6744 - loss: 0.9481 - val_accuracy: 0.8169 - val_loss: 0.6743
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.8243 - loss: 0.6279 - val_accuracy: 0.8823 - val_loss: 0.4358
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.8760 - loss: 0.4568 - val_accuracy: 0.8989 - val_loss: 0.3396
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.8947 - loss: 0.3414 - val_accuracy: 0.9037 - val_loss: 0.2827
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9075 - loss: 0.2983 - val_accuracy: 0.9084 - val_loss: 0.2393
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9209 - loss: 0.2406 - val_accuracy: 0.9144 - val_loss: 0.2196
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9251 - loss: 0.2262 - val_accuracy: 0.9215 - val_loss: 0.1952
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9313 - loss: 0.1976 - val_accuracy: 0.9287 - val_loss: 0.1794
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9426 - loss: 0.1769 - val_accuracy: 0.9370 - val_loss: 0.1711
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9480 - loss: 0.1584 - val_accuracy: 0.9441 - val_loss: 0.1636
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9497 - loss: 0.1487 - val_accuracy: 0.9512 - val_loss: 0.1519
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9557 - loss: 0.1325 - val_accuracy: 0.9524 - val_loss: 0.1488
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9622 - loss: 0.1167 - val_accuracy: 0.9572 - val_loss: 0.1438
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9652 - loss: 0.1156 - val_accuracy: 0.9572 - val_loss: 0.1354
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9637 - loss: 0.1093 - val_accuracy: 0.9572 - val_loss: 0.1422
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9634 - loss: 0.1070 - val_accuracy: 0.9584 - val_loss: 0.1427
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9682 - loss: 0.0997 - val_accuracy: 0.9596 - val_loss: 0.1352
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 136ms/step - accuracy: 0.9676 - loss: 0.1010 - val_accuracy: 0.9643 - val_loss: 0.1381
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9700 - loss: 0.0911 - val_accuracy: 0.9596 - val_loss: 0.1364
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9732 - loss: 0.0731 - val_accuracy: 0.9631 - val_loss: 0.1395
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9720 - loss: 0.0751 - val_accuracy: 0.9631 - val_loss: 0.1414
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.9759 - loss: 0.0725 - val_accuracy: 0.9643 - val_loss: 0.1371
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9759 - loss: 0.0701 - val_accuracy: 0.9643 - val_loss: 0.1474
#
# Dropout 0.8 | Fold 3
# Loss     : 0.1474
# Accuracy : 0.9643
# Model for Dropout 0.8 Fold 3 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_8_fold_3.keras
#
# ====== Dropout 0.8 | Fold 4 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 22s 143ms/step - accuracy: 0.3886 - loss: 1.4769 - val_accuracy: 0.4162 - val_loss: 1.2720
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.4020 - loss: 1.2760 - val_accuracy: 0.6147 - val_loss: 1.1276
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.6476 - loss: 0.9595 - val_accuracy: 0.7919 - val_loss: 0.6703
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.7921 - loss: 0.7119 - val_accuracy: 0.8847 - val_loss: 0.4645
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.8448 - loss: 0.5564 - val_accuracy: 0.9073 - val_loss: 0.3368
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.8843 - loss: 0.4198 - val_accuracy: 0.9144 - val_loss: 0.2616
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 135ms/step - accuracy: 0.8965 - loss: 0.3473 - val_accuracy: 0.9191 - val_loss: 0.2267
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9066 - loss: 0.2799 - val_accuracy: 0.9227 - val_loss: 0.1980
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9150 - loss: 0.2531 - val_accuracy: 0.9227 - val_loss: 0.1778
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9170 - loss: 0.2354 - val_accuracy: 0.9251 - val_loss: 0.1685
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9263 - loss: 0.1976 - val_accuracy: 0.9358 - val_loss: 0.1580
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9319 - loss: 0.1889 - val_accuracy: 0.9453 - val_loss: 0.1486
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9420 - loss: 0.1548 - val_accuracy: 0.9584 - val_loss: 0.1450
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9429 - loss: 0.1554 - val_accuracy: 0.9631 - val_loss: 0.1338
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9489 - loss: 0.1389 - val_accuracy: 0.9631 - val_loss: 0.1307
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9563 - loss: 0.1221 - val_accuracy: 0.9655 - val_loss: 0.1315
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9628 - loss: 0.1180 - val_accuracy: 0.9643 - val_loss: 0.1177
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9587 - loss: 0.1160 - val_accuracy: 0.9667 - val_loss: 0.1096
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9634 - loss: 0.1109 - val_accuracy: 0.9667 - val_loss: 0.1125
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9652 - loss: 0.1080 - val_accuracy: 0.9691 - val_loss: 0.1069
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9640 - loss: 0.1052 - val_accuracy: 0.9715 - val_loss: 0.1112
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9616 - loss: 0.1181 - val_accuracy: 0.9727 - val_loss: 0.1069
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9688 - loss: 0.0874 - val_accuracy: 0.9715 - val_loss: 0.1074
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9718 - loss: 0.0898 - val_accuracy: 0.9715 - val_loss: 0.1116
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9703 - loss: 0.0877 - val_accuracy: 0.9738 - val_loss: 0.1156
#
# Dropout 0.8 | Fold 4
# Loss     : 0.1156
# Accuracy : 0.9738
# Model for Dropout 0.8 Fold 4 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_8_fold_4.keras
#
# ====== Dropout 0.8 | Fold 5 ======
# Epoch 1/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 23s 140ms/step - accuracy: 0.3856 - loss: 1.4974 - val_accuracy: 0.4143 - val_loss: 1.2999
# Epoch 2/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.4646 - loss: 1.2389 - val_accuracy: 0.7238 - val_loss: 1.0184
# Epoch 3/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.7027 - loss: 0.8971 - val_accuracy: 0.8024 - val_loss: 0.7060
# Epoch 4/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.8139 - loss: 0.6442 - val_accuracy: 0.8810 - val_loss: 0.4718
# Epoch 5/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.8769 - loss: 0.4512 - val_accuracy: 0.9024 - val_loss: 0.3609
# Epoch 6/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.8995 - loss: 0.3690 - val_accuracy: 0.9095 - val_loss: 0.2989
# Epoch 7/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9093 - loss: 0.3259 - val_accuracy: 0.9131 - val_loss: 0.2661
# Epoch 8/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9183 - loss: 0.2663 - val_accuracy: 0.9131 - val_loss: 0.2550
# Epoch 9/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 129ms/step - accuracy: 0.9171 - loss: 0.2380 - val_accuracy: 0.9131 - val_loss: 0.2422
# Epoch 10/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 130ms/step - accuracy: 0.9284 - loss: 0.2264 - val_accuracy: 0.9143 - val_loss: 0.2296
# Epoch 11/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9301 - loss: 0.1958 - val_accuracy: 0.9155 - val_loss: 0.2230
# Epoch 12/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9325 - loss: 0.1850 - val_accuracy: 0.9190 - val_loss: 0.2259
# Epoch 13/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9382 - loss: 0.1800 - val_accuracy: 0.9250 - val_loss: 0.2172
# Epoch 14/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9417 - loss: 0.1666 - val_accuracy: 0.9345 - val_loss: 0.2018
# Epoch 15/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 133ms/step - accuracy: 0.9411 - loss: 0.1790 - val_accuracy: 0.9429 - val_loss: 0.1860
# Epoch 16/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9501 - loss: 0.1502 - val_accuracy: 0.9500 - val_loss: 0.1683
# Epoch 17/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9533 - loss: 0.1478 - val_accuracy: 0.9560 - val_loss: 0.1628
# Epoch 18/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 134ms/step - accuracy: 0.9557 - loss: 0.1309 - val_accuracy: 0.9595 - val_loss: 0.1566
# Epoch 19/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9584 - loss: 0.1199 - val_accuracy: 0.9607 - val_loss: 0.1539
# Epoch 20/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9611 - loss: 0.1153 - val_accuracy: 0.9619 - val_loss: 0.1535
# Epoch 21/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9658 - loss: 0.0995 - val_accuracy: 0.9619 - val_loss: 0.1424
# Epoch 22/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9670 - loss: 0.1042 - val_accuracy: 0.9595 - val_loss: 0.1419
# Epoch 23/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9664 - loss: 0.1006 - val_accuracy: 0.9619 - val_loss: 0.1396
# Epoch 24/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 132ms/step - accuracy: 0.9709 - loss: 0.0931 - val_accuracy: 0.9619 - val_loss: 0.1394
# Epoch 25/25
# 106/106 ━━━━━━━━━━━━━━━━━━━━ 14s 131ms/step - accuracy: 0.9703 - loss: 0.0883 - val_accuracy: 0.9655 - val_loss: 0.1407
#
# Dropout 0.8 | Fold 5
# Loss     : 0.1407
# Accuracy : 0.9655
# Model for Dropout 0.8 Fold 5 saved to: /kaggle/working/EPOCH_25/aspect_classification_models/aspect_model_dropout_0_8_fold_5.keras
#
# ============================================================
# HASIL AKHIR DROPOUT = 0.8
# ============================================================
# Average Accuracy : 0.9676
#
# ############################################################
# # RINGKASAN PERBANDINGAN DROPOUT (Klasifikasi Aspek)
# ############################################################
# Dropout 0.2: rata-rata accuracy (K-Fold) = 0.9812
# Dropout 0.5: rata-rata accuracy (K-Fold) = 0.9848
# Dropout 0.8: rata-rata accuracy (K-Fold) = 0.9676

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix
)

import numpy as np
import pandas as pd
import os
import re
import ast

# =========================
# FUNCTION
# =========================

def ensure_list(x):

    if isinstance(x, list):
        return x

    if isinstance(x, str):

        try:
            val = ast.literal_eval(x)

            if isinstance(val, list):
                return val

        except:
            return x.split()

    return []

# =========================
# PREPARE TEST DATA
# =========================

tokens = X_test_full['Tokenized_Opinion'].apply(ensure_list)

X_test_texts = tokens.apply(lambda x: ' '.join(x)).fillna("")

print("Contoh teks:")
print(X_test_texts.iloc[0])

X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

X_test_pad_final = pad_sequences(
    X_test_seq,
    maxlen=max_len,
    padding='post',
    truncating='post'
)

y_true = np.array(Y_test_aspect)

print("\nShape X_test:", X_test_pad_final.shape)
print("Shape y_test:", y_true.shape)

# =========================
# LOAD MODEL FILES
# =========================

model_save_dir = os.path.join(
    BASE_DRIVE_PATH,
    'aspect_classification_models'
)

model_files = [
    f for f in os.listdir(model_save_dir)
    if f.endswith('.keras')
    and f.startswith('aspect_model_dropout_')
]

def parse_dropout_fold(filename):
    """Ambil nilai dropout & nomor fold dari nama file aspect_model_dropout_<d>_fold_<n>.keras"""
    match = re.search(r'dropout_([0-9_]+)_fold_(\d+)\.keras', filename)
    if match:
        dropout_value = float(match.group(1).replace('_', '.'))
        fold_number = int(match.group(2))
        return dropout_value, fold_number
    return None, -1

model_files = sorted(
    model_files,
    key=lambda f: parse_dropout_fold(f)
)

results = []
# Prediksi dikelompokkan per nilai dropout supaya bisa dibuat ensemble per dropout
preds_by_dropout = {}

if not model_files:

    print(
        f"\nTidak ada model ditemukan di {model_save_dir}"
    )

else:

    print("\nModel ditemukan:")
    for file in model_files:
        print("-", file)

    for file_name in model_files:

        full_file_path = os.path.join(
            model_save_dir,
            file_name
        )

        dropout_value, fold_number = parse_dropout_fold(file_name)

        print("\n" + "="*60)
        print(
            f"EVALUASI MODEL | Dropout {dropout_value} | Fold {fold_number}"
        )
        print("="*60)

        model = load_model(full_file_path)

        y_pred_prob = model.predict(
            X_test_pad_final,
            verbose=0
        )

        preds_by_dropout.setdefault(dropout_value, []).append(y_pred_prob)

        y_pred = np.argmax(
            y_pred_prob,
            axis=1
        )

        print("\nDistribusi Prediksi:")
        print(np.bincount(y_pred))

        # =========================
        # METRICS
        # =========================

        acc = accuracy_score(
            y_true,
            y_pred
        )

        precision = precision_score(
            y_true,
            y_pred,
            average='weighted',
            zero_division=0
        )

        recall = recall_score(
            y_true,
            y_pred,
            average='weighted',
            zero_division=0
        )

        f1 = f1_score(
            y_true,
            y_pred,
            average='weighted',
            zero_division=0
        )

        print(f"\nAccuracy      : {acc:.4f}")
        print(f"Precision     : {precision:.4f}")
        print(f"Recall        : {recall:.4f}")
        print(f"F1-Score      : {f1:.4f}")

        results.append({
            "model_name": file_name,
            "dropout": dropout_value,
            "fold": fold_number,
            "accuracy": acc,
            "precision": precision,
            "recall": recall,
            "f1_score": f1
        })

# =========================
# HASIL SEMUA MODEL (per fold, semua dropout)
# =========================

df_results = pd.DataFrame(results)

if not df_results.empty:

    df_results = df_results.sort_values(
        by='accuracy',
        ascending=False
    )

    print("\n" + "="*60)
    print("PERBANDINGAN HASIL MODEL (semua dropout & fold)")
    print("="*60)

    display(df_results)

    # =========================
    # RINGKASAN RATA-RATA PER NILAI DROPOUT
    # =========================
    print("\n" + "="*60)
    print("RATA-RATA AKURASI PER NILAI DROPOUT")
    print("="*60)

    df_dropout_summary = (
        df_results
        .groupby('dropout')[['accuracy', 'precision', 'recall', 'f1_score']]
        .mean()
        .sort_values(by='accuracy', ascending=False)
    )
    display(df_dropout_summary)

# =========================
# ENSEMBLE PER NILAI DROPOUT (soft voting antar fold, per dropout)
# =========================

ensemble_summary = []

for dropout_value, prob_list in preds_by_dropout.items():

    avg_y_pred_prob = np.mean(prob_list, axis=0)
    y_pred_ensemble = np.argmax(avg_y_pred_prob, axis=1)

    ensemble_accuracy = accuracy_score(y_true, y_pred_ensemble)
    ensemble_precision = precision_score(y_true, y_pred_ensemble, average='weighted', zero_division=0)
    ensemble_recall = recall_score(y_true, y_pred_ensemble, average='weighted', zero_division=0)
    ensemble_f1 = f1_score(y_true, y_pred_ensemble, average='weighted', zero_division=0)

    ensemble_summary.append({
        'dropout': dropout_value,
        'ensemble_accuracy': ensemble_accuracy,
        'ensemble_precision': ensemble_precision,
        'ensemble_recall': ensemble_recall,
        'ensemble_f1': ensemble_f1
    })

    print("\n" + "="*60)
    print(f"EVALUASI ENSEMBLE (soft voting 5-fold) | Dropout = {dropout_value}")
    print("="*60)

    print(f"Accuracy      : {ensemble_accuracy:.4f}")
    print(f"Precision     : {ensemble_precision:.4f}")
    print(f"Recall        : {ensemble_recall:.4f}")
    print(f"F1-Score      : {ensemble_f1:.4f}")

    print("\nClassification Report:")
    if 'aspect_le' in globals():
        target_names_str = [str(cls) for cls in aspect_le.classes_]
        print(classification_report(y_true, y_pred_ensemble, target_names=target_names_str, zero_division=0))
    else:
        print(classification_report(y_true, y_pred_ensemble, zero_division=0))

    print("\nConfusion Matrix:")
    print(confusion_matrix(y_true, y_pred_ensemble))

if ensemble_summary:
    print("\n" + "#"*60)
    print("# RINGKASAN ENSEMBLE PER DROPOUT (Klasifikasi Aspek)")
    print("#"*60)
    df_ensemble_summary = pd.DataFrame(ensemble_summary).sort_values(by='ensemble_accuracy', ascending=False)
    display(df_ensemble_summary)
# Out:
# Contoh teks:
# instruksi jelas
#
# Shape X_test: (1051, 20)
# Shape y_test: (1051,)
#
# Model ditemukan:
# - aspect_model_dropout_0_2_fold_1.keras
# - aspect_model_dropout_0_2_fold_2.keras
# - aspect_model_dropout_0_2_fold_3.keras
# - aspect_model_dropout_0_2_fold_4.keras
# - aspect_model_dropout_0_2_fold_5.keras
# - aspect_model_dropout_0_5_fold_1.keras
# - aspect_model_dropout_0_5_fold_2.keras
# - aspect_model_dropout_0_5_fold_3.keras
# - aspect_model_dropout_0_5_fold_4.keras
# - aspect_model_dropout_0_5_fold_5.keras
# - aspect_model_dropout_0_8_fold_1.keras
# - aspect_model_dropout_0_8_fold_2.keras
# - aspect_model_dropout_0_8_fold_3.keras
# - aspect_model_dropout_0_8_fold_4.keras
# - aspect_model_dropout_0_8_fold_5.keras
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 1
# ============================================================
#
# Distribusi Prediksi:
# [ 17 185 377 421  51]
#
# Accuracy      : 0.9905
# Precision     : 0.9906
# Recall        : 0.9905
# F1-Score      : 0.9905
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 2
# ============================================================
#
# Distribusi Prediksi:
# [ 15 179 383 420  54]
#
# Accuracy      : 0.9838
# Precision     : 0.9839
# Recall        : 0.9838
# F1-Score      : 0.9838
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 3
# ============================================================
#
# Distribusi Prediksi:
# [ 16 181 384 417  53]
#
# Accuracy      : 0.9810
# Precision     : 0.9810
# Recall        : 0.9810
# F1-Score      : 0.9809
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 4
# ============================================================
#
# Distribusi Prediksi:
# [ 18 183 379 421  50]
#
# Accuracy      : 0.9895
# Precision     : 0.9896
# Recall        : 0.9895
# F1-Score      : 0.9895
#
# ============================================================
# EVALUASI MODEL | Dropout 0.2 | Fold 5
# ============================================================
#
# Distribusi Prediksi:
# [ 17 182 379 420  53]
#
# Accuracy      : 0.9848
# Precision     : 0.9848
# Recall        : 0.9848
# F1-Score      : 0.9848
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 1
# ============================================================
#
# Distribusi Prediksi:
# [ 19 181 378 423  50]
#
# Accuracy      : 0.9933
# Precision     : 0.9935
# Recall        : 0.9933
# F1-Score      : 0.9934
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 2
# ============================================================
#
# Distribusi Prediksi:
# [ 18 179 380 424  50]
#
# Accuracy      : 0.9876
# Precision     : 0.9877
# Recall        : 0.9876
# F1-Score      : 0.9876
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 3
# ============================================================
#
# Distribusi Prediksi:
# [ 16 182 380 420  53]
#
# Accuracy      : 0.9876
# Precision     : 0.9877
# Recall        : 0.9876
# F1-Score      : 0.9876
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 4
# ============================================================
#
# Distribusi Prediksi:
# [ 18 183 379 420  51]
#
# Accuracy      : 0.9895
# Precision     : 0.9896
# Recall        : 0.9895
# F1-Score      : 0.9896
#
# ============================================================
# EVALUASI MODEL | Dropout 0.5 | Fold 5
# ============================================================
#
# Distribusi Prediksi:
# [ 17 180 377 425  52]
#
# Accuracy      : 0.9886
# Precision     : 0.9886
# Recall        : 0.9886
# F1-Score      : 0.9886
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 1
# ============================================================
#
# Distribusi Prediksi:
# [  0 179 384 420  68]
#
# Accuracy      : 0.9686
# Precision     : 0.9572
# Recall        : 0.9686
# F1-Score      : 0.9622
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 2
# ============================================================
#
# Distribusi Prediksi:
# [  1 185 383 417  65]
#
# Accuracy      : 0.9629
# Precision     : 0.9517
# Recall        : 0.9629
# F1-Score      : 0.9567
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 3
# ============================================================
#
# Distribusi Prediksi:
# [  5 177 383 421  65]
#
# Accuracy      : 0.9676
# Precision     : 0.9709
# Recall        : 0.9676
# F1-Score      : 0.9656
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 4
# ============================================================
#
# Distribusi Prediksi:
# [  0 176 385 419  71]
#
# Accuracy      : 0.9657
# Precision     : 0.9555
# Recall        : 0.9657
# F1-Score      : 0.9596
#
# ============================================================
# EVALUASI MODEL | Dropout 0.8 | Fold 5
# ============================================================
#
# Distribusi Prediksi:
# [  0 181 386 416  68]
#
# Accuracy      : 0.9619
# Precision     : 0.9509
# Recall        : 0.9619
# F1-Score      : 0.9556
#
# ============================================================
# PERBANDINGAN HASIL MODEL (semua dropout & fold)
# ============================================================
#                                model_name  dropout  fold  accuracy  precision  \
# 5   aspect_model_dropout_0_5_fold_1.keras      0.5     1  0.993340   0.993543
# 0   aspect_model_dropout_0_2_fold_1.keras      0.2     1  0.990485   0.990568
# 3   aspect_model_dropout_0_2_fold_4.keras      0.2     4  0.989534   0.989618
# 8   aspect_model_dropout_0_5_fold_4.keras      0.5     4  0.989534   0.989649
# 9   aspect_model_dropout_0_5_fold_5.keras      0.5     5  0.988582   0.988588
# 6   aspect_model_dropout_0_5_fold_2.keras      0.5     2  0.987631   0.987733
# 7   aspect_model_dropout_0_5_fold_3.keras      0.5     3  0.987631   0.987666
# 4   aspect_model_dropout_0_2_fold_5.keras      0.2     5  0.984776   0.984795
# 1   aspect_model_dropout_0_2_fold_2.keras      0.2     2  0.983825   0.983948
# 2   aspect_model_dropout_0_2_fold_3.keras      0.2     3  0.980971   0.981049
# 10  aspect_model_dropout_0_8_fold_1.keras      0.8     1  0.968601   0.957227
# 12  aspect_model_dropout_0_8_fold_3.keras      0.8     3  0.967650   0.970884
# 13  aspect_model_dropout_0_8_fold_4.keras      0.8     4  0.965747   0.955529
# 11  aspect_model_dropout_0_8_fold_2.keras      0.8     2  0.962892   0.951696
# 14  aspect_model_dropout_0_8_fold_5.keras      0.8     5  0.961941   0.950899
#
#       recall  f1_score
# 5   0.993340  0.993374
# 0   0.990485  0.990497
# 3   0.989534  0.989532
# 8   0.989534  0.989558
# 9   0.988582  0.988583
# 6   0.987631  0.987642
# 7   0.987631  0.987614
# 4   0.984776  0.984769
# 1   0.983825  0.983774
# 2   0.980971  0.980934
# 10  0.968601  0.962169
# 12  0.967650  0.965598
# 13  0.965747  0.959608
# 11  0.962892  0.956749
# 14  0.961941  0.955648
# ============================================================
# RATA-RATA AKURASI PER NILAI DROPOUT
# ============================================================
#          accuracy  precision    recall  f1_score
# dropout
# 0.5      0.989343   0.989436  0.989343  0.989354
# 0.2      0.985918   0.985995  0.985918  0.985901
# 0.8      0.965366   0.957247  0.965366  0.959954
# ============================================================
# EVALUASI ENSEMBLE (soft voting 5-fold) | Dropout = 0.2
# ============================================================
# Accuracy      : 0.9943
# Precision     : 0.9943
# Recall        : 0.9943
# F1-Score      : 0.9943
#
# Classification Report:
#                                    precision    recall  f1-score   support
#
#                     biaya layanan       1.00      0.94      0.97        17
#       fasilitas dan infrastruktur       1.00      0.99      1.00       181
# kualitas pelayanan medis dan staf       0.99      1.00      0.99       377
#                           lainnya       1.00      0.99      0.99       424
#                      waktu tunggu       0.98      1.00      0.99        52
#
#                          accuracy                           0.99      1051
#                         macro avg       0.99      0.99      0.99      1051
#                      weighted avg       0.99      0.99      0.99      1051
#
#
# Confusion Matrix:
# [[ 16   0   0   0   1]
#  [  0 180   0   1   0]
#  [  0   0 376   1   0]
#  [  0   0   3 421   0]
#  [  0   0   0   0  52]]
#
# ============================================================
# EVALUASI ENSEMBLE (soft voting 5-fold) | Dropout = 0.5
# ============================================================
# Accuracy      : 0.9943
# Precision     : 0.9944
# Recall        : 0.9943
# F1-Score      : 0.9943
#
# Classification Report:
#                                    precision    recall  f1-score   support
#
#                     biaya layanan       0.89      0.94      0.91        17
#       fasilitas dan infrastruktur       1.00      1.00      1.00       181
# kualitas pelayanan medis dan staf       0.99      1.00      1.00       377
#                           lainnya       1.00      1.00      1.00       424
#                      waktu tunggu       0.98      0.96      0.97        52
#
#                          accuracy                           0.99      1051
#                         macro avg       0.97      0.98      0.98      1051
#                      weighted avg       0.99      0.99      0.99      1051
#
#
# Confusion Matrix:
# [[ 16   0   0   0   1]
#  [  0 181   0   0   0]
#  [  0   0 376   1   0]
#  [  0   0   2 422   0]
#  [  2   0   0   0  50]]
#
# ============================================================
# EVALUASI ENSEMBLE (soft voting 5-fold) | Dropout = 0.8
# ============================================================
# Accuracy      : 0.9657
# Precision     : 0.9541
# Recall        : 0.9657
# F1-Score      : 0.9593
#
# Classification Report:
#                                    precision    recall  f1-score   support
#
#                     biaya layanan       0.00      0.00      0.00        17
#       fasilitas dan infrastruktur       0.98      0.97      0.98       181
# kualitas pelayanan medis dan staf       0.98      1.00      0.99       377
#                           lainnya       0.99      0.98      0.99       424
#                      waktu tunggu       0.69      0.88      0.77        52
#
#                          accuracy                           0.97      1051
#                         macro avg       0.73      0.77      0.74      1051
#                      weighted avg       0.95      0.97      0.96      1051
#
#
# Confusion Matrix:
# [[  0   0   0   0  17]
#  [  0 176   0   1   4]
#  [  0   0 376   1   0]
#  [  0   1   6 417   0]
#  [  0   3   2   1  46]]
#
# ############################################################
# # RINGKASAN ENSEMBLE PER DROPOUT (Klasifikasi Aspek)
# ############################################################
#    dropout  ensemble_accuracy  ensemble_precision  ensemble_recall  \
# 0      0.2           0.994291            0.994320         0.994291
# 1      0.5           0.994291            0.994381         0.994291
# 2      0.8           0.965747            0.954136         0.965747
#
#    ensemble_f1
# 0     0.994282
# 1     0.994318
# 2     0.959283

# %%
import os
from tensorflow.keras.models import load_model

# Ensure df_results exists and is not empty
if 'df_results' in globals() and not df_results.empty:
    # Get the name of the best model (highest accuracy, across ALL dropout & fold combinations)
    best_row = df_results.iloc[0]
    best_model_name = best_row['model_name']

    # Construct the full path to the best model
    # model_save_dir is already defined in the evaluation cell above
    source_best_model_path = os.path.join(model_save_dir, best_model_name)

    # Define the directory to save the best model
    best_models_dir = os.path.join(BASE_DRIVE_PATH, 'best_models')
    os.makedirs(best_models_dir, exist_ok=True)

    # Define the destination path for the best model with the new requested name
    destination_best_model_path = os.path.join(best_models_dir, 'best_model_aspek.keras')

    try:
        # Load the best model
        best_model = load_model(source_best_model_path)

        # Save the best model to the new location
        best_model.save(destination_best_model_path)

        print(
            f"✅ Best aspect classification model '{best_model_name}' "
            f"(Dropout: {best_row.get('dropout', 'N/A')}, Fold: {best_row.get('fold', 'N/A')}, "
            f"Accuracy: {best_row['accuracy']:.4f}) saved successfully to: {destination_best_model_path}"
        )
    except Exception as e:
        print(f"❌ Error saving the best aspect classification model: {e}")
else:
    print("❌ No model results found to determine the best model. Please ensure the evaluation cell ran successfully.")
# Out:
# ✅ Best aspect classification model 'aspect_model_dropout_0_5_fold_1.keras' (Dropout: 0.5, Fold: 1, Accuracy: 0.9933) saved successfully to: /kaggle/working/EPOCH_25/best_models/best_model_aspek.keras

# %% [markdown]
# #KLASIFIKASI SENTIMEN PER ASPEK

# %%
import pandas as pd
from IPython.display import display

if 'df_aspect_labeling' not in locals():
    # Use the already loaded df_loaded DataFrame
    if 'df_loaded' in globals():
        df_aspect_labeling = df_loaded.copy()
        print("Assigned df_loaded to df_aspect_labeling.")
    else:
        print("Error: df_loaded not found. Please ensure 'dataset_hasil_labelling_aspek.xlsx' was loaded successfully in a previous cell.")
        # Fallback to attempt loading if df_loaded is unexpectedly missing
        try:
            # Assuming PREPROCESSED_DATA_DIR is defined
            if 'PREPROCESSED_DATA_DIR' in globals():
                file_path = find_input_file('dataset_hasil_labelling_aspek.xlsx', base_dir=PREPROCESSED_DATA_DIR)
                df_aspect_labeling = pd.read_excel(file_path)
                print(f"Loaded df_aspect_labeling from '{file_path}' as fallback.")
            else:
                print("Error: PREPROCESSED_DATA_DIR not defined for fallback loading.")
                df_aspect_labeling = pd.DataFrame() # Initialize empty
        except FileNotFoundError:
            print("Error: 'dataset_hasil_labelling_aspek.xlsx' not found. Please ensure previous steps ran successfully.")
            df_aspect_labeling = pd.DataFrame() # Initialize empty

# Membuat dictionary untuk menyimpan DataFrame per aspek
data_per_aspek = {}

# Ensure df_aspect_labeling is not empty before proceeding
if not df_aspect_labeling.empty:
    unique_aspects = df_aspect_labeling['Aspek'].unique()

    print("Memisahkan data berdasarkan aspek...")
    for aspek in unique_aspects:
        data_per_aspek[aspek] = df_aspect_labeling[df_aspect_labeling['Aspek'] == aspek].copy()
        print(f"- Aspek '{aspek}': {len(data_per_aspek[aspek])} baris")

    print("Data berhasil dipisahkan per aspek.")

    # Contoh menampilkan data untuk aspek 'kualitas pelayanan medis dan staf'
    if 'kualitas pelayanan medis dan staf' in data_per_aspek:
        print("\nContoh data untuk aspek 'kualitas pelayanan medis dan staf':")
        display(data_per_aspek['kualitas pelayanan medis dan staf'].head())
    else:
        print("Aspek 'kualitas pelayanan medis dan staf' tidak ditemukan dalam data.")
else:
    print("df_aspect_labeling is empty, skipping aspect separation.")
# Out:
# Assigned df_loaded to df_aspect_labeling.
# Memisahkan data berdasarkan aspek...
# - Aspek 'fasilitas dan infrastruktur': 903 baris
# - Aspek 'kualitas pelayanan medis dan staf': 1886 baris
# - Aspek 'lainnya': 2119 baris
# - Aspek 'waktu tunggu': 261 baris
# - Aspek 'biaya layanan': 86 baris
# Data berhasil dipisahkan per aspek.
#
# Contoh data untuk aspek 'kualitas pelayanan medis dan staf':
#    Original_Review_ID                                             Review  \
# 1                   1  Ruang flamboyan rumah sakit mitra keluarga dar...
# 3                   3                           Pelayanan baik memuaskan
# 4                   4  Dirawat inap di kamar Flamboyan, setelah opera...
# 7                   7  RS yang nyaman, pelayan oke. Suster lantai-lan...
# 8                   8  Pelayanan baik cepat tanggap luar biasa baik. ...
#
#   Extracted_Opinion Translated_Opinion Cleaned_Opinion Casefolded_Opinion  \
# 1     perawat ramah     friendly nurse   perawat ramah      perawat ramah
# 3    Pelayanan baik       Good service  Pelayanan baik     pelayanan baik
# 4      tenaga medis  medical personnel    tenaga medis       tenaga medis
# 7    flamboyan baik    flamboyant good  flamboyan baik     flamboyan baik
# 8    Pelayanan baik       Good service  Pelayanan baik     pelayanan baik
#
#        Tokenized_Opinion Vader_Sentiment_Category  Sentiment_encoded  \
# 1   ['perawat', 'ramah']                 Positive                  2
# 3  ['pelayanan', 'baik']                 Positive                  2
# 4    ['tenaga', 'medis']                  Neutral                  1
# 7  ['flamboyan', 'baik']                 Positive                  2
# 8  ['pelayanan', 'baik']                 Positive                  2
#
#                                Aspek  Aspek_encoded
# 1  kualitas pelayanan medis dan staf              2
# 3  kualitas pelayanan medis dan staf              2
# 4  kualitas pelayanan medis dan staf              2
# 7  kualitas pelayanan medis dan staf              2
# 8  kualitas pelayanan medis dan staf              2

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import os

if 'data_per_aspek' not in locals():
    try:
        if 'df_aspect_labeling' not in locals():
            # Use the already loaded df_loaded DataFrame
            if 'df_loaded' in globals():
                df_aspect_labeling = df_loaded.copy()
                print("Assigned df_loaded to df_aspect_labeling.")
            else:
                print("Error: df_loaded not found. Please ensure 'dataset_hasil_labelling_aspek.xlsx' was loaded successfully in a previous cell.")
                # Fallback to attempt loading if df_loaded is unexpectedly missing
                if 'PREPROCESSED_DATA_DIR' in globals():
                    file_path = find_input_file('dataset_hasil_labelling_aspek.xlsx', base_dir=PREPROCESSED_DATA_DIR)
                    df_aspect_labeling = pd.read_excel(file_path)
                    print(f"Loaded df_aspect_labeling from '{file_path}' as fallback.")
                else:
                    print("Error: PREPROCESSED_DATA_DIR not defined for fallback loading.")
                    df_aspect_labeling = pd.DataFrame() # Initialize empty

        if not df_aspect_labeling.empty:
            data_per_aspek = {}
            unique_aspects = df_aspect_labeling['Aspek'].unique()
            for aspek in unique_aspects:
                data_per_aspek[aspek] = df_aspect_labeling[df_aspect_labeling['Aspek'] == aspek].copy()
            print("Re-created data_per_aspek dictionary.")
        else:
            print("df_aspect_labeling is empty, cannot re-create data_per_aspek.")

    except FileNotFoundError:
        print("Error: 'dataset_hasil_labelling_aspek.xlsx' not found.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# 1. Initialize an empty dictionary to store split data
split_data_per_aspek = {}

print("Performing train-test split for each aspect...")

# 2. Iterate through each aspect and its corresponding DataFrame
if 'data_per_aspek' in locals() and data_per_aspek:
    for aspek_name, df_aspek in data_per_aspek.items():
        if len(df_aspek) == 0:
            print(f"Skipping empty aspect: {aspek_name}")
            continue

        # 3a. Define features (X) and target (Y)
        X = df_aspek['Tokenized_Opinion'] # Corrected column name
        Y = df_aspek['Sentiment_encoded']

        # Use KFold-like split, no stratification as requested
        # Check if there's enough data for splitting
        if len(df_aspek) > 1:
            X_train_aspect, X_test_aspect, Y_train_sentiment, Y_test_sentiment = train_test_split(
                X,
                Y,
                test_size=0.2,
                random_state=42
            )
            print(f"- Aspect '{aspek_name}': Data split. Train samples: {len(X_train_aspect)}, Test samples: {len(X_test_aspect)}")
        else:
            print(f"- Aspect '{aspek_name}': Skipping split due to insufficient data (only 1 sample).")
            continue

        split_data_per_aspek[aspek_name] = {
            'X_train': X_train_aspect,
            'X_test': X_test_aspect,
            'Y_train': Y_train_sentiment,
            'Y_test': Y_test_sentiment
        }

    print("Data splitting per aspect complete.")

    print("\nVerification of split data shapes (all aspects with splits):")
    for aspek_name, data in split_data_per_aspek.items():
        if 'X_train' in data and 'X_test' in data:
            print(f"\nAspect: {aspek_name}")
            print(f"  X_train shape: {data['X_train'].shape}")
            print(f"  X_test shape: {data['X_test'].shape}")
            print(f"  Y_train shape: {data['Y_train'].shape}")
            print(f"  Y_test shape: {data['Y_test'].shape}")
else:
    print("data_per_aspek is empty or not defined, skipping data splitting.")
# Out:
# Performing train-test split for each aspect...
# - Aspect 'fasilitas dan infrastruktur': Data split. Train samples: 722, Test samples: 181
# - Aspect 'kualitas pelayanan medis dan staf': Data split. Train samples: 1508, Test samples: 378
# - Aspect 'lainnya': Data split. Train samples: 1695, Test samples: 424
# - Aspect 'waktu tunggu': Data split. Train samples: 208, Test samples: 53
# - Aspect 'biaya layanan': Data split. Train samples: 68, Test samples: 18
# Data splitting per aspect complete.
#
# Verification of split data shapes (all aspects with splits):
#
# Aspect: fasilitas dan infrastruktur
#   X_train shape: (722,)
#   X_test shape: (181,)
#   Y_train shape: (722,)
#   Y_test shape: (181,)
#
# Aspect: kualitas pelayanan medis dan staf
#   X_train shape: (1508,)
#   X_test shape: (378,)
#   Y_train shape: (1508,)
#   Y_test shape: (378,)
#
# Aspect: lainnya
#   X_train shape: (1695,)
#   X_test shape: (424,)
#   Y_train shape: (1695,)
#   Y_test shape: (424,)
#
# Aspect: waktu tunggu
#   X_train shape: (208,)
#   X_test shape: (53,)
#   Y_train shape: (208,)
#   Y_test shape: (53,)
#
# Aspect: biaya layanan
#   X_train shape: (68,)
#   X_test shape: (18,)
#   Y_train shape: (68,)
#   Y_test shape: (18,)

# %%
import pickle
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
import ast
import pandas as pd # Ensure pandas is imported

# Use SAVE_ROOT_PATH which correctly points to WORK_DIR/EPOCH 10 (folder kerja Kaggle)
# for constructing the path to the experiment_states directory.
# BASE_DRIVE_PATH currently holds a different WORK_DIR subfolder, which is not correct here.
with open(os.path.join(SAVE_ROOT_PATH, 'experiment_states', 'tokenizer_lstm.pkl'), "rb") as f:
    tokenizer = pickle.load(f)
print("Tokenizer loaded successfully.")

maxlen = 20 # Standardized maxlen
print("Sequences dan padding untuk tiap aspek")
for aspek_name, data in split_data_per_aspek.items():
    print(f"Processing aspek: {aspek_name}")

    def prepare_for_tokenizer(series):
        processed_texts = []
        for item in series:
            if isinstance(item, str):
                try:
                    item = ast.literal_eval(item)
                except (ValueError, SyntaxError):
                    item = []
            if isinstance(item, list) and item:
                processed_texts.append(' '.join(item))
            else:
                processed_texts.append('')
        return pd.Series(processed_texts, index=series.index)

    X_train_texts = prepare_for_tokenizer(data['X_train'])
    X_test_texts = prepare_for_tokenizer(data['X_test'])

    X_train_seq = tokenizer.texts_to_sequences(X_train_texts)
    X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

    # Pad sequences
    X_train_padded = pad_sequences(X_train_seq, maxlen=maxlen, padding='post', truncating='post')
    X_test_padded = pad_sequences(X_test_seq, maxlen=maxlen, padding='post', truncating='post')

    data['X_train_padded'] = X_train_padded
    data['X_test_padded'] = X_test_padded

print("Tokenization and padding complete for all aspek.")

print("Verification of padded data shapes (all aspek):")
for aspek_name, data in split_data_per_aspek.items():
    if 'X_train_padded' in data and 'X_test_padded' in data:
        print(f"aspek: {aspek_name}")
        print(f"  X_train_padded shape: {data['X_train_padded'].shape}")
        print(f"  X_test_padded shape: {data['X_test_padded'].shape}")
# Out:
# Tokenizer loaded successfully.
# Sequences dan padding untuk tiap aspek
# Processing aspek: fasilitas dan infrastruktur
# Processing aspek: kualitas pelayanan medis dan staf
# Processing aspek: lainnya
# Processing aspek: waktu tunggu
# Processing aspek: biaya layanan
# Tokenization and padding complete for all aspek.
# Verification of padded data shapes (all aspek):
# aspek: fasilitas dan infrastruktur
#   X_train_padded shape: (722, 20)
#   X_test_padded shape: (181, 20)
# aspek: kualitas pelayanan medis dan staf
#   X_train_padded shape: (1508, 20)
#   X_test_padded shape: (378, 20)
# aspek: lainnya
#   X_train_padded shape: (1695, 20)
#   X_test_padded shape: (424, 20)
# aspek: waktu tunggu
#   X_train_padded shape: (208, 20)
#   X_test_padded shape: (53, 20)
# aspek: biaya layanan
#   X_train_padded shape: (68, 20)
#   X_test_padded shape: (18, 20)

# %%
import pickle
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
import ast
import pandas as pd # Ensure pandas is imported

# Use SAVE_ROOT_PATH which correctly points to WORK_DIR/EPOCH 05 (folder kerja Kaggle)
# for constructing the path to the experiment_states directory.
# BASE_DRIVE_PATH currently holds a different WORK_DIR subfolder, which is not correct here.
with open(os.path.join(SAVE_ROOT_PATH, 'experiment_states', 'tokenizer_lstm.pkl'), "rb") as f:
    tokenizer = pickle.load(f)
print("Tokenizer loaded successfully.")

maxlen = 20 # Standardized maxlen
print("Sequences dan padding untuk tiap aspek")
for aspek_name, data in split_data_per_aspek.items():
    print(f"Processing aspek: {aspek_name}")

    def prepare_for_tokenizer(series):
        processed_texts = []
        for item in series:
            if isinstance(item, str):
                try:
                    item = ast.literal_eval(item)
                except (ValueError, SyntaxError):
                    item = []
            if isinstance(item, list) and item:
                processed_texts.append(' '.join(item))
            else:
                processed_texts.append('')
        return pd.Series(processed_texts, index=series.index)

    X_train_texts = prepare_for_tokenizer(data['X_train'])
    X_test_texts = prepare_for_tokenizer(data['X_test'])

    X_train_seq = tokenizer.texts_to_sequences(X_train_texts)
    X_test_seq = tokenizer.texts_to_sequences(X_test_texts)

    # Pad sequences
    X_train_padded = pad_sequences(X_train_seq, maxlen=maxlen, padding='post', truncating='post')
    X_test_padded = pad_sequences(X_test_seq, maxlen=maxlen, padding='post', truncating='post')

    data['X_train_padded'] = X_train_padded
    data['X_test_padded'] = X_test_padded

print("Tokenization and padding complete for all aspek.")

print("Verification of padded data shapes (all aspek):")
for aspek_name, data in split_data_per_aspek.items():
    if 'X_train_padded' in data and 'X_test_padded' in data:
        print(f"aspek: {aspek_name}")
        print(f"  X_train_padded shape: {data['X_train_padded'].shape}")
        print(f"  X_test_padded shape: {data['X_test_padded'].shape}")
# Out:
# Tokenizer loaded successfully.
# Sequences dan padding untuk tiap aspek
# Processing aspek: fasilitas dan infrastruktur
# Processing aspek: kualitas pelayanan medis dan staf
# Processing aspek: lainnya
# Processing aspek: waktu tunggu
# Processing aspek: biaya layanan
# Tokenization and padding complete for all aspek.
# Verification of padded data shapes (all aspek):
# aspek: fasilitas dan infrastruktur
#   X_train_padded shape: (722, 20)
#   X_test_padded shape: (181, 20)
# aspek: kualitas pelayanan medis dan staf
#   X_train_padded shape: (1508, 20)
#   X_test_padded shape: (378, 20)
# aspek: lainnya
#   X_train_padded shape: (1695, 20)
#   X_test_padded shape: (424, 20)
# aspek: waktu tunggu
#   X_train_padded shape: (208, 20)
#   X_test_padded shape: (53, 20)
# aspek: biaya layanan
#   X_train_padded shape: (68, 20)
#   X_test_padded shape: (18, 20)

# %%
import tensorflow as tf
import numpy as np
import random
import os

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import (
    Dropout,
    Dense,
    LSTM,
    Embedding
)
from tensorflow.keras.models import Sequential
# from tensorflow.keras.callbacks import EarlyStopping # Removed EarlyStopping

from sklearn.model_selection import KFold

# =========================
# RANDOM SEED
# =========================
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)

# =========================
# PARAMETER
# =========================
vocab_size = 5000
max_len = 20
EPOCHS = 25

# =========================
# PARAMETER UJI COBA DROPOUT
# =========================
if 'DROPOUT_VALUES' not in globals():
    DROPOUT_VALUES = [0.2, 0.5, 0.8]

print(f"Dropout yang akan diuji untuk sentimen per aspek: {DROPOUT_VALUES}")

# =========================
# LOOP TIAP ASPEK
# =========================
for aspek_name, data in split_data_per_aspek.items():

    print("="*70)
    print(f"TRAINING SENTIMEN UNTUK ASPEK: {aspek_name}")
    print("="*70)

    # =========================
    # DATA
    # =========================
    X_pad = data['X_train_padded']
    y = np.array(data['Y_train'])

    num_classes = len(np.unique(y))

    # =========================
    # FOLDER SAVE
    # =========================
    if 'BASE_DRIVE_PATH' not in globals():

        print("❌ BASE_DRIVE_PATH not found.")

        raise SystemExit(
            "Stopping execution: BASE_DRIVE_PATH is not defined."
        )

    save_dir_relative = (
        f"sentiment_models_per_aspect/epoch_{EPOCHS}"
    )

    save_dir_full_path = os.path.join(
        BASE_DRIVE_PATH,
        save_dir_relative
    )

    os.makedirs(
        save_dir_full_path,
        exist_ok=True
    )

    # =========================
    # LOOP TIAP NILAI DROPOUT
    # =========================
    for dropout_rate in DROPOUT_VALUES:

        dropout_tag = str(dropout_rate).replace('.', '_')

        print("\n" + "#"*60)
        print(f"# ASPEK '{aspek_name}' | DROPOUT = {dropout_rate}")
        print("#"*60)

        # =========================
        # KFOLD
        # =========================
        skf = KFold(
            n_splits=5,
            shuffle=True,
            random_state=SEED
        )

        print("="*60)
        print(f"TRAINING DENGAN MAX EPOCH = {EPOCHS}")
        print("="*60)

        # best_val_loss = float('inf') # Removed as EarlyStopping is removed
        fold_no = 1

        fold_accuracies = []

        # =========================
        # KFOLD LOOP
        # =========================
        for train_idx, val_idx in skf.split(X_pad):

            print(f"\n====== Dropout {dropout_rate} | Fold {fold_no} ======")

            # =========================
            # SPLIT DATA
            # =========================
            X_tr = X_pad[train_idx]
            X_val = X_pad[val_idx]

            y_tr = y[train_idx]
            y_val = y[val_idx]

            # =========================
            # MODEL LSTM
            # =========================
            model = Sequential([

                Embedding(
                    input_dim=vocab_size,
                    output_dim=128,
                    mask_zero=True
                ),

                LSTM(
                    128,
                    return_sequences=True,
                    dropout=dropout_rate,
                    recurrent_dropout=dropout_rate
                ),

                LSTM(
                    64,
                    dropout=dropout_rate,
                    recurrent_dropout=dropout_rate
                ),

                Dense(
                    128,
                    activation='relu'
                ),

                Dropout(dropout_rate),

                Dense(
                    num_classes,
                    activation='softmax'
                )
            ])

            # =========================
            # COMPILE
            # =========================
            model.compile(
                optimizer=Adam(
                    learning_rate=0.0005
                ),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']
            )

            # =========================
            # EARLY STOPPING - REMOVED
            # =========================
            # early_stopping = EarlyStopping(
            #     monitor='val_loss',
            #     patience=2,
            #     restore_best_weights=True,
            #     verbose=1
            # )

            # =========================
            # TRAINING
            # =========================
            history = model.fit(
                X_tr,
                y_tr,
                epochs=EPOCHS,
                batch_size=32,
                validation_data=(X_val, y_val),
                # callbacks=[early_stopping], # Removed early_stopping from callbacks
                verbose=1
            )

            # =========================
            # EVALUASI
            # =========================
            scores = model.evaluate(
                X_val,
                y_val,
                verbose=0
            )

            print(f"\nDropout {dropout_rate} | Fold {fold_no}")
            print(f"Loss     : {scores[0]:.4f}")
            print(f"Accuracy : {scores[1]:.4f}")

            fold_accuracies.append(
                scores[1]
            )

            # =========================
            # SAVE MODEL FOR EACH FOLD
            # =========================
            # Nama file sekarang menyertakan nilai dropout supaya tiap konfigurasi
            # bisa dibandingkan pada cell evaluasi berikutnya.
            file_name = (
                f"sentiment_model_{aspek_name.replace(' ', '_').replace('/', '_').lower()}"
                f"_dropout_{dropout_tag}_fold_{fold_no}.keras"
            )

            model.save(
                os.path.join(
                    save_dir_full_path,
                    file_name
                )
            )

            print(
                f"Model for '{aspek_name}' Dropout {dropout_rate} Fold {fold_no} saved to:\n"
                f"{os.path.join(save_dir_full_path, file_name)}"
            )

            fold_no += 1

        # =========================
        # RATA-RATA KFOLD UNTUK DROPOUT INI
        # =========================
        avg_acc = np.mean(
            fold_accuracies
        )

        print("\n" + "="*60)
        print(f"RATA-RATA AKURASI ASPEK '{aspek_name}' | DROPOUT {dropout_rate}")
        print("="*60)

        print(
            f"Average Accuracy : "
            f"{avg_acc:.4f}"
        )
# Out:
# Dropout yang akan diuji untuk sentimen per aspek: [0.2, 0.5, 0.8]
# ======================================================================
# TRAINING SENTIMEN UNTUK ASPEK: fasilitas dan infrastruktur
# ======================================================================
#
# ############################################################
# # ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.2
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 25
# ============================================================
#
# ====== Dropout 0.2 | Fold 1 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.6863 - loss: 1.0642 - val_accuracy: 0.6621 - val_loss: 1.0011
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.6932 - loss: 0.8740 - val_accuracy: 0.6621 - val_loss: 0.8165
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6950 - loss: 0.6625 - val_accuracy: 0.6690 - val_loss: 0.7040
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.7938 - loss: 0.5406 - val_accuracy: 0.7586 - val_loss: 0.6171
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.8544 - loss: 0.4321 - val_accuracy: 0.7931 - val_loss: 0.5059
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.8977 - loss: 0.3311 - val_accuracy: 0.8483 - val_loss: 0.4059
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9168 - loss: 0.2405 - val_accuracy: 0.8690 - val_loss: 0.3402
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9376 - loss: 0.1696 - val_accuracy: 0.9241 - val_loss: 0.3194
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9775 - loss: 0.1234 - val_accuracy: 0.9103 - val_loss: 0.3163
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9757 - loss: 0.1032 - val_accuracy: 0.9103 - val_loss: 0.3360
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9775 - loss: 0.0829 - val_accuracy: 0.9034 - val_loss: 0.3467
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9827 - loss: 0.0717 - val_accuracy: 0.8966 - val_loss: 0.3602
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9809 - loss: 0.0613 - val_accuracy: 0.8897 - val_loss: 0.3668
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9792 - loss: 0.0546 - val_accuracy: 0.8828 - val_loss: 0.4049
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 0.9827 - loss: 0.0550 - val_accuracy: 0.8966 - val_loss: 0.3744
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9896 - loss: 0.0430 - val_accuracy: 0.8966 - val_loss: 0.3945
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9896 - loss: 0.0361 - val_accuracy: 0.8828 - val_loss: 0.4083
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9879 - loss: 0.0329 - val_accuracy: 0.8966 - val_loss: 0.4301
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9913 - loss: 0.0300 - val_accuracy: 0.8966 - val_loss: 0.4422
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9965 - loss: 0.0234 - val_accuracy: 0.9034 - val_loss: 0.4418
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9931 - loss: 0.0284 - val_accuracy: 0.9103 - val_loss: 0.4726
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9948 - loss: 0.0201 - val_accuracy: 0.9103 - val_loss: 0.4720
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9965 - loss: 0.0171 - val_accuracy: 0.9103 - val_loss: 0.4784
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9965 - loss: 0.0187 - val_accuracy: 0.9103 - val_loss: 0.4937
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9983 - loss: 0.0117 - val_accuracy: 0.8966 - val_loss: 0.5214
#
# Dropout 0.2 | Fold 1
# Loss     : 0.5214
# Accuracy : 0.8966
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 1 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_1.keras
#
# ====== Dropout 0.2 | Fold 2 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.6638 - loss: 1.0727 - val_accuracy: 0.6897 - val_loss: 1.0266
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.6863 - loss: 0.9318 - val_accuracy: 0.6897 - val_loss: 0.7794
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6863 - loss: 0.6909 - val_accuracy: 0.6897 - val_loss: 0.6722
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.7608 - loss: 0.5515 - val_accuracy: 0.7586 - val_loss: 0.5853
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.8475 - loss: 0.4412 - val_accuracy: 0.7931 - val_loss: 0.4963
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.8943 - loss: 0.3263 - val_accuracy: 0.8207 - val_loss: 0.4133
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - accuracy: 0.9289 - loss: 0.2115 - val_accuracy: 0.8621 - val_loss: 0.3880
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9636 - loss: 0.1393 - val_accuracy: 0.8966 - val_loss: 0.4022
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9705 - loss: 0.1052 - val_accuracy: 0.9034 - val_loss: 0.4184
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9757 - loss: 0.0883 - val_accuracy: 0.9172 - val_loss: 0.4296
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - accuracy: 0.9775 - loss: 0.0716 - val_accuracy: 0.9034 - val_loss: 0.4569
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.9809 - loss: 0.0638 - val_accuracy: 0.8966 - val_loss: 0.4828
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9809 - loss: 0.0495 - val_accuracy: 0.8966 - val_loss: 0.5210
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9861 - loss: 0.0425 - val_accuracy: 0.8897 - val_loss: 0.5611
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9965 - loss: 0.0328 - val_accuracy: 0.8897 - val_loss: 0.5760
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9948 - loss: 0.0286 - val_accuracy: 0.8966 - val_loss: 0.6220
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9983 - loss: 0.0189 - val_accuracy: 0.8966 - val_loss: 0.6379
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9965 - loss: 0.0193 - val_accuracy: 0.8966 - val_loss: 0.6983
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9965 - loss: 0.0151 - val_accuracy: 0.8966 - val_loss: 0.6973
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9983 - loss: 0.0099 - val_accuracy: 0.8966 - val_loss: 0.7122
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9983 - loss: 0.0101 - val_accuracy: 0.8966 - val_loss: 0.7450
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9983 - loss: 0.0096 - val_accuracy: 0.8966 - val_loss: 0.7663
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9983 - loss: 0.0066 - val_accuracy: 0.8897 - val_loss: 0.8092
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9965 - loss: 0.0083 - val_accuracy: 0.8966 - val_loss: 0.7925
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9983 - loss: 0.0080 - val_accuracy: 0.8966 - val_loss: 0.8214
#
# Dropout 0.2 | Fold 2
# Loss     : 0.8214
# Accuracy : 0.8966
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 2 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_2.keras
#
# ====== Dropout 0.2 | Fold 3 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 187ms/step - accuracy: 0.6592 - loss: 1.0689 - val_accuracy: 0.7014 - val_loss: 1.0070
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6834 - loss: 0.9148 - val_accuracy: 0.7014 - val_loss: 0.7038
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6834 - loss: 0.6950 - val_accuracy: 0.7014 - val_loss: 0.5729
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.7474 - loss: 0.5515 - val_accuracy: 0.7917 - val_loss: 0.4409
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.8512 - loss: 0.4228 - val_accuracy: 0.9028 - val_loss: 0.3263
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9083 - loss: 0.3066 - val_accuracy: 0.9583 - val_loss: 0.2279
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 149ms/step - accuracy: 0.9464 - loss: 0.2214 - val_accuracy: 0.9653 - val_loss: 0.1714
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9585 - loss: 0.1792 - val_accuracy: 0.9653 - val_loss: 0.1484
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9689 - loss: 0.1454 - val_accuracy: 0.9653 - val_loss: 0.1321
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9706 - loss: 0.1191 - val_accuracy: 0.9653 - val_loss: 0.1244
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9723 - loss: 0.1088 - val_accuracy: 0.9653 - val_loss: 0.1201
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9723 - loss: 0.0898 - val_accuracy: 0.9653 - val_loss: 0.1177
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9758 - loss: 0.0884 - val_accuracy: 0.9653 - val_loss: 0.1143
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9810 - loss: 0.0767 - val_accuracy: 0.9653 - val_loss: 0.1176
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9844 - loss: 0.0669 - val_accuracy: 0.9653 - val_loss: 0.1195
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9810 - loss: 0.0649 - val_accuracy: 0.9653 - val_loss: 0.1173
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9844 - loss: 0.0521 - val_accuracy: 0.9653 - val_loss: 0.1128
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9827 - loss: 0.0482 - val_accuracy: 0.9653 - val_loss: 0.1182
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 146ms/step - accuracy: 0.9844 - loss: 0.0468 - val_accuracy: 0.9722 - val_loss: 0.0991
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9948 - loss: 0.0376 - val_accuracy: 0.9792 - val_loss: 0.1075
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9965 - loss: 0.0298 - val_accuracy: 0.9792 - val_loss: 0.1021
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9965 - loss: 0.0257 - val_accuracy: 0.9792 - val_loss: 0.1008
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9948 - loss: 0.0251 - val_accuracy: 0.9792 - val_loss: 0.1057
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9948 - loss: 0.0228 - val_accuracy: 0.9722 - val_loss: 0.1097
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9965 - loss: 0.0164 - val_accuracy: 0.9722 - val_loss: 0.1119
#
# Dropout 0.2 | Fold 3
# Loss     : 0.1119
# Accuracy : 0.9722
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 3 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_3.keras
#
# ====== Dropout 0.2 | Fold 4 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 185ms/step - accuracy: 0.6782 - loss: 1.0664 - val_accuracy: 0.7014 - val_loss: 1.0047
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6834 - loss: 0.8980 - val_accuracy: 0.7014 - val_loss: 0.7039
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.6834 - loss: 0.6948 - val_accuracy: 0.7014 - val_loss: 0.5723
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.7474 - loss: 0.5556 - val_accuracy: 0.7917 - val_loss: 0.4543
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.8322 - loss: 0.4228 - val_accuracy: 0.8889 - val_loss: 0.3548
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9204 - loss: 0.2916 - val_accuracy: 0.9375 - val_loss: 0.2678
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9637 - loss: 0.1915 - val_accuracy: 0.9167 - val_loss: 0.2381
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9706 - loss: 0.1510 - val_accuracy: 0.9236 - val_loss: 0.2409
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9706 - loss: 0.1216 - val_accuracy: 0.9236 - val_loss: 0.2517
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9775 - loss: 0.0962 - val_accuracy: 0.9236 - val_loss: 0.2672
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9758 - loss: 0.0935 - val_accuracy: 0.9236 - val_loss: 0.2753
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9827 - loss: 0.0824 - val_accuracy: 0.9236 - val_loss: 0.2826
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9810 - loss: 0.0713 - val_accuracy: 0.9167 - val_loss: 0.2866
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9844 - loss: 0.0648 - val_accuracy: 0.9236 - val_loss: 0.3012
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9844 - loss: 0.0640 - val_accuracy: 0.9236 - val_loss: 0.3118
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9844 - loss: 0.0586 - val_accuracy: 0.9236 - val_loss: 0.3172
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9844 - loss: 0.0554 - val_accuracy: 0.9167 - val_loss: 0.3322
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9862 - loss: 0.0478 - val_accuracy: 0.9236 - val_loss: 0.3474
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9862 - loss: 0.0505 - val_accuracy: 0.9236 - val_loss: 0.3499
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9862 - loss: 0.0466 - val_accuracy: 0.9167 - val_loss: 0.3671
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9879 - loss: 0.0377 - val_accuracy: 0.9097 - val_loss: 0.3782
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9862 - loss: 0.0383 - val_accuracy: 0.9167 - val_loss: 0.3873
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9931 - loss: 0.0310 - val_accuracy: 0.9167 - val_loss: 0.4056
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9948 - loss: 0.0261 - val_accuracy: 0.9236 - val_loss: 0.4164
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9931 - loss: 0.0263 - val_accuracy: 0.9375 - val_loss: 0.3987
#
# Dropout 0.2 | Fold 4
# Loss     : 0.3987
# Accuracy : 0.9375
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 4 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_4.keras
#
# ====== Dropout 0.2 | Fold 5 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 193ms/step - accuracy: 0.6782 - loss: 1.0741 - val_accuracy: 0.6806 - val_loss: 1.0313
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.6886 - loss: 0.9390 - val_accuracy: 0.6806 - val_loss: 0.7884
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.6886 - loss: 0.6873 - val_accuracy: 0.6944 - val_loss: 0.6428
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.7958 - loss: 0.5297 - val_accuracy: 0.7986 - val_loss: 0.5181
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.8616 - loss: 0.3794 - val_accuracy: 0.8472 - val_loss: 0.4154
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9152 - loss: 0.2518 - val_accuracy: 0.8542 - val_loss: 0.3717
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9516 - loss: 0.1728 - val_accuracy: 0.9097 - val_loss: 0.3961
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 131ms/step - accuracy: 0.9706 - loss: 0.1362 - val_accuracy: 0.9167 - val_loss: 0.3897
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9706 - loss: 0.1034 - val_accuracy: 0.8958 - val_loss: 0.4301
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9723 - loss: 0.0876 - val_accuracy: 0.9097 - val_loss: 0.4228
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9792 - loss: 0.0769 - val_accuracy: 0.9028 - val_loss: 0.4789
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9827 - loss: 0.0683 - val_accuracy: 0.9097 - val_loss: 0.4688
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9827 - loss: 0.0672 - val_accuracy: 0.9097 - val_loss: 0.4774
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9827 - loss: 0.0584 - val_accuracy: 0.9167 - val_loss: 0.5056
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9827 - loss: 0.0561 - val_accuracy: 0.9167 - val_loss: 0.5260
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9827 - loss: 0.0572 - val_accuracy: 0.9167 - val_loss: 0.5531
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9827 - loss: 0.0516 - val_accuracy: 0.9167 - val_loss: 0.5541
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9844 - loss: 0.0453 - val_accuracy: 0.9167 - val_loss: 0.5672
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9844 - loss: 0.0427 - val_accuracy: 0.9167 - val_loss: 0.5601
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9931 - loss: 0.0365 - val_accuracy: 0.9167 - val_loss: 0.5706
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9948 - loss: 0.0320 - val_accuracy: 0.9167 - val_loss: 0.5724
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9965 - loss: 0.0285 - val_accuracy: 0.9167 - val_loss: 0.6168
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9983 - loss: 0.0224 - val_accuracy: 0.9236 - val_loss: 0.6322
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.9983 - loss: 0.0188 - val_accuracy: 0.9236 - val_loss: 0.6838
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9983 - loss: 0.0136 - val_accuracy: 0.9236 - val_loss: 0.6890
#
# Dropout 0.2 | Fold 5
# Loss     : 0.6890
# Accuracy : 0.9236
# Model for 'fasilitas dan infrastruktur' Dropout 0.2 Fold 5 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_2_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'fasilitas dan infrastruktur' | DROPOUT 0.2
# ============================================================
# Average Accuracy : 0.9253
#
# ############################################################
# # ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.5
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 25
# ============================================================
#
# ====== Dropout 0.5 | Fold 1 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.6690 - loss: 1.0729 - val_accuracy: 0.6621 - val_loss: 1.0340
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6932 - loss: 0.9730 - val_accuracy: 0.6621 - val_loss: 0.8782
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.6932 - loss: 0.7647 - val_accuracy: 0.6621 - val_loss: 0.8021
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6932 - loss: 0.6433 - val_accuracy: 0.6621 - val_loss: 0.6747
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.7522 - loss: 0.5194 - val_accuracy: 0.7517 - val_loss: 0.6098
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.8371 - loss: 0.4303 - val_accuracy: 0.7862 - val_loss: 0.5367
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.8821 - loss: 0.3516 - val_accuracy: 0.8483 - val_loss: 0.4244
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9099 - loss: 0.2652 - val_accuracy: 0.8621 - val_loss: 0.3558
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9133 - loss: 0.2208 - val_accuracy: 0.8759 - val_loss: 0.3159
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9359 - loss: 0.1754 - val_accuracy: 0.9172 - val_loss: 0.3024
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9567 - loss: 0.1348 - val_accuracy: 0.9310 - val_loss: 0.3105
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9723 - loss: 0.1117 - val_accuracy: 0.9172 - val_loss: 0.3059
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9757 - loss: 0.1026 - val_accuracy: 0.9103 - val_loss: 0.3239
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9757 - loss: 0.0912 - val_accuracy: 0.9103 - val_loss: 0.3345
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9740 - loss: 0.0844 - val_accuracy: 0.9034 - val_loss: 0.3391
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9861 - loss: 0.0688 - val_accuracy: 0.9034 - val_loss: 0.3480
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9775 - loss: 0.0777 - val_accuracy: 0.9034 - val_loss: 0.3810
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9827 - loss: 0.0619 - val_accuracy: 0.9103 - val_loss: 0.3638
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9861 - loss: 0.0699 - val_accuracy: 0.8966 - val_loss: 0.3813
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9792 - loss: 0.0588 - val_accuracy: 0.8966 - val_loss: 0.4051
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.9879 - loss: 0.0444 - val_accuracy: 0.8966 - val_loss: 0.4022
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9879 - loss: 0.0519 - val_accuracy: 0.8897 - val_loss: 0.4431
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9896 - loss: 0.0415 - val_accuracy: 0.8897 - val_loss: 0.4444
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9879 - loss: 0.0436 - val_accuracy: 0.9103 - val_loss: 0.4314
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9879 - loss: 0.0439 - val_accuracy: 0.9103 - val_loss: 0.4319
#
# Dropout 0.5 | Fold 1
# Loss     : 0.4319
# Accuracy : 0.9103
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 1 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_1.keras
#
# ====== Dropout 0.5 | Fold 2 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.6586 - loss: 1.0762 - val_accuracy: 0.6897 - val_loss: 1.0384
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.6863 - loss: 0.9868 - val_accuracy: 0.6897 - val_loss: 0.8943
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6863 - loss: 0.8005 - val_accuracy: 0.6897 - val_loss: 0.7318
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.6863 - loss: 0.6642 - val_accuracy: 0.6897 - val_loss: 0.6575
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.7383 - loss: 0.5549 - val_accuracy: 0.7517 - val_loss: 0.5785
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.8267 - loss: 0.4576 - val_accuracy: 0.7931 - val_loss: 0.4991
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.8908 - loss: 0.3661 - val_accuracy: 0.8345 - val_loss: 0.4331
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9168 - loss: 0.2790 - val_accuracy: 0.8345 - val_loss: 0.3943
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9272 - loss: 0.1934 - val_accuracy: 0.8552 - val_loss: 0.3807
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9428 - loss: 0.1445 - val_accuracy: 0.9103 - val_loss: 0.3844
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9653 - loss: 0.1244 - val_accuracy: 0.9103 - val_loss: 0.4035
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9757 - loss: 0.1106 - val_accuracy: 0.9172 - val_loss: 0.4046
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9740 - loss: 0.0867 - val_accuracy: 0.9241 - val_loss: 0.4092
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9723 - loss: 0.0831 - val_accuracy: 0.9310 - val_loss: 0.4328
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9792 - loss: 0.0702 - val_accuracy: 0.9172 - val_loss: 0.4491
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9792 - loss: 0.0693 - val_accuracy: 0.9172 - val_loss: 0.4764
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9809 - loss: 0.0656 - val_accuracy: 0.9103 - val_loss: 0.5043
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9792 - loss: 0.0541 - val_accuracy: 0.9103 - val_loss: 0.5119
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9809 - loss: 0.0497 - val_accuracy: 0.9172 - val_loss: 0.5038
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9861 - loss: 0.0420 - val_accuracy: 0.9172 - val_loss: 0.5300
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9896 - loss: 0.0390 - val_accuracy: 0.9103 - val_loss: 0.5621
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9913 - loss: 0.0321 - val_accuracy: 0.9172 - val_loss: 0.5836
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9931 - loss: 0.0315 - val_accuracy: 0.9172 - val_loss: 0.5936
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9931 - loss: 0.0287 - val_accuracy: 0.9172 - val_loss: 0.5870
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9931 - loss: 0.0219 - val_accuracy: 0.9103 - val_loss: 0.6154
#
# Dropout 0.5 | Fold 2
# Loss     : 0.6154
# Accuracy : 0.9103
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 2 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_2.keras
#
# ====== Dropout 0.5 | Fold 3 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.6592 - loss: 1.0767 - val_accuracy: 0.7014 - val_loss: 1.0376
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.6834 - loss: 0.9918 - val_accuracy: 0.7014 - val_loss: 0.8740
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.6834 - loss: 0.8013 - val_accuracy: 0.7014 - val_loss: 0.6524
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6851 - loss: 0.6645 - val_accuracy: 0.7014 - val_loss: 0.5491
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.7266 - loss: 0.5494 - val_accuracy: 0.8056 - val_loss: 0.4365
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.8443 - loss: 0.4424 - val_accuracy: 0.8542 - val_loss: 0.3380
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.8979 - loss: 0.3306 - val_accuracy: 0.8958 - val_loss: 0.2436
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9083 - loss: 0.2545 - val_accuracy: 0.9097 - val_loss: 0.1865
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9221 - loss: 0.2241 - val_accuracy: 0.9167 - val_loss: 0.1604
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9273 - loss: 0.1900 - val_accuracy: 0.9306 - val_loss: 0.1451
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9567 - loss: 0.1618 - val_accuracy: 0.9722 - val_loss: 0.1274
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9533 - loss: 0.1533 - val_accuracy: 0.9722 - val_loss: 0.1182
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9637 - loss: 0.1331 - val_accuracy: 0.9722 - val_loss: 0.1144
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9740 - loss: 0.1066 - val_accuracy: 0.9722 - val_loss: 0.1054
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.9758 - loss: 0.0952 - val_accuracy: 0.9722 - val_loss: 0.1009
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9740 - loss: 0.0964 - val_accuracy: 0.9722 - val_loss: 0.0966
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9740 - loss: 0.0948 - val_accuracy: 0.9653 - val_loss: 0.0901
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9775 - loss: 0.0817 - val_accuracy: 0.9722 - val_loss: 0.0895
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9758 - loss: 0.0800 - val_accuracy: 0.9722 - val_loss: 0.0861
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9740 - loss: 0.0855 - val_accuracy: 0.9722 - val_loss: 0.0799
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9810 - loss: 0.0635 - val_accuracy: 0.9583 - val_loss: 0.0923
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9792 - loss: 0.0755 - val_accuracy: 0.9792 - val_loss: 0.0810
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9862 - loss: 0.0585 - val_accuracy: 0.9792 - val_loss: 0.0720
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9758 - loss: 0.0628 - val_accuracy: 0.9722 - val_loss: 0.0728
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9827 - loss: 0.0587 - val_accuracy: 0.9722 - val_loss: 0.0780
#
# Dropout 0.5 | Fold 3
# Loss     : 0.0780
# Accuracy : 0.9722
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 3 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_3.keras
#
# ====== Dropout 0.5 | Fold 4 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 185ms/step - accuracy: 0.6488 - loss: 1.0751 - val_accuracy: 0.7014 - val_loss: 1.0366
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.6834 - loss: 0.9871 - val_accuracy: 0.7014 - val_loss: 0.8793
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.6834 - loss: 0.7923 - val_accuracy: 0.7014 - val_loss: 0.6625
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6886 - loss: 0.6875 - val_accuracy: 0.7014 - val_loss: 0.5719
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.7370 - loss: 0.5676 - val_accuracy: 0.8056 - val_loss: 0.4638
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.8304 - loss: 0.4539 - val_accuracy: 0.8681 - val_loss: 0.3750
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.8858 - loss: 0.3470 - val_accuracy: 0.8819 - val_loss: 0.2987
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9118 - loss: 0.2519 - val_accuracy: 0.9028 - val_loss: 0.2429
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9256 - loss: 0.2156 - val_accuracy: 0.9167 - val_loss: 0.2231
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.9619 - loss: 0.1534 - val_accuracy: 0.9236 - val_loss: 0.2271
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9758 - loss: 0.1279 - val_accuracy: 0.9167 - val_loss: 0.2410
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9740 - loss: 0.1259 - val_accuracy: 0.9236 - val_loss: 0.2507
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9706 - loss: 0.1192 - val_accuracy: 0.9167 - val_loss: 0.2563
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9740 - loss: 0.0931 - val_accuracy: 0.9167 - val_loss: 0.2695
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.9758 - loss: 0.0884 - val_accuracy: 0.9167 - val_loss: 0.2797
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9792 - loss: 0.0756 - val_accuracy: 0.9097 - val_loss: 0.2929
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9758 - loss: 0.0727 - val_accuracy: 0.9097 - val_loss: 0.2972
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9775 - loss: 0.0727 - val_accuracy: 0.9167 - val_loss: 0.3109
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9792 - loss: 0.0681 - val_accuracy: 0.9167 - val_loss: 0.3140
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9810 - loss: 0.0600 - val_accuracy: 0.9167 - val_loss: 0.2977
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9792 - loss: 0.0555 - val_accuracy: 0.9306 - val_loss: 0.3217
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9862 - loss: 0.0506 - val_accuracy: 0.9167 - val_loss: 0.3298
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9810 - loss: 0.0547 - val_accuracy: 0.9236 - val_loss: 0.3327
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9810 - loss: 0.0492 - val_accuracy: 0.9306 - val_loss: 0.3337
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9913 - loss: 0.0353 - val_accuracy: 0.9306 - val_loss: 0.3464
#
# Dropout 0.5 | Fold 4
# Loss     : 0.3464
# Accuracy : 0.9306
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 4 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_4.keras
#
# ====== Dropout 0.5 | Fold 5 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 186ms/step - accuracy: 0.6661 - loss: 1.0737 - val_accuracy: 0.6806 - val_loss: 1.0352
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.6886 - loss: 0.9723 - val_accuracy: 0.6806 - val_loss: 0.8733
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.6886 - loss: 0.7696 - val_accuracy: 0.6806 - val_loss: 0.7214
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.6920 - loss: 0.6420 - val_accuracy: 0.7014 - val_loss: 0.6234
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.7664 - loss: 0.5328 - val_accuracy: 0.7708 - val_loss: 0.5559
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.8374 - loss: 0.4247 - val_accuracy: 0.7917 - val_loss: 0.5121
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.8875 - loss: 0.3460 - val_accuracy: 0.8125 - val_loss: 0.4814
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9204 - loss: 0.2497 - val_accuracy: 0.8264 - val_loss: 0.4502
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9308 - loss: 0.1881 - val_accuracy: 0.8472 - val_loss: 0.4467
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9412 - loss: 0.1507 - val_accuracy: 0.8472 - val_loss: 0.4533
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9516 - loss: 0.1283 - val_accuracy: 0.9097 - val_loss: 0.4645
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9689 - loss: 0.0926 - val_accuracy: 0.9097 - val_loss: 0.4826
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9706 - loss: 0.0953 - val_accuracy: 0.9028 - val_loss: 0.4935
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9706 - loss: 0.0929 - val_accuracy: 0.9028 - val_loss: 0.4759
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9723 - loss: 0.0849 - val_accuracy: 0.9028 - val_loss: 0.5035
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9758 - loss: 0.0641 - val_accuracy: 0.9028 - val_loss: 0.5313
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9740 - loss: 0.0711 - val_accuracy: 0.9028 - val_loss: 0.5238
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9758 - loss: 0.0645 - val_accuracy: 0.9167 - val_loss: 0.5046
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9758 - loss: 0.0679 - val_accuracy: 0.9097 - val_loss: 0.5223
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9810 - loss: 0.0580 - val_accuracy: 0.9097 - val_loss: 0.5136
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.9792 - loss: 0.0613 - val_accuracy: 0.9236 - val_loss: 0.5055
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9844 - loss: 0.0536 - val_accuracy: 0.9097 - val_loss: 0.5440
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9879 - loss: 0.0433 - val_accuracy: 0.9167 - val_loss: 0.5651
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9862 - loss: 0.0490 - val_accuracy: 0.9167 - val_loss: 0.5556
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9862 - loss: 0.0358 - val_accuracy: 0.9236 - val_loss: 0.5235
#
# Dropout 0.5 | Fold 5
# Loss     : 0.5235
# Accuracy : 0.9236
# Model for 'fasilitas dan infrastruktur' Dropout 0.5 Fold 5 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_5_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'fasilitas dan infrastruktur' | DROPOUT 0.5
# ============================================================
# Average Accuracy : 0.9294
#
# ############################################################
# # ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.8
# ############################################################
# ============================================================
# TRAINING DENGAN MAX EPOCH = 25
# ============================================================
#
# ====== Dropout 0.8 | Fold 1 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.5581 - loss: 1.0843 - val_accuracy: 0.6621 - val_loss: 1.0654
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6915 - loss: 1.0435 - val_accuracy: 0.6621 - val_loss: 1.0187
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6932 - loss: 0.9881 - val_accuracy: 0.6621 - val_loss: 0.9502
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.6932 - loss: 0.8969 - val_accuracy: 0.6621 - val_loss: 0.8542
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.6932 - loss: 0.8116 - val_accuracy: 0.6621 - val_loss: 0.7982
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6932 - loss: 0.7701 - val_accuracy: 0.6621 - val_loss: 0.7720
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.6932 - loss: 0.7373 - val_accuracy: 0.6621 - val_loss: 0.7258
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.6932 - loss: 0.6767 - val_accuracy: 0.6621 - val_loss: 0.6765
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.6984 - loss: 0.6122 - val_accuracy: 0.6621 - val_loss: 0.6404
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.7192 - loss: 0.5508 - val_accuracy: 0.7034 - val_loss: 0.6086
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.7782 - loss: 0.4914 - val_accuracy: 0.7724 - val_loss: 0.5590
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.8284 - loss: 0.4524 - val_accuracy: 0.7793 - val_loss: 0.5221
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.8336 - loss: 0.4178 - val_accuracy: 0.8207 - val_loss: 0.4672
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.8562 - loss: 0.3839 - val_accuracy: 0.8207 - val_loss: 0.4173
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.8891 - loss: 0.3414 - val_accuracy: 0.8276 - val_loss: 0.3963
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.8908 - loss: 0.3052 - val_accuracy: 0.8345 - val_loss: 0.3901
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9012 - loss: 0.2688 - val_accuracy: 0.8621 - val_loss: 0.3799
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9185 - loss: 0.2356 - val_accuracy: 0.8828 - val_loss: 0.3586
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9376 - loss: 0.2225 - val_accuracy: 0.8690 - val_loss: 0.3552
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9289 - loss: 0.2004 - val_accuracy: 0.8897 - val_loss: 0.3529
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9480 - loss: 0.1884 - val_accuracy: 0.8897 - val_loss: 0.3472
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9393 - loss: 0.1853 - val_accuracy: 0.8828 - val_loss: 0.3510
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9445 - loss: 0.1768 - val_accuracy: 0.8759 - val_loss: 0.3532
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9567 - loss: 0.1512 - val_accuracy: 0.8828 - val_loss: 0.3643
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9636 - loss: 0.1588 - val_accuracy: 0.8897 - val_loss: 0.3647
#
# Dropout 0.8 | Fold 1
# Loss     : 0.3647
# Accuracy : 0.8897
# Model for 'fasilitas dan infrastruktur' Dropout 0.8 Fold 1 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_8_fold_1.keras
#
# ====== Dropout 0.8 | Fold 2 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 12s 187ms/step - accuracy: 0.5130 - loss: 1.0859 - val_accuracy: 0.6897 - val_loss: 1.0608
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6863 - loss: 1.0430 - val_accuracy: 0.6897 - val_loss: 1.0101
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6863 - loss: 0.9853 - val_accuracy: 0.6897 - val_loss: 0.9388
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6863 - loss: 0.9030 - val_accuracy: 0.6897 - val_loss: 0.8480
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.6863 - loss: 0.8261 - val_accuracy: 0.6897 - val_loss: 0.7824
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.6863 - loss: 0.7909 - val_accuracy: 0.6897 - val_loss: 0.7586
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6863 - loss: 0.7680 - val_accuracy: 0.6897 - val_loss: 0.7359
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6863 - loss: 0.7122 - val_accuracy: 0.6897 - val_loss: 0.7025
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.6863 - loss: 0.6579 - val_accuracy: 0.6897 - val_loss: 0.6608
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.6932 - loss: 0.6152 - val_accuracy: 0.6759 - val_loss: 0.6146
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.7314 - loss: 0.5490 - val_accuracy: 0.7517 - val_loss: 0.5703
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.7799 - loss: 0.4965 - val_accuracy: 0.7655 - val_loss: 0.5317
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.8371 - loss: 0.4344 - val_accuracy: 0.7862 - val_loss: 0.4814
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 142ms/step - accuracy: 0.8752 - loss: 0.3797 - val_accuracy: 0.8069 - val_loss: 0.4499
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.8821 - loss: 0.3315 - val_accuracy: 0.8276 - val_loss: 0.4295
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9012 - loss: 0.2871 - val_accuracy: 0.8276 - val_loss: 0.4276
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.8960 - loss: 0.2727 - val_accuracy: 0.8414 - val_loss: 0.4180
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9220 - loss: 0.2636 - val_accuracy: 0.8414 - val_loss: 0.4023
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9220 - loss: 0.2240 - val_accuracy: 0.8552 - val_loss: 0.3984
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9255 - loss: 0.1810 - val_accuracy: 0.8621 - val_loss: 0.3985
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.9341 - loss: 0.1640 - val_accuracy: 0.8759 - val_loss: 0.4081
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9324 - loss: 0.1765 - val_accuracy: 0.8966 - val_loss: 0.4046
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9463 - loss: 0.1505 - val_accuracy: 0.8966 - val_loss: 0.3992
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9532 - loss: 0.1501 - val_accuracy: 0.9103 - val_loss: 0.4083
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 140ms/step - accuracy: 0.9411 - loss: 0.1561 - val_accuracy: 0.9103 - val_loss: 0.4099
#
# Dropout 0.8 | Fold 2
# Loss     : 0.4099
# Accuracy : 0.9103
# Model for 'fasilitas dan infrastruktur' Dropout 0.8 Fold 2 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 191ms/step - accuracy: 0.5727 - loss: 1.0835 - val_accuracy: 0.7014 - val_loss: 1.0600
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6851 - loss: 1.0406 - val_accuracy: 0.7014 - val_loss: 1.0073
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 143ms/step - accuracy: 0.6834 - loss: 0.9836 - val_accuracy: 0.7014 - val_loss: 0.9283
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.6817 - loss: 0.9118 - val_accuracy: 0.7014 - val_loss: 0.8247
# Epoch 5/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 141ms/step - accuracy: 0.6834 - loss: 0.8300 - val_accuracy: 0.7014 - val_loss: 0.7489
# Epoch 6/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.6834 - loss: 0.7826 - val_accuracy: 0.7014 - val_loss: 0.7121
# Epoch 7/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6834 - loss: 0.7559 - val_accuracy: 0.7014 - val_loss: 0.6780
# Epoch 8/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6834 - loss: 0.7235 - val_accuracy: 0.7014 - val_loss: 0.6309
# Epoch 9/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.6851 - loss: 0.6739 - val_accuracy: 0.7014 - val_loss: 0.5669
# Epoch 10/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.7163 - loss: 0.6071 - val_accuracy: 0.7431 - val_loss: 0.5010
# Epoch 11/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.7509 - loss: 0.5561 - val_accuracy: 0.8194 - val_loss: 0.4425
# Epoch 12/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.8183 - loss: 0.4920 - val_accuracy: 0.8264 - val_loss: 0.3954
# Epoch 13/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.8529 - loss: 0.4291 - val_accuracy: 0.8542 - val_loss: 0.3505
# Epoch 14/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.8651 - loss: 0.4152 - val_accuracy: 0.8819 - val_loss: 0.3134
# Epoch 15/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.8702 - loss: 0.3851 - val_accuracy: 0.8958 - val_loss: 0.2812
# Epoch 16/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.8875 - loss: 0.3744 - val_accuracy: 0.8958 - val_loss: 0.2561
# Epoch 17/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.9031 - loss: 0.2904 - val_accuracy: 0.9097 - val_loss: 0.2330
# Epoch 18/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9031 - loss: 0.2832 - val_accuracy: 0.9167 - val_loss: 0.2110
# Epoch 19/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 135ms/step - accuracy: 0.9118 - loss: 0.2648 - val_accuracy: 0.9167 - val_loss: 0.1964
# Epoch 20/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9048 - loss: 0.2353 - val_accuracy: 0.9167 - val_loss: 0.1808
# Epoch 21/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9135 - loss: 0.2426 - val_accuracy: 0.9097 - val_loss: 0.1668
# Epoch 22/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9204 - loss: 0.2390 - val_accuracy: 0.9236 - val_loss: 0.1525
# Epoch 23/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.9256 - loss: 0.2160 - val_accuracy: 0.9583 - val_loss: 0.1397
# Epoch 24/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.9412 - loss: 0.1860 - val_accuracy: 0.9722 - val_loss: 0.1287
# Epoch 25/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9481 - loss: 0.1697 - val_accuracy: 0.9722 - val_loss: 0.1215
#
# Dropout 0.8 | Fold 3
# Loss     : 0.1215
# Accuracy : 0.9722
# Model for 'fasilitas dan infrastruktur' Dropout 0.8 Fold 3 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_fasilitas_dan_infrastruktur_dropout_0_8_fold_3.keras
#
# ====== Dropout 0.8 | Fold 4 ======
# Epoch 1/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 11s 192ms/step - accuracy: 0.5260 - loss: 1.0827 - val_accuracy: 0.7014 - val_loss: 1.0569
# Epoch 2/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.6799 - loss: 1.0422 - val_accuracy: 0.7014 - val_loss: 1.0007
# Epoch 3/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.6817 - loss: 0.9751 - val_accuracy: 0.7014 - val_loss: 0.9142
# Epoch 4/25
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 136ms/step - accuracy: 0.6834 - loss: 0.8833 - val_accuracy: 0.7014 - val_loss: 0.7998
# Epoch 5/25
# ...
# Epoch 21/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7831 - loss: 0.6299 - val_accuracy: 0.8095 - val_loss: 0.5418
# Epoch 22/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7831 - loss: 0.6127 - val_accuracy: 0.8095 - val_loss: 0.5325
# Epoch 23/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.7831 - loss: 0.5772 - val_accuracy: 0.8095 - val_loss: 0.5221
# Epoch 24/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.7831 - loss: 0.5555 - val_accuracy: 0.8095 - val_loss: 0.5097
# Epoch 25/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.7831 - loss: 0.5649 - val_accuracy: 0.8095 - val_loss: 0.4974
#
# Dropout 0.8 | Fold 2
# Loss     : 0.4974
# Accuracy : 0.8095
# Model for 'waktu tunggu' Dropout 0.8 Fold 2 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_waktu_tunggu_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 10s 348ms/step - accuracy: 0.3133 - loss: 1.0992 - val_accuracy: 0.5952 - val_loss: 1.0912
# Epoch 2/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.6988 - loss: 1.0824 - val_accuracy: 0.5952 - val_loss: 1.0830
# Epoch 3/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.8253 - loss: 1.0640 - val_accuracy: 0.5952 - val_loss: 1.0737
# Epoch 4/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.8373 - loss: 1.0434 - val_accuracy: 0.5952 - val_loss: 1.0630
# Epoch 5/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.8373 - loss: 1.0249 - val_accuracy: 0.5952 - val_loss: 1.0505
# Epoch 6/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.8373 - loss: 0.9979 - val_accuracy: 0.5952 - val_loss: 1.0365
# Epoch 7/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.8373 - loss: 0.9656 - val_accuracy: 0.5952 - val_loss: 1.0205
# Epoch 8/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.8373 - loss: 0.9340 - val_accuracy: 0.5952 - val_loss: 1.0024
# Epoch 9/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.8373 - loss: 0.8949 - val_accuracy: 0.5952 - val_loss: 0.9833
# Epoch 10/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.8373 - loss: 0.8519 - val_accuracy: 0.5952 - val_loss: 0.9653
# Epoch 11/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8373 - loss: 0.8081 - val_accuracy: 0.5952 - val_loss: 0.9520
# Epoch 12/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8373 - loss: 0.7646 - val_accuracy: 0.5952 - val_loss: 0.9498
# Epoch 13/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.8373 - loss: 0.6952 - val_accuracy: 0.5952 - val_loss: 0.9657
# Epoch 14/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.8373 - loss: 0.6589 - val_accuracy: 0.5952 - val_loss: 1.0043
# Epoch 15/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.8373 - loss: 0.6132 - val_accuracy: 0.5952 - val_loss: 1.0424
# Epoch 16/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.8373 - loss: 0.6005 - val_accuracy: 0.5952 - val_loss: 1.0742
# Epoch 17/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.8373 - loss: 0.5740 - val_accuracy: 0.5952 - val_loss: 1.0882
# Epoch 18/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.8373 - loss: 0.5980 - val_accuracy: 0.5952 - val_loss: 1.0838
# Epoch 19/25
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.8373 - loss: 0.5693 - val_accuracy: 0.5952 - val_loss: 1.0698
# Epoch 20/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.6852 - loss: 1.0508 - val_accuracy: 0.7143 - val_loss: 1.0402
# Epoch 12/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.7037 - loss: 1.0519 - val_accuracy: 0.7143 - val_loss: 1.0337
# Epoch 13/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.7037 - loss: 1.0366 - val_accuracy: 0.7143 - val_loss: 1.0269
# Epoch 14/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7037 - loss: 1.0302 - val_accuracy: 0.7143 - val_loss: 1.0198
# Epoch 15/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.6852 - loss: 1.0302 - val_accuracy: 0.7143 - val_loss: 1.0125
# Epoch 16/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7037 - loss: 1.0177 - val_accuracy: 0.7143 - val_loss: 1.0048
# Epoch 17/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7037 - loss: 1.0165 - val_accuracy: 0.7143 - val_loss: 0.9967
# Epoch 18/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.7037 - loss: 1.0019 - val_accuracy: 0.7143 - val_loss: 0.9883
# Epoch 19/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.7037 - loss: 0.9978 - val_accuracy: 0.7143 - val_loss: 0.9795
# Epoch 20/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7037 - loss: 0.9851 - val_accuracy: 0.7143 - val_loss: 0.9702
# Epoch 21/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.7037 - loss: 0.9599 - val_accuracy: 0.7143 - val_loss: 0.9603
# Epoch 22/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7037 - loss: 0.9697 - val_accuracy: 0.7143 - val_loss: 0.9500
# Epoch 23/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7037 - loss: 0.9519 - val_accuracy: 0.7143 - val_loss: 0.9391
# Epoch 24/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7037 - loss: 0.9362 - val_accuracy: 0.7143 - val_loss: 0.9278
# Epoch 25/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.7037 - loss: 0.9393 - val_accuracy: 0.7143 - val_loss: 0.9161
#
# Dropout 0.8 | Fold 2
# Loss     : 0.9161
# Accuracy : 0.7143
# Model for 'biaya layanan' Dropout 0.8 Fold 2 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_biaya_layanan_dropout_0_8_fold_2.keras
#
# ====== Dropout 0.8 | Fold 3 ======
# Epoch 1/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.3519 - loss: 1.0990 - val_accuracy: 0.7857 - val_loss: 1.0935
# Epoch 2/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.4444 - loss: 1.0932 - val_accuracy: 0.7857 - val_loss: 1.0889
# Epoch 3/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.6296 - loss: 1.0873 - val_accuracy: 0.7857 - val_loss: 1.0838
# Epoch 4/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.6296 - loss: 1.0845 - val_accuracy: 0.7857 - val_loss: 1.0784
# Epoch 5/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.6481 - loss: 1.0828 - val_accuracy: 0.7857 - val_loss: 1.0729
# Epoch 6/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.6667 - loss: 1.0764 - val_accuracy: 0.7857 - val_loss: 1.0672
# Epoch 7/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.6852 - loss: 1.0679 - val_accuracy: 0.7857 - val_loss: 1.0611
# Epoch 8/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.6852 - loss: 1.0650 - val_accuracy: 0.7857 - val_loss: 1.0547
# Epoch 9/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.6852 - loss: 1.0652 - val_accuracy: 0.7857 - val_loss: 1.0481
# Epoch 10/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.6852 - loss: 1.0587 - val_accuracy: 0.7857 - val_loss: 1.0412
# Epoch 11/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.6852 - loss: 1.0495 - val_accuracy: 0.7857 - val_loss: 1.0340
# Epoch 12/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.6852 - loss: 1.0464 - val_accuracy: 0.7857 - val_loss: 1.0266
# Epoch 13/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.6852 - loss: 1.0443 - val_accuracy: 0.7857 - val_loss: 1.0191
# Epoch 14/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.6852 - loss: 1.0288 - val_accuracy: 0.7857 - val_loss: 1.0111
# Epoch 15/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.6852 - loss: 1.0242 - val_accuracy: 0.7857 - val_loss: 1.0028
# Epoch 16/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.6852 - loss: 1.0169 - val_accuracy: 0.7857 - val_loss: 0.9943
# Epoch 17/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.6852 - loss: 1.0201 - val_accuracy: 0.7857 - val_loss: 0.9857
# Epoch 18/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.6852 - loss: 1.0044 - val_accuracy: 0.7857 - val_loss: 0.9767
# Epoch 19/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.6852 - loss: 0.9883 - val_accuracy: 0.7857 - val_loss: 0.9672
# Epoch 20/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.6852 - loss: 0.9858 - val_accuracy: 0.7857 - val_loss: 0.9573
# Epoch 21/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.6852 - loss: 0.9945 - val_accuracy: 0.7857 - val_loss: 0.9472
# Epoch 22/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.6852 - loss: 0.9661 - val_accuracy: 0.7857 - val_loss: 0.9366
# Epoch 23/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.6852 - loss: 0.9651 - val_accuracy: 0.7857 - val_loss: 0.9255
# Epoch 24/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.6852 - loss: 0.9655 - val_accuracy: 0.7857 - val_loss: 0.9141
# Epoch 25/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.6852 - loss: 0.9291 - val_accuracy: 0.7857 - val_loss: 0.9022
#
# Dropout 0.8 | Fold 3
# Loss     : 0.9022
# Accuracy : 0.7857
# Model for 'biaya layanan' Dropout 0.8 Fold 3 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_biaya_layanan_dropout_0_8_fold_3.keras
#
# ====== Dropout 0.8 | Fold 4 ======
# Epoch 1/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.3818 - loss: 1.0996 - val_accuracy: 0.5385 - val_loss: 1.0960
# Epoch 2/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 0.4727 - loss: 1.0928 - val_accuracy: 0.5385 - val_loss: 1.0929
# Epoch 3/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5636 - loss: 1.0822 - val_accuracy: 0.5385 - val_loss: 1.0898
# Epoch 4/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.6182 - loss: 1.0836 - val_accuracy: 0.5385 - val_loss: 1.0864
# Epoch 5/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.6909 - loss: 1.0785 - val_accuracy: 0.5385 - val_loss: 1.0829
# Epoch 6/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.7455 - loss: 1.0748 - val_accuracy: 0.5385 - val_loss: 1.0794
# Epoch 7/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7455 - loss: 1.0674 - val_accuracy: 0.5385 - val_loss: 1.0757
# Epoch 8/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7455 - loss: 1.0591 - val_accuracy: 0.5385 - val_loss: 1.0719
# Epoch 9/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7636 - loss: 1.0541 - val_accuracy: 0.5385 - val_loss: 1.0679
# Epoch 10/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7455 - loss: 1.0457 - val_accuracy: 0.5385 - val_loss: 1.0638
# Epoch 11/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 0.7455 - loss: 1.0417 - val_accuracy: 0.5385 - val_loss: 1.0595
# Epoch 12/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.7455 - loss: 1.0356 - val_accuracy: 0.5385 - val_loss: 1.0551
# Epoch 13/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 0.7455 - loss: 1.0265 - val_accuracy: 0.5385 - val_loss: 1.0505
# Epoch 14/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7455 - loss: 1.0088 - val_accuracy: 0.5385 - val_loss: 1.0456
# Epoch 15/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7455 - loss: 1.0188 - val_accuracy: 0.5385 - val_loss: 1.0405
# Epoch 16/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7455 - loss: 1.0069 - val_accuracy: 0.5385 - val_loss: 1.0353
# Epoch 17/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7455 - loss: 0.9946 - val_accuracy: 0.5385 - val_loss: 1.0299
# Epoch 18/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.7455 - loss: 0.9768 - val_accuracy: 0.5385 - val_loss: 1.0244
# Epoch 19/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7455 - loss: 0.9766 - val_accuracy: 0.5385 - val_loss: 1.0187
# Epoch 20/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7455 - loss: 0.9615 - val_accuracy: 0.5385 - val_loss: 1.0130
# Epoch 21/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.7455 - loss: 0.9502 - val_accuracy: 0.5385 - val_loss: 1.0072
# Epoch 22/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step - accuracy: 0.7455 - loss: 0.9689 - val_accuracy: 0.5385 - val_loss: 1.0014
# Epoch 23/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7455 - loss: 0.9448 - val_accuracy: 0.5385 - val_loss: 0.9955
# Epoch 24/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.7455 - loss: 0.9351 - val_accuracy: 0.5385 - val_loss: 0.9896
# Epoch 25/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.7455 - loss: 0.9209 - val_accuracy: 0.5385 - val_loss: 0.9837
#
# Dropout 0.8 | Fold 4
# Loss     : 0.9837
# Accuracy : 0.5385
# Model for 'biaya layanan' Dropout 0.8 Fold 4 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_biaya_layanan_dropout_0_8_fold_4.keras
#
# ====== Dropout 0.8 | Fold 5 ======
# Epoch 1/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.3818 - loss: 1.0968 - val_accuracy: 0.6923 - val_loss: 1.0944
# Epoch 2/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.4000 - loss: 1.0917 - val_accuracy: 0.6923 - val_loss: 1.0904
# Epoch 3/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.5818 - loss: 1.0870 - val_accuracy: 0.6923 - val_loss: 1.0863
# Epoch 4/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.7273 - loss: 1.0774 - val_accuracy: 0.6923 - val_loss: 1.0820
# Epoch 5/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.6727 - loss: 1.0764 - val_accuracy: 0.6923 - val_loss: 1.0776
# Epoch 6/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - accuracy: 0.6364 - loss: 1.0746 - val_accuracy: 0.6923 - val_loss: 1.0732
# Epoch 7/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7091 - loss: 1.0668 - val_accuracy: 0.6923 - val_loss: 1.0686
# Epoch 8/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7091 - loss: 1.0619 - val_accuracy: 0.6923 - val_loss: 1.0638
# Epoch 9/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7273 - loss: 1.0614 - val_accuracy: 0.6923 - val_loss: 1.0590
# Epoch 10/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7091 - loss: 1.0536 - val_accuracy: 0.6923 - val_loss: 1.0539
# Epoch 11/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.7273 - loss: 1.0401 - val_accuracy: 0.6923 - val_loss: 1.0487
# Epoch 12/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7273 - loss: 1.0334 - val_accuracy: 0.6923 - val_loss: 1.0432
# Epoch 13/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.6909 - loss: 1.0295 - val_accuracy: 0.6923 - val_loss: 1.0374
# Epoch 14/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.7091 - loss: 1.0341 - val_accuracy: 0.6923 - val_loss: 1.0316
# Epoch 15/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7091 - loss: 1.0224 - val_accuracy: 0.6923 - val_loss: 1.0256
# Epoch 16/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7091 - loss: 1.0177 - val_accuracy: 0.6923 - val_loss: 1.0193
# Epoch 17/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7091 - loss: 1.0141 - val_accuracy: 0.6923 - val_loss: 1.0129
# Epoch 18/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7091 - loss: 0.9887 - val_accuracy: 0.6923 - val_loss: 1.0061
# Epoch 19/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.7091 - loss: 0.9933 - val_accuracy: 0.6923 - val_loss: 0.9990
# Epoch 20/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.7091 - loss: 0.9706 - val_accuracy: 0.6923 - val_loss: 0.9917
# Epoch 21/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.7091 - loss: 0.9698 - val_accuracy: 0.6923 - val_loss: 0.9840
# Epoch 22/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.7091 - loss: 0.9618 - val_accuracy: 0.6923 - val_loss: 0.9761
# Epoch 23/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.7091 - loss: 0.9454 - val_accuracy: 0.6923 - val_loss: 0.9679
# Epoch 24/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.7091 - loss: 0.9479 - val_accuracy: 0.6923 - val_loss: 0.9594
# Epoch 25/25
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.7091 - loss: 0.9253 - val_accuracy: 0.6923 - val_loss: 0.9508
#
# Dropout 0.8 | Fold 5
# Loss     : 0.9508
# Accuracy : 0.6923
# Model for 'biaya layanan' Dropout 0.8 Fold 5 saved to:
# /kaggle/working/EPOCH_25/sentiment_models_per_aspect/epoch_25/sentiment_model_biaya_layanan_dropout_0_8_fold_5.keras
#
# ============================================================
# RATA-RATA AKURASI ASPEK 'biaya layanan' | DROPOUT 0.8
# ============================================================
# Average Accuracy : 0.7033

# %%
import os
import re
import numpy as np
import pandas as pd

from tensorflow.keras.models import load_model

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score
)

# ============================================================
# CEK VARIABEL YANG DIBUTUHKAN
# ============================================================

if 'BASE_DRIVE_PATH' not in globals():
    print("Error: BASE_DRIVE_PATH tidak ditemukan.")
    raise SystemExit()

if 'sentiment_le' not in globals():
    print("Warning: sentiment_le tidak ditemukan.")
    sentiment_target_names = [str(i) for i in range(3)]
else:
    sentiment_target_names = list(sentiment_le.classes_)

if 'DROPOUT_VALUES' not in globals():
    DROPOUT_VALUES = [0.2, 0.5, 0.8]

# ============================================================
# LOKASI MODEL
# ============================================================

save_dir_relative = f"sentiment_models_per_aspect/epoch_{EPOCHS}"

sentiment_models_base_dir = os.path.join(
    BASE_DRIVE_PATH,
    save_dir_relative
)

print("="*70)
print("EVALUASI ENSEMBLE MODEL SENTIMEN PER ASPEK (per nilai dropout)")
print("="*70)

def get_fold_number(filename):
    match = re.search(r'fold_(\d+)\.keras', filename)
    if match:
        return int(match.group(1))
    return -1

# Menyimpan ringkasan ensemble untuk semua kombinasi aspek x dropout
all_ensemble_rows = []

# ============================================================
# LOOP SETIAP ASPEK
# ============================================================

for aspek_name, data in split_data_per_aspek.items():

    print("\n")
    print("="*70)
    print(f"EVALUASI ASPEK : {aspek_name}")
    print("="*70)

    # --------------------------------------------------------
    # CEK DATA TEST
    # --------------------------------------------------------

    if (
        'X_test_padded' not in data
        or
        'Y_test' not in data
    ):
        print("Data test tidak ditemukan.")
        continue

    X_test_aspect = data['X_test_padded']
    Y_test_aspect = np.array(data['Y_test'])

    if len(Y_test_aspect) == 0:
        print("Data test kosong.")
        continue

    cleaned_aspek_name = aspek_name.replace(' ', '_').replace('/', '_').lower()

    # --------------------------------------------------------
    # LOOP SETIAP NILAI DROPOUT
    # --------------------------------------------------------

    for dropout_rate in DROPOUT_VALUES:

        dropout_tag = str(dropout_rate).replace('.', '_')

        print("\n" + "-"*70)
        print(f"ASPEK '{aspek_name}' | DROPOUT = {dropout_rate}")
        print("-"*70)

        # --------------------------------------------------------
        # CARI MODEL UNTUK ASPEK + DROPOUT INI
        # --------------------------------------------------------

        prefix = f"sentiment_model_{cleaned_aspek_name}_dropout_{dropout_tag}_fold_"

        aspect_model_files = [
            f for f in os.listdir(sentiment_models_base_dir)
            if f.startswith(prefix) and f.endswith('.keras')
        ]

        if not aspect_model_files:
            print(f"Tidak ditemukan model untuk aspek '{aspek_name}' dengan dropout {dropout_rate}")
            continue

        aspect_model_files = sorted(aspect_model_files, key=get_fold_number)

        print(f"Jumlah model ditemukan : {len(aspect_model_files)}")

        # --------------------------------------------------------
        # LOAD SEMUA MODEL (5-fold) UNTUK DROPOUT INI
        # --------------------------------------------------------

        all_y_pred_probs = []

        for model_file in aspect_model_files:

            full_model_path = os.path.join(sentiment_models_base_dir, model_file)

            try:
                model = load_model(full_model_path)
                y_pred_prob = model.predict(X_test_aspect, verbose=0)
                all_y_pred_probs.append(y_pred_prob)
            except Exception as e:
                print(f"Error model {model_file}: {e}")

        if len(all_y_pred_probs) == 0:
            print("Tidak ada prediksi yang berhasil.")
            continue

        # --------------------------------------------------------
        # ENSEMBLE SOFT VOTING (antar 5 fold, untuk dropout ini)
        # --------------------------------------------------------

        avg_y_pred_prob = np.mean(all_y_pred_probs, axis=0)
        y_pred_ensemble = np.argmax(avg_y_pred_prob, axis=1)

        # --------------------------------------------------------
        # METRICS
        # --------------------------------------------------------

        accuracy = accuracy_score(Y_test_aspect, y_pred_ensemble)
        precision = precision_score(Y_test_aspect, y_pred_ensemble, average='weighted', zero_division=0)
        recall = recall_score(Y_test_aspect, y_pred_ensemble, average='weighted', zero_division=0)
        f1 = f1_score(Y_test_aspect, y_pred_ensemble, average='weighted', zero_division=0)

        all_ensemble_rows.append({
            'aspek': aspek_name,
            'dropout': dropout_rate,
            'accuracy': accuracy,
            'precision': precision,
            'recall': recall,
            'f1_score': f1
        })

        print("\n" + "-"*60)
        print("HASIL EVALUASI ENSEMBLE")
        print("-"*60)

        print(f"Accuracy      : {accuracy:.4f}")
        print(f"Precision     : {precision:.4f}")
        print(f"Recall        : {recall:.4f}")
        print(f"F1-Score      : {f1:.4f}")

        print("\nClassification Report:")
        print(
            classification_report(
                Y_test_aspect,
                y_pred_ensemble,
                target_names=sentiment_target_names,
                zero_division=0
            )
        )

        print("\nConfusion Matrix:")
        print(confusion_matrix(Y_test_aspect, y_pred_ensemble))

# ============================================================
# RINGKASAN SEMUA ASPEK x DROPOUT
# ============================================================

if all_ensemble_rows:
    df_sentiment_dropout_summary = pd.DataFrame(all_ensemble_rows)

    print("\n" + "#"*70)
    print("# RINGKASAN ENSEMBLE SENTIMEN PER ASPEK x DROPOUT")
    print("#"*70)
    display(df_sentiment_dropout_summary.sort_values(by=['aspek', 'accuracy'], ascending=[True, False]))

    print("\n" + "#"*70)
    print("# RATA-RATA AKURASI PER DROPOUT (semua aspek digabung)")
    print("#"*70)
    display(
        df_sentiment_dropout_summary
        .groupby('dropout')[['accuracy', 'precision', 'recall', 'f1_score']]
        .mean()
        .sort_values(by='accuracy', ascending=False)
    )

# ============================================================
# SELESAI
# ============================================================

print("\n")
print("="*70)
print("EVALUASI MODEL SENTIMEN PER ASPEK SELESAI")
print("="*70)
# Out:
# ======================================================================
# EVALUASI ENSEMBLE MODEL SENTIMEN PER ASPEK (per nilai dropout)
# ======================================================================
#
#
# ======================================================================
# EVALUASI ASPEK : fasilitas dan infrastruktur
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
# WARNING:tensorflow:5 out of the last 40 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78b046f59260> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x78b1201bd620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.9337
# Precision     : 0.9364
# Recall        : 0.9337
# F1-Score      : 0.9331
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       1.00      0.73      0.85        15
#      Neutral       0.85      0.91      0.88        44
#     Positive       0.96      0.97      0.96       122
#
#     accuracy                           0.93       181
#    macro avg       0.94      0.87      0.90       181
# weighted avg       0.94      0.93      0.93       181
#
#
# Confusion Matrix:
# [[ 11   3   1]
#  [  0  40   4]
#  [  0   4 118]]
#
# ----------------------------------------------------------------------
# ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.9282
# Precision     : 0.9274
# Recall        : 0.9282
# F1-Score      : 0.9274
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.85      0.73      0.79        15
#      Neutral       0.87      0.89      0.88        44
#     Positive       0.96      0.97      0.96       122
#
#     accuracy                           0.93       181
#    macro avg       0.89      0.86      0.88       181
# weighted avg       0.93      0.93      0.93       181
#
#
# Confusion Matrix:
# [[ 11   3   1]
#  [  1  39   4]
#  [  1   3 118]]
#
# ----------------------------------------------------------------------
# ASPEK 'fasilitas dan infrastruktur' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.9282
# Precision     : 0.9281
# Recall        : 0.9282
# F1-Score      : 0.9280
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.86      0.80      0.83        15
#      Neutral       0.87      0.89      0.88        44
#     Positive       0.96      0.96      0.96       122
#
#     accuracy                           0.93       181
#    macro avg       0.89      0.88      0.89       181
# weighted avg       0.93      0.93      0.93       181
#
#
# Confusion Matrix:
# [[ 12   2   1]
#  [  1  39   4]
#  [  1   4 117]]
#
#
# ======================================================================
# EVALUASI ASPEK : kualitas pelayanan medis dan staf
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.9206
# Precision     : 0.9239
# Recall        : 0.9206
# F1-Score      : 0.9214
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.50      0.67      0.57         9
#      Neutral       0.93      0.85      0.89       124
#     Positive       0.94      0.96      0.95       245
#
#     accuracy                           0.92       378
#    macro avg       0.79      0.83      0.80       378
# weighted avg       0.92      0.92      0.92       378
#
#
# Confusion Matrix:
# [[  6   0   3]
#  [  5 106  13]
#  [  1   8 236]]
#
# ----------------------------------------------------------------------
# ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.9286
# Precision     : 0.9309
# Recall        : 0.9286
# F1-Score      : 0.9296
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.45      0.56      0.50         9
#      Neutral       0.92      0.90      0.91       124
#     Positive       0.96      0.96      0.96       245
#
#     accuracy                           0.93       378
#    macro avg       0.78      0.80      0.79       378
# weighted avg       0.93      0.93      0.93       378
#
#
# Confusion Matrix:
# [[  5   1   3]
#  [  5 111   8]
#  [  1   9 235]]
#
# ----------------------------------------------------------------------
# ASPEK 'kualitas pelayanan medis dan staf' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.9339
# Precision     : 0.9271
# Recall        : 0.9339
# F1-Score      : 0.9300
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.20      0.11      0.14         9
#      Neutral       0.89      0.94      0.92       124
#     Positive       0.97      0.96      0.97       245
#
#     accuracy                           0.93       378
#    macro avg       0.69      0.67      0.68       378
# weighted avg       0.93      0.93      0.93       378
#
#
# Confusion Matrix:
# [[  1   5   3]
#  [  3 117   4]
#  [  1   9 235]]
#
#
# ======================================================================
# EVALUASI ASPEK : lainnya
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'lainnya' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.8113
# Precision     : 0.8120
# Recall        : 0.8113
# F1-Score      : 0.8115
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.79      0.81        56
#      Neutral       0.85      0.85      0.85       237
#     Positive       0.74      0.76      0.75       131
#
#     accuracy                           0.81       424
#    macro avg       0.81      0.80      0.80       424
# weighted avg       0.81      0.81      0.81       424
#
#
# Confusion Matrix:
# [[ 44   6   6]
#  [  7 201  29]
#  [  2  30  99]]
#
# ----------------------------------------------------------------------
# ASPEK 'lainnya' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.8443
# Precision     : 0.8435
# Recall        : 0.8443
# F1-Score      : 0.8434
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.87      0.80      0.83        56
#      Neutral       0.86      0.90      0.88       237
#     Positive       0.81      0.76      0.78       131
#
#     accuracy                           0.84       424
#    macro avg       0.84      0.82      0.83       424
# weighted avg       0.84      0.84      0.84       424
#
#
# Confusion Matrix:
# [[ 45   6   5]
#  [  5 213  19]
#  [  2  29 100]]
#
# ----------------------------------------------------------------------
# ASPEK 'lainnya' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.8373
# Precision     : 0.8391
# Recall        : 0.8373
# F1-Score      : 0.8361
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.93      0.73      0.82        56
#      Neutral       0.85      0.90      0.88       237
#     Positive       0.78      0.76      0.77       131
#
#     accuracy                           0.84       424
#    macro avg       0.85      0.80      0.82       424
# weighted avg       0.84      0.84      0.84       424
#
#
# Confusion Matrix:
# [[ 41   8   7]
#  [  2 214  21]
#  [  1  30 100]]
#
#
# ======================================================================
# EVALUASI ASPEK : waktu tunggu
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'waktu tunggu' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.8491
# Precision     : 0.7839
# Recall        : 0.8491
# F1-Score      : 0.8149
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         4
#      Neutral       0.86      0.95      0.90        40
#     Positive       0.78      0.78      0.78         9
#
#     accuracy                           0.85        53
#    macro avg       0.55      0.58      0.56        53
# weighted avg       0.78      0.85      0.81        53
#
#
# Confusion Matrix:
# [[ 0  4  0]
#  [ 0 38  2]
#  [ 0  2  7]]
#
# ----------------------------------------------------------------------
# ASPEK 'waktu tunggu' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.8302
# Precision     : 0.7647
# Recall        : 0.8302
# F1-Score      : 0.7947
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         4
#      Neutral       0.84      0.95      0.89        40
#     Positive       0.75      0.67      0.71         9
#
#     accuracy                           0.83        53
#    macro avg       0.53      0.54      0.53        53
# weighted avg       0.76      0.83      0.79        53
#
#
# Confusion Matrix:
# [[ 0  4  0]
#  [ 0 38  2]
#  [ 0  3  6]]
#
# ----------------------------------------------------------------------
# ASPEK 'waktu tunggu' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.7547
# Precision     : 0.5696
# Recall        : 0.7547
# F1-Score      : 0.6492
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         4
#      Neutral       0.75      1.00      0.86        40
#     Positive       0.00      0.00      0.00         9
#
#     accuracy                           0.75        53
#    macro avg       0.25      0.33      0.29        53
# weighted avg       0.57      0.75      0.65        53
#
#
# Confusion Matrix:
# [[ 0  4  0]
#  [ 0 40  0]
#  [ 0  9  0]]
#
#
# ======================================================================
# EVALUASI ASPEK : biaya layanan
# ======================================================================
#
# ----------------------------------------------------------------------
# ASPEK 'biaya layanan' | DROPOUT = 0.2
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.5556
# Precision     : 0.3086
# Recall        : 0.5556
# F1-Score      : 0.3968
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         3
#      Neutral       0.56      1.00      0.71        10
#     Positive       0.00      0.00      0.00         5
#
#     accuracy                           0.56        18
#    macro avg       0.19      0.33      0.24        18
# weighted avg       0.31      0.56      0.40        18
#
#
# Confusion Matrix:
# [[ 0  3  0]
#  [ 0 10  0]
#  [ 0  5  0]]
#
# ----------------------------------------------------------------------
# ASPEK 'biaya layanan' | DROPOUT = 0.5
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.5556
# Precision     : 0.3086
# Recall        : 0.5556
# F1-Score      : 0.3968
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         3
#      Neutral       0.56      1.00      0.71        10
#     Positive       0.00      0.00      0.00         5
#
#     accuracy                           0.56        18
#    macro avg       0.19      0.33      0.24        18
# weighted avg       0.31      0.56      0.40        18
#
#
# Confusion Matrix:
# [[ 0  3  0]
#  [ 0 10  0]
#  [ 0  5  0]]
#
# ----------------------------------------------------------------------
# ASPEK 'biaya layanan' | DROPOUT = 0.8
# ----------------------------------------------------------------------
# Jumlah model ditemukan : 5
#
# ------------------------------------------------------------
# HASIL EVALUASI ENSEMBLE
# ------------------------------------------------------------
# Accuracy      : 0.5556
# Precision     : 0.3086
# Recall        : 0.5556
# F1-Score      : 0.3968
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Negative       0.00      0.00      0.00         3
#      Neutral       0.56      1.00      0.71        10
#     Positive       0.00      0.00      0.00         5
#
#     accuracy                           0.56        18
#    macro avg       0.19      0.33      0.24        18
# weighted avg       0.31      0.56      0.40        18
#
#
# Confusion Matrix:
# [[ 0  3  0]
#  [ 0 10  0]
#  [ 0  5  0]]
#
# ######################################################################
# # RINGKASAN ENSEMBLE SENTIMEN PER ASPEK x DROPOUT
# ######################################################################
#                                 aspek  dropout  accuracy  precision    recall  \
# 12                      biaya layanan      0.2  0.555556   0.308642  0.555556
# 13                      biaya layanan      0.5  0.555556   0.308642  0.555556
# 14                      biaya layanan      0.8  0.555556   0.308642  0.555556
# 0         fasilitas dan infrastruktur      0.2  0.933702   0.936395  0.933702
# 1         fasilitas dan infrastruktur      0.5  0.928177   0.927438  0.928177
# 2         fasilitas dan infrastruktur      0.8  0.928177   0.928124  0.928177
# 5   kualitas pelayanan medis dan staf      0.8  0.933862   0.927146  0.933862
# 4   kualitas pelayanan medis dan staf      0.5  0.928571   0.930920  0.928571
# 3   kualitas pelayanan medis dan staf      0.2  0.920635   0.923922  0.920635
# 7                             lainnya      0.5  0.844340   0.843536  0.844340
# 8                             lainnya      0.8  0.837264   0.839121  0.837264
# 6                             lainnya      0.2  0.811321   0.811967  0.811321
# 9                        waktu tunggu      0.2  0.849057   0.783877  0.849057
# 10                       waktu tunggu      0.5  0.830189   0.764675  0.830189
# 11                       waktu tunggu      0.8  0.754717   0.569598  0.754717
#
#     f1_score
# 12  0.396825
# 13  0.396825
# 14  0.396825
# 0   0.933105
# 1   0.927436
# 2   0.928042
# 5   0.929951
# 4   0.929578
# 3   0.921356
# 7   0.843351
# 8   0.836118
# 6   0.811534
# 9   0.814915
# 10  0.794673
# 11  0.649219
# ######################################################################
# # RATA-RATA AKURASI PER DROPOUT (semua aspek digabung)
# ######################################################################
#          accuracy  precision    recall  f1_score
# dropout
# 0.5      0.817366   0.755042  0.817366  0.778373
# 0.2      0.814054   0.752961  0.814054  0.775547
# 0.8      0.801915   0.714526  0.801915  0.748031
# ======================================================================
# EVALUASI MODEL SENTIMEN PER ASPEK SELESAI
# ======================================================================

# %%
import os
import re
import numpy as np
import pandas as pd
from tensorflow.keras.models import load_model
from sklearn.metrics import accuracy_score

# Define the directory to save the best sentiment models
best_sentiment_models_dir = os.path.join(BASE_DRIVE_PATH, 'best_sentiment_models')
os.makedirs(best_sentiment_models_dir, exist_ok=True)

# Path where individual fold models for each aspect are saved
# Assuming EPOCHS is still defined and correct for the folder name
if 'EPOCHS' not in globals():
    EPOCHS = 25 # Fallback if EPOCHS is not defined
sentiment_models_base_dir = os.path.join(BASE_DRIVE_PATH, f"sentiment_models_per_aspect/epoch_{EPOCHS}")

print("Menyimpan model terbaik untuk setiap klasifikasi sentimen per aspek (lintas semua nilai dropout)...")

def parse_dropout_fold(filename):
    match = re.search(r'dropout_([0-9_]+)_fold_(\d+)\.keras', filename)
    if match:
        return float(match.group(1).replace('_', '.')), int(match.group(2))
    return None, -1

# Iterate through each aspect's split data
if 'split_data_per_aspek' in globals() and split_data_per_aspek:
    for aspek_name, data in split_data_per_aspek.items():
        print(f"\n--- Memproses aspek: {aspek_name} ---")

        # Check if test data exists for this aspect
        if 'X_test_padded' not in data or 'Y_test' not in data:
            print(f"  Tidak ada data uji yang diproses untuk aspek '{aspek_name}'. Melewatkan.")
            continue
        if len(data['Y_test']) == 0:
            print(f"  Data uji kosong untuk aspek '{aspek_name}'. Melewatkan.")
            continue

        X_test_aspect = data['X_test_padded']
        Y_test_aspect = np.array(data['Y_test'])

        # Clean aspect_name for filename matching (replace spaces/slashes with underscores and lowercase)
        cleaned_aspek_name = aspek_name.replace(' ', '_').replace('/', '_').lower()

        # Filter model files for the current aspect (semua nilai dropout & fold)
        aspect_model_files = [
            f for f in os.listdir(sentiment_models_base_dir)
            if f.startswith(f"sentiment_model_{cleaned_aspek_name}_dropout_") and f.endswith('.keras')
        ]

        if not aspect_model_files:
            print(f"  Tidak ditemukan model untuk aspek '{aspek_name}' di '{sentiment_models_base_dir}'.")
            continue

        best_accuracy_for_aspect = -1
        best_model_filename = ""
        best_dropout_for_aspect = None
        best_fold_for_aspect = None

        # Evaluate each model (semua dropout & fold) for the current aspect to find the best one
        for model_file in aspect_model_files:
            full_model_path = os.path.join(sentiment_models_base_dir, model_file)
            try:
                model = load_model(full_model_path)

                # Predict probabilities
                y_pred_prob = model.predict(X_test_aspect, verbose=0)
                # Get predicted classes
                y_pred = np.argmax(y_pred_prob, axis=1)

                # Calculate accuracy
                current_accuracy = accuracy_score(Y_test_aspect, y_pred)

                if current_accuracy > best_accuracy_for_aspect:
                    best_accuracy_for_aspect = current_accuracy
                    best_model_filename = model_file
                    best_dropout_for_aspect, best_fold_for_aspect = parse_dropout_fold(model_file)

            except Exception as e:
                print(f"  Error saat mengevaluasi model '{model_file}': {e}")
                continue

        if best_model_filename:
            source_best_model_path = os.path.join(sentiment_models_base_dir, best_model_filename)
            destination_best_model_path = os.path.join(best_sentiment_models_dir, f"{cleaned_aspek_name}_best_model.keras")

            try:
                # Load the best model again to save it in the new location
                best_model = load_model(source_best_model_path)
                best_model.save(destination_best_model_path)
                print(
                    f"  ✅ Model terbaik untuk aspek '{aspek_name}' "
                    f"(Dropout: {best_dropout_for_aspect}, Fold: {best_fold_for_aspect}, "
                    f"Akurasi: {best_accuracy_for_aspect:.4f}) disimpan sebagai: '{destination_best_model_path}'"
                )
            except Exception as e:
                print(f"  ❌ Error saat menyimpan model terbaik untuk aspek '{aspek_name}': {e}")
        else:
            print(f"  Tidak ada model terbaik yang ditemukan untuk aspek '{aspek_name}'.")

else:
    print("❌ Variabel 'split_data_per_aspek' tidak ditemukan atau kosong. Pastikan data telah dibagi per aspek.")

print("\nProses penyimpanan model terbaik per aspek selesai.")
# Out:
# Menyimpan model terbaik untuk setiap klasifikasi sentimen per aspek (lintas semua nilai dropout)...
#
# --- Memproses aspek: fasilitas dan infrastruktur ---
#   ✅ Model terbaik untuk aspek 'fasilitas dan infrastruktur' (Dropout: 0.5, Fold: 1, Akurasi: 0.9503) disimpan sebagai: '/kaggle/working/EPOCH_25/best_sentiment_models/fasilitas_dan_infrastruktur_best_model.keras'
#
# --- Memproses aspek: kualitas pelayanan medis dan staf ---
#   ✅ Model terbaik untuk aspek 'kualitas pelayanan medis dan staf' (Dropout: 0.8, Fold: 4, Akurasi: 0.9392) disimpan sebagai: '/kaggle/working/EPOCH_25/best_sentiment_models/kualitas_pelayanan_medis_dan_staf_best_model.keras'
#
# --- Memproses aspek: lainnya ---
#   ✅ Model terbaik untuk aspek 'lainnya' (Dropout: 0.8, Fold: 5, Akurasi: 0.8349) disimpan sebagai: '/kaggle/working/EPOCH_25/best_sentiment_models/lainnya_best_model.keras'
#
# --- Memproses aspek: waktu tunggu ---
#   ✅ Model terbaik untuk aspek 'waktu tunggu' (Dropout: 0.2, Fold: 2, Akurasi: 0.8302) disimpan sebagai: '/kaggle/working/EPOCH_25/best_sentiment_models/waktu_tunggu_best_model.keras'
#
# --- Memproses aspek: biaya layanan ---
#   ✅ Model terbaik untuk aspek 'biaya layanan' (Dropout: 0.2, Fold: 3, Akurasi: 0.6667) disimpan sebagai: '/kaggle/working/EPOCH_25/best_sentiment_models/biaya_layanan_best_model.keras'
#
# Proses penyimpanan model terbaik per aspek selesai.
